# %%
# !pip install copernicusmarine
# Out:
# Collecting copernicusmarine
#   Downloading copernicusmarine-2.4.1-py3-none-any.whl.metadata (8.2 kB)
# Collecting arcosparse<0.6.0,>=0.5.1 (from copernicusmarine)
#   Downloading arcosparse-0.5.1-py3-none-any.whl.metadata (7.7 kB)
# Collecting boto3>=1.26 (from copernicusmarine)
#   Downloading boto3-1.43.54-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: click!=8.3.0,!=8.3.1,>8.2.0 in /usr/local/lib/python3.12/dist-packages (from copernicusmarine) (8.4.2)
# Requirement already satisfied: dask>=2024.8.1 in /usr/local/lib/python3.12/dist-packages (from copernicusmarine) (2026.7.0)
# Requirement already satisfied: h5netcdf<2.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from h5netcdf[h5py]<2.0.0,>=1.4.0->copernicusmarine) (1.8.1)
# Collecting numpy>=2.1.0 (from copernicusmarine)
#   Downloading numpy-2.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.1 in /usr/local/lib/python3.12/dist-packages (from copernicusmarine) (2.13.4)
# Collecting pystac>=1.11.0 (from copernicusmarine)
#   Downloading pystac-1.15.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.12/dist-packages (from copernicusmarine) (2.32.4)
# Collecting semver>=3.0.2 (from copernicusmarine)
#   Downloading semver-3.0.4-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from copernicusmarine) (4.67.3)
# Requirement already satisfied: xarray>=2024.10.0 in /usr/local/lib/python3.12/dist-packages (from copernicusmarine) (2025.12.0)
# Collecting zarr>=2.18.3 (from copernicusmarine)
#   Downloading zarr-3.2.1-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: pandas>=2 in /usr/local/lib/python3.12/dist-packages (from arcosparse<0.6.0,>=0.5.1->copernicusmarine) (2.2.2)
# Requirement already satisfied: pyarrow>=17.0.0 in /usr/local/lib/python3.12/dist-packages (from arcosparse<0.6.0,>=0.5.1->copernicusmarine) (18.1.0)
# Collecting botocore<1.44.0,>=1.43.54 (from boto3>=1.26->copernicusmarine)
#   Downloading botocore-1.43.54-py3-none-any.whl.metadata (5.6 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.26->copernicusmarine)
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.20.0,>=0.19.0 (from boto3>=1.26->copernicusmarine)
#   Downloading s3transfer-0.19.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.8.1->copernicusmarine) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.8.1->copernicusmarine) (2025.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.8.1->copernicusmarine) (26.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.8.1->copernicusmarine) (1.4.2)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.8.1->copernicusmarine) (6.0.3)
# Requirement already satisfied: toolz>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.8.1->copernicusmarine) (0.12.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from h5netcdf[h5py]<2.0.0,>=1.4.0->copernicusmarine) (3.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.1->copernicusmarine) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.1->copernicusmarine) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.1->copernicusmarine) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.1->copernicusmarine) (0.4.2)
# Collecting pystac-core<2,>=1.15.0 (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_core-1.15.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting pystac-ext-classification (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_classification-2.0.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting pystac-ext-datacube (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_datacube-2.2.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-eo (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_eo-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-file (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_file-2.1.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-grid (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_grid-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-item-assets (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_item_assets-1.0.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-label (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_label-1.0.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-mgrs (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_mgrs-1.0.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-mlm (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_mlm-1.4.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting pystac-ext-pointcloud (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_pointcloud-1.0.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-projection (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_projection-2.0.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting pystac-ext-raster (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_raster-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-render (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_render-2.0.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-sar (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_sar-1.0.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-sat (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_sat-1.0.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-scientific (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_scientific-1.0.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-storage (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_storage-2.0.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-table (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_table-1.2.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-timestamps (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_timestamps-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-version (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_version-1.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-view (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_view-1.0.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-xarray-assets (from pystac>=1.11.0->copernicusmarine)
#   Downloading pystac_ext_xarray_assets-1.0.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27.1->copernicusmarine) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27.1->copernicusmarine) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27.1->copernicusmarine) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27.1->copernicusmarine) (2026.6.17)
# Collecting donfig>=0.8 (from zarr>=2.18.3->copernicusmarine)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr>=2.18.3->copernicusmarine) (1.8.0)
# Collecting numcodecs>=0.14 (from zarr>=2.18.3->copernicusmarine)
#   Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.44.0,>=1.43.54->boto3>=1.26->copernicusmarine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2->arcosparse<0.6.0,>=0.5.1->copernicusmarine) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2->arcosparse<0.6.0,>=0.5.1->copernicusmarine) (2026.3)
# Requirement already satisfied: locket in /usr/local/lib/python3.12/dist-packages (from partd>=1.4.0->dask>=2024.8.1->copernicusmarine) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.44.0,>=1.43.54->boto3>=1.26->copernicusmarine) (1.17.0)
# Downloading copernicusmarine-2.4.1-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 2.1 MB/s eta 0:00:00
# Downloading arcosparse-0.5.1-py3-none-any.whl (23 kB)
# Downloading boto3-1.43.54-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.0/140.0 kB 8.6 MB/s eta 0:00:00
# Downloading numpy-2.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 71.4 MB/s eta 0:00:00
# Downloading pystac-1.15.1-py3-none-any.whl (5.1 kB)
# Downloading semver-3.0.4-py3-none-any.whl (17 kB)
# Downloading zarr-3.2.1-py3-none-any.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.6/319.6 kB 24.6 MB/s eta 0:00:00
# Downloading botocore-1.43.54-py3-none-any.whl (15.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 51.7 MB/s eta 0:00:00
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 85.6 MB/s eta 0:00:00
# Downloading pystac_core-1.15.1-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.0/119.0 kB 10.7 MB/s eta 0:00:00
# Downloading s3transfer-0.19.2-py3-none-any.whl (90 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 kB 8.1 MB/s eta 0:00:00
# Downloading pystac_ext_classification-2.0.0-py3-none-any.whl (7.0 kB)
# Downloading pystac_ext_datacube-2.2.0-py3-none-any.whl (6.8 kB)
# Downloading pystac_ext_eo-1.1.0-py3-none-any.whl (7.4 kB)
# Downloading pystac_ext_file-2.1.0-py3-none-any.whl (5.5 kB)
# Downloading pystac_ext_grid-1.1.0-py3-none-any.whl (3.3 kB)
# Downloading pystac_ext_item_assets-1.0.0-py3-none-any.whl (3.4 kB)
# Downloading pystac_ext_label-1.0.1-py3-none-any.whl (7.9 kB)
# Downloading pystac_ext_mgrs-1.0.0-py3-none-any.whl (3.8 kB)
# Downloading pystac_ext_mlm-1.4.0-py3-none-any.whl (13 kB)
# Downloading pystac_ext_pointcloud-1.0.0-py3-none-any.whl (6.2 kB)
# Downloading pystac_ext_projection-2.0.0-py3-none-any.whl (7.1 kB)
# Downloading pystac_ext_raster-1.1.0-py3-none-any.whl (6.6 kB)
# Downloading pystac_ext_render-2.0.0-py3-none-any.whl (5.0 kB)
# Downloading pystac_ext_sar-1.0.0-py3-none-any.whl (6.3 kB)
# Downloading pystac_ext_sat-1.0.0-py3-none-any.whl (4.6 kB)
# Downloading pystac_ext_scientific-1.0.0-py3-none-any.whl (5.2 kB)
# Downloading pystac_ext_storage-2.0.0-py3-none-any.whl (7.4 kB)
# Downloading pystac_ext_table-1.2.0-py3-none-any.whl (4.4 kB)
# Downloading pystac_ext_timestamps-1.1.0-py3-none-any.whl (4.3 kB)
# Downloading pystac_ext_version-1.2.0-py3-none-any.whl (5.4 kB)
# Downloading pystac_ext_view-1.0.0-py3-none-any.whl (4.5 kB)
# Downloading pystac_ext_xarray_assets-1.0.0-py3-none-any.whl (3.6 kB)
# Installing collected packages: semver, numpy, jmespath, donfig, pystac-core, numcodecs, botocore, zarr, s3transfer, pystac-ext-xarray-assets, pystac-ext-view, pystac-ext-version, pystac-ext-timestamps, pystac-ext-table, pystac-ext-storage, pystac-ext-scientific, pystac-ext-sat, pystac-ext-sar, pystac-ext-render, pystac-ext-raster, pystac-ext-projection, pystac-ext-pointcloud, pystac-ext-mlm, pystac-ext-mgrs, pystac-ext-label, pystac-ext-item-assets, pystac-ext-grid, pystac-ext-file, pystac-ext-eo, pystac-ext-datacube, pystac-ext-classification, pystac, boto3, arcosparse, copernicusmarine
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.5.1 which is incompatible.
# Successfully installed arcosparse-0.5.1 boto3-1.43.54 botocore-1.43.54 copernicusmarine-2.4.1 donfig-0.8.1.post1 jmespath-1.1.0 numcodecs-0.16.5 numpy-2.5.1 pystac-1.15.1 pystac-core-1.15.1 pystac-ext-classification-2.0.0 pystac-ext-datacube-2.2.0 pystac-ext-eo-1.1.0 pystac-ext-file-2.1.0 pystac-ext-grid-1.1.0 pystac-ext-item-assets-1.0.0 pystac-ext-label-1.0.1 pystac-ext-mgrs-1.0.0 pystac-ext-mlm-1.4.0 pystac-ext-pointcloud-1.0.0 pystac-ext-projection-2.0.0 pystac-ext-raster-1.1.0 pystac-ext-render-2.0.0 pystac-ext-sar-1.0.0 pystac-ext-sat-1.0.0 pystac-ext-scientific-1.0.0 pystac-ext-storage-2.0.0 pystac-ext-table-1.2.0 pystac-ext-timestamps-1.1.0 pystac-ext-version-1.2.0 pystac-ext-view-1.0.0 pystac-ext-xarray-assets-1.0.0 s3transfer-0.19.2 semver-3.0.4 zarr-3.2.1

# %%
import copernicusmarine

copernicusmarine.subset(
  dataset_id="cmems_mod_glo_phy_my_0.083deg_P1D-m",
  variables=["thetao"],
  minimum_longitude = 129.0,
  maximum_longitude = 133.0,
  minimum_latitude = 35.0,
  maximum_latitude = 40.0,
  start_datetime="2012-08-19T00:00:00",
  end_datetime="2026-04-28T00:00:00",
  minimum_depth=0.49402499198913574,
  maximum_depth=0.49402499198913574,
)
# Out:
# INFO - 2026-07-23T02:23:26Z - Downloading Copernicus Marine data requires a Copernicus Marine username and password, sign up for free at: https://data.marine.copernicus.eu/register
# INFO:copernicusmarine:Downloading Copernicus Marine data requires a Copernicus Marine username and password, sign up for free at: https://data.marine.copernicus.eu/register
# Copernicus Marine username: sherxonazimov94@gmail.com
# Copernicus Marine password: ··········
# INFO - 2026-07-23T02:23:46Z - Selected dataset version: "202311"
# INFO:copernicusmarine:Selected dataset version: "202311"
# INFO - 2026-07-23T02:23:46Z - Selected dataset part: "default"
# INFO:copernicusmarine:Selected dataset part: "default"
#   0%|          | [00:00<?]
# INFO - 2026-07-23T02:23:58Z - Total size of the download: 28.54 MB.
# INFO:copernicusmarine:Total size of the download: 28.54 MB.
# ResponseSubset(file_path=PosixPath('cmems_mod_glo_phy_my_0.083deg_P1D-m_thetao_129.00E-133.00E_35.00N-40.00N_0.49m_2012-08-19-2026-04-28.nc'), output_directory=PosixPath('.'), filename='cmems_mod_glo_phy_my_0.083deg_P1D-m_thetao_129.00E-133.00E_35.00N-40.00N_0.49m_2012-08-19-2026-04-28.nc', file_size=28.5396965648855, data_transfer_size=488.0024427480916, variables=['thetao'], coordinates_extent=[GeographicalExtent(minimum=129.0, maximum=133.0, unit='degrees_east', coordinate_id='longitude'), GeographicalExtent(minimum=35.0, maximum=40.0, unit='degrees_north', coordinate_id='latitude'), TimeExtent(minimum='2012-08-19T00:00:00+00:00', maximum='2026-04-28T00:00:00+00:00', unit='iso8601', coordinate_id='time'), GeographicalExtent(minimum=0.49402499198913574, maximum=0.49402499198913574, unit='m', coordinate_id='depth')], status='000', message='The request was successful.', file_status='DOWNLOADED', file_names=None)

# %%
import xarray as xr
ds = xr.open_dataset("cmems_mod_glo_phy_my_0.083deg_P1D-m_thetao_129.00E-133.00E_35.00N-40.00N_0.49m_2012-08-19-2026-04-28.nc")
print(ds)
# Out:
# <xarray.Dataset> Size: 120MB
# Dimensions:    (time: 5001, depth: 1, latitude: 61, longitude: 49)
# Coordinates:
#   * time       (time) datetime64[ns] 40kB 2012-08-19 2012-08-20 ... 2026-04-28
#   * depth      (depth) float32 4B 0.494
#   * latitude   (latitude) float32 244B 35.0 35.08 35.17 ... 39.83 39.92 40.0
#   * longitude  (longitude) float32 196B 129.0 129.1 129.2 ... 132.8 132.9 133.0
# Data variables:
#     thetao     (time, depth, latitude, longitude) float64 120MB ...
# Attributes: (12/25)
#     Conventions:               CF-1.4
#     bulletin_date:             2021-07-07 00:00:00
#     bulletin_type:             operational
#     comment:                   CMEMS product
#     domain_name:               GL12
#     easting:                   longitude
#     ...                        ...
#     references:                http://www.mercator-ocean.fr
#     source:                    MERCATOR GLORYS12V1
#     title:                     daily mean fields from Global Ocean Physics An...
#     z_max:                     5727.9169921875
#     z_min:                     0.49402499198913574
#     copernicusmarine_version:  2.4.1

# %%
import numpy as np

# 1. Extract 3D numpy array, dropping depth: shape (T, Lat, Lon) -> (5001, 49, 27)
sst_np = ds["thetao"].squeeze().values

# 2. Extract 2D boolean mask for valid ocean points: shape (49, 27)
ocean_mask = ~np.isnan(sst_np[0])

# 3. Filter out land (NaN) cells: shape (T, ocean_features) -> (5001, 1293)
X_nvar = sst_np[:, ocean_mask]

print("NVAR input shape before transpose:", X_nvar.shape)  # (5001, 1293)

# 4. Transpose to (features, time) and save: shape (1293, 5001)
np.save("SST_temp_Dataset_1.npy", X_nvar.T)

print(
    "Saved file shape (features, T):", np.load("SST_temp_Dataset_1.npy").shape
)
# Out:
# NVAR input shape before transpose: (5001, 2801)
# Saved file shape (features, T): (2801, 5001)

# %%
import numpy as np

# Extract 2D array for a single timestamp
sst_2d = ds["thetao"].isel(time=0, depth=0).values

# Water = True, Land = False
ocean_mask = ~np.isnan(sst_2d)

# 1. Check if any land (False) exists
has_land = False in ocean_mask  # Returns True

# 2. Count total land points (False entries)
num_land_points = np.sum(~ocean_mask)
print(f"Number of land cells (False): {num_land_points}")
# Out:
# Number of land cells (False): 188

# %%
sst = ds['thetao']
print(sst.shape)  # (time, depth, lat, lon)
# Out:
# (5001, 1, 61, 49)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Set a professional style for the plot
plt.style.use('seaborn-v0_8')  # Use a clean, professional matplotlib style

# Randomly select a time index
random_time_index = np.random.randint(0, sst.shape[0])

# Extract sea surface salinity at the selected time index (depth = 0)
sal_slice = sst.isel(time=random_time_index, depth=0)

# Create a figure with a professional size and resolution
fig, ax = plt.subplots(figsize=(10, 6), dpi=100)

# Plot the salinity slice with a colorbar
plot = sal_slice.plot(
    cmap='RdBu_r',  # Use a diverging colormap for better contrast
    ax=ax,
    cbar_kwargs={
        'label': 'Temperature (°C)',  # Professional label for colorbar
        'pad': 0.02,  # Adjust colorbar position
    }
)

# Customize the plot title and labels
ax.set_title(
    f'Sea water potential temperature\nTime Index: {random_time_index}',
    fontsize=14,
    pad=15,
    weight='bold'
)
ax.set_xlabel('Longitude (°E)', fontsize=12)
ax.set_ylabel('Latitude (°N)', fontsize=12)

# Improve tick label formatting
ax.tick_params(axis='both', which='major', labelsize=10)

# Ensure the plot layout is tight to avoid clipping
plt.tight_layout()

# Save the plot as a high-resolution PNG
plt.savefig('Sea_water_potential_temperature.png', dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

# Close the figure to free memory
plt.close(fig)
