# %%
# ============================================================
# High-Resolution SST Forecasting in the East Sea via SVD-Enhanced NG-RC
# ============================================================
# Author: Azimov Sherkhon Azizkhon Ugli
# Email:  sherxonazimov94@pusan.ac.kr
# GitHub: @AzimovSherkhon
# ============================================================

# %%
# ============================================================
# Imports
# ============================================================
import numpy as np
import matplotlib.pyplot as plt
import itertools
import warnings

from sklearn.decomposition import PCA

# Suppress unnecessary warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# ============================================================
# Reproducibility
# ============================================================

seed = 2025

np.random.seed(seed)

# %%
# ============================================================
# 1. Load SST Dataset
# ============================================================

sst_data = np.load("sst_normalized_5k.npy")

# Shape:
# (spatial_points, time)

sst_time_major = sst_data.T

print("Original SST shape:", sst_time_major.shape)
# Out:
# Original SST shape: (5001, 2801)

# %%
# ============================================================
# 2. Time Setup
# ============================================================
dt = 1.0
warmup   = 100.0
traintime = 3900.0
valtime   = 500.0
testtime  = 500.0

maxtime = warmup + traintime + valtime + testtime

warmup_pts    = int(round(warmup / dt))
traintime_pts = int(round(traintime / dt))
valtime_pts   = int(round(valtime / dt))
testtime_pts  = int(round(testtime / dt))

warmtrain_pts = warmup_pts + traintime_pts
val_end       = warmtrain_pts + valtime_pts
maxtime_pts   = int(round(maxtime / dt))

print("==== Data Splits ====")
print(f"Warmup : {warmup_pts}")
print(f"Train  : {traintime_pts}")
print(f"Val    : {valtime_pts}")
print(f"Test   : {testtime_pts}")
# Out:
# ==== Data Splits ====
# Warmup : 100
# Train  : 3900
# Val    : 500
# Test   : 500

# %%
# ============================================================
# 3. Fit PCA/SVD on TRAINING DATA ONLY
# ============================================================
pca_train_end = warmtrain_pts

n_components = 1

train_sst = sst_time_major[:pca_train_end]

pca = PCA(
    n_components=n_components,
    svd_solver='full'
)

pca.fit(train_sst)

# Transform entire dataset using TRAIN PCA basis
sst_pca = pca.transform(sst_time_major)

explained_variance = pca.explained_variance_ratio_

print("\n==== PCA/SVD Summary ====")
print(f"Retained components      : {n_components}")
print(f"Explained variance ratio : {explained_variance}")
# Out:
# ==== PCA/SVD Summary ====
# Retained components      : 1
# Explained variance ratio : [0.96191511]

# %%
# ============================================================
# 4. Prepare Latent SST Dataset
# ============================================================

latent_sst = sst_pca.T

X_soln = latent_sst[:, :maxtime_pts + 1]

d, T_full = X_soln.shape

print(f"\nLatent SST shape: {X_soln.shape}")
# Out:
# Latent SST shape: (1, 5001)

# %%
# ============================================================
# Visualization of Latent SST Dynamics (PCA Components)
# ============================================================

# latent_sst shape:
# (n_components, time)

num_components_to_plot = min(n_components, 10)

time = np.arange(latent_sst.shape[1])

plt.figure(figsize=(12, 2.5 * num_components_to_plot))

for i in range(num_components_to_plot):

    plt.subplot(num_components_to_plot, 1, i + 1)

    plt.plot(
        time,
        latent_sst[i],
        linewidth=1.0,
        label=f'PC {i+1}'
    )

    plt.ylabel(f'PC {i+1}')

    plt.grid(True, alpha=0.3)

    plt.legend(loc='upper right')

    if i == 0:
        plt.title(
            "Latent SST Dynamics in PCA Space",
            fontsize=14
        )

    if i == num_components_to_plot - 1:
        plt.xlabel("Time Step")

plt.tight_layout()
plt.show()

# %%
# ============================================================
# 5. NG-RC / NVAR Hyperparameter Optimization Configuration
# ============================================================

import time
import optuna
import numpy as np

# Validation configuration
window_size = 90
stride = 1  # fully overlapping rolling windows

# Number of Optuna trials
n_trials = 200

# Store optimization history
results = []


# ============================================================
# 6. Vectorized Feature Construction for NG-RC
# ============================================================

def build_features(data, k, start_idx, end_idx):
    """
    Construct nonlinear vector autoregressive (NVAR) features using vectorization.

    Parameters
    ----------
    data : ndarray
        Input latent-state data with shape (d, T)
    k : int
        Delay embedding dimension
    start_idx : int
        Starting time index
    end_idx : int
        Ending time index (exclusive)

    Returns
    -------
    features : ndarray
        Full NVAR feature matrix of shape (d_total, length)
    linear_block : ndarray
        Delay-coordinate linear features of shape (d_linear, length)
    """
    d, _ = data.shape

    if start_idx < (k - 1):
        raise ValueError("Insufficient history for selected delay dimension k.")

    length = end_idx - start_idx
    d_linear = d * k
    d_quadratic = (d_linear * (d_linear + 1)) // 2
    d_total = 1 + d_linear + d_quadratic

    # 1. Construct Linear Delay Embedding
    linear_block = np.zeros((d_linear, length))
    for delay in range(k):
        linear_block[delay * d : (delay + 1) * d, :] = data[:, start_idx - delay : end_idx - delay]

    # 2. Construct Full Feature Matrix
    features = np.ones((d_total, length))
    features[1 : 1 + d_linear, :] = linear_block

    # 3. Vectorized Quadratic Terms
    r_idx, c_idx = np.triu_indices(d_linear)
    features[1 + d_linear :, :] = linear_block[r_idx, :] * linear_block[c_idx, :]

    return features, linear_block


# ============================================================
# 7. Optuna Objective Function
# ============================================================

def objective(trial):
    # Search Space
    k = trial.suggest_categorical("k", [2, 5, 10, 20, 30, 40, 50])
    ridge_param = trial.suggest_float("ridge", 1e-7, 1e6, log=True)

    d_linear = d * k
    d_quadratic = (d_linear * (d_linear + 1)) // 2
    d_total = 1 + d_linear + d_quadratic

    train_start = warmup_pts - 1
    train_end = warmtrain_pts - 1

    if train_start < (k - 1):
        return np.inf

    # --- Training Phase ---
    train_features, _ = build_features(X_soln, k, train_start, train_end)
    delta_x = X_soln[:, warmup_pts:warmtrain_pts] - X_soln[:, warmup_pts - 1 : warmtrain_pts - 1]

    # Ridge Regression Solution
    cov_matrix = train_features @ train_features.T
    reg_matrix = cov_matrix + ridge_param * np.eye(d_total)

    try:
        # Solve (W_out @ reg_matrix) = (delta_x @ train_features.T)
        W_out = np.linalg.solve(reg_matrix.T, (delta_x @ train_features.T).T).T
    except np.linalg.LinAlgError:
        W_out = delta_x @ train_features.T @ np.linalg.pinv(reg_matrix)

    # Pre-index upper-triangular elements for fast test feature construction
    r_idx, c_idx = np.triu_indices(d_linear)

    # --- Validation Phase ---
    validation_mses, validation_maes, validation_rmses = [], [], []

    for start in range(warmtrain_pts, val_end - window_size + 1, stride):
        end = start + window_size

        # Initialize Delay History
        history = [X_soln[:, start - k + i].copy() for i in range(k)]
        prediction = np.zeros((d, window_size))

        # Autonomous Rollout
        for step in range(window_size):
            z = np.hstack([history[-1 - delay] for delay in range(k)])

            test_features = np.ones(d_total)
            test_features[1 : 1 + d_linear] = z
            test_features[1 + d_linear :] = z[r_idx] * z[c_idx]

            delta_pred = W_out @ test_features
            next_state = history[-1] + delta_pred

            prediction[:, step] = next_state
            history.append(next_state)

        # Validation Metrics
        truth = X_soln[:, start:end]
        mse = np.mean((truth - prediction) ** 2)
        mae = np.mean(np.abs(truth - prediction))
        rmse = np.sqrt(mse)

        validation_mses.append(mse)
        validation_maes.append(mae)
        validation_rmses.append(rmse)

    # --- Aggregate Scores ---
    avg_mse = np.mean(validation_mses) if validation_mses else np.inf
    avg_mae = np.mean(validation_maes) if validation_maes else np.inf
    avg_rmse = np.mean(validation_rmses) if validation_rmses else np.inf

    results.append({
        "k": k,
        "ridge": ridge_param,
        "mse": avg_mse,
        "mae": avg_mae,
        "rmse": avg_rmse
    })

    print(
        f"Trial {trial.number:03d} | "
        f"k = {k:<2d} | "
        f"ridge = {ridge_param:>10.2e} | "
        f"MSE = {avg_mse:.6f} | "
        f"MAE = {avg_mae:.6f} | "
        f"RMSE = {avg_rmse:.6f}"
    )

    return avg_rmse


# ============================================================
# 8. Run Optuna Optimization
# ============================================================

start_time = time.time()
print("\n==== NG-RC Hyperparameter Optimization ====\n")

study = optuna.create_study(
    direction="minimize",
    sampler=optuna.samplers.TPESampler(seed=seed)
)

study.optimize(
    objective,
    n_trials=n_trials,
    show_progress_bar=True
)


# ============================================================
# 9. Best Hyperparameters Summary
# ============================================================

best_k = study.best_params["k"]
best_ridge = study.best_params["ridge"]
best_rmse = study.best_value

best_result = min(results, key=lambda x: x["rmse"])
best_mse = best_result["mse"]
best_mae = best_result["mae"]

print("\n==== Optimal NG-RC Configuration ====\n")
print(f"Optimal delay dimension (k) : {best_k}")
print(f"Optimal ridge parameter     : {best_ridge:.2e}")
print(f"Best validation MSE         : {best_mse:.6f}")
print(f"Best validation MAE         : {best_mae:.6f}")
print(f"Best validation RMSE        : {best_rmse:.6f}")
print(f"Execution time              : {time.time() - start_time:.2f} seconds")
# Out:
# [I 2026-07-26 21:42:38,355] A new study created in memory with name: no-name-41be5a2c-8a70-4808-bf26-961b78f88b3c
# ==== NG-RC Hyperparameter Optimization ====
#   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 000 | k = 10 | ridge =   2.54e-01 | MSE = 1246.655073 | MAE = 27.637642 | RMSE = 32.713182
# [I 2026-07-26 21:42:38,871] Trial 0 finished with value: 32.713181709519695 and parameters: {'k': 10, 'ridge': 0.25352464752029175}. Best is trial 0 with value: 32.713181709519695.
# Trial 001 | k = 2  | ridge =   6.41e-04 | MSE = 1713.506730 | MAE = 33.412034 | RMSE = 39.014408
# [I 2026-07-26 21:42:39,252] Trial 1 finished with value: 39.01440778380712 and parameters: {'k': 2, 'ridge': 0.0006405043692191096}. Best is trial 0 with value: 32.713181709519695.
# /tmp/ipykernel_106335/3564220722.py:124: RuntimeWarning: overflow encountered in multiply
#   test_features[1 + d_linear :] = z[r_idx] * z[c_idx]
# /tmp/ipykernel_106335/3564220722.py:126: RuntimeWarning: invalid value encountered in matmul
#   delta_pred = W_out @ test_features
# /tmp/ipykernel_106335/3564220722.py:134: RuntimeWarning: overflow encountered in square
#   mse = np.mean((truth - prediction) ** 2)
# Trial 002 | k = 40 | ridge =   4.01e-06 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:42:40,383] Trial 2 failed with parameters: {'k': 40, 'ridge': 4.006230508002568e-06} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:42:40,383] Trial 2 failed with value nan.
# Trial 003 | k = 5  | ridge =   7.62e+05 | MSE = 1747.864899 | MAE = 33.471602 | RMSE = 38.966621
# [I 2026-07-26 21:42:40,823] Trial 3 finished with value: 38.966621320485324 and parameters: {'k': 5, 'ridge': 761517.1767224498}. Best is trial 0 with value: 32.713181709519695.
# Trial 004 | k = 50 | ridge =   1.29e-02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:42:42,179] Trial 4 failed with parameters: {'k': 50, 'ridge': 0.012862009967543995} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:42:42,180] Trial 4 failed with value nan.
# Trial 005 | k = 2  | ridge =   2.65e-03 | MSE = 1713.506786 | MAE = 33.412034 | RMSE = 39.014408
# [I 2026-07-26 21:42:42,559] Trial 5 finished with value: 39.01440797552234 and parameters: {'k': 2, 'ridge': 0.0026483767982816643}. Best is trial 0 with value: 32.713181709519695.
# Trial 006 | k = 20 | ridge =   1.56e+05 | MSE = 1036.970205 | MAE = 23.606986 | RMSE = 27.822912
# [I 2026-07-26 21:42:43,276] Trial 6 finished with value: 27.822912435292995 and parameters: {'k': 20, 'ridge': 155708.54671269728}. Best is trial 6 with value: 27.822912435292995.
# Trial 007 | k = 2  | ridge =   6.47e+05 | MSE = 1916.187318 | MAE = 35.373339 | RMSE = 41.338978
# [I 2026-07-26 21:42:43,661] Trial 7 finished with value: 41.33897762434899 and parameters: {'k': 2, 'ridge': 647231.5631352852}. Best is trial 6 with value: 27.822912435292995.
# Trial 008 | k = 5  | ridge =   9.54e-03 | MSE = 1522.614465 | MAE = 30.892167 | RMSE = 36.128841
# [I 2026-07-26 21:42:44,084] Trial 8 finished with value: 36.12884142692734 and parameters: {'k': 5, 'ridge': 0.00953915916793728}. Best is trial 6 with value: 27.822912435292995.
# Trial 009 | k = 40 | ridge =   1.27e-04 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:42:45,209] Trial 9 failed with parameters: {'k': 40, 'ridge': 0.00012705363801063493} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:42:45,209] Trial 9 failed with value nan.
# Trial 010 | k = 2  | ridge =   5.80e-06 | MSE = 1713.506712 | MAE = 33.412034 | RMSE = 39.014408
# [I 2026-07-26 21:42:45,598] Trial 10 finished with value: 39.01440772324734 and parameters: {'k': 2, 'ridge': 5.798214493433132e-06}. Best is trial 6 with value: 27.822912435292995.
# Trial 011 | k = 30 | ridge =   4.20e-06 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:42:46,515] Trial 11 failed with parameters: {'k': 30, 'ridge': 4.201261270629809e-06} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:42:46,516] Trial 11 failed with value nan.
# Trial 012 | k = 50 | ridge =   1.47e-05 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:42:48,737] Trial 12 failed with parameters: {'k': 50, 'ridge': 1.469990055727916e-05} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:42:48,738] Trial 12 failed with value nan.
# Trial 013 | k = 5  | ridge =   1.04e+04 | MSE = 1592.329269 | MAE = 31.451417 | RMSE = 36.687800
# [I 2026-07-26 21:42:49,161] Trial 13 finished with value: 36.687800096042324 and parameters: {'k': 5, 'ridge': 10436.458285315375}. Best is trial 6 with value: 27.822912435292995.
# Trial 014 | k = 50 | ridge =   3.99e-06 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:42:50,829] Trial 14 failed with parameters: {'k': 50, 'ridge': 3.986582558612395e-06} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:42:50,830] Trial 14 failed with value nan.
# Trial 015 | k = 30 | ridge =   2.69e-03 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:42:51,745] Trial 15 failed with parameters: {'k': 30, 'ridge': 0.0026866767222803105} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:42:51,746] Trial 15 failed with value nan.
# Trial 016 | k = 5  | ridge =   3.12e+05 | MSE = 1719.386827 | MAE = 33.107252 | RMSE = 38.516833
# [I 2026-07-26 21:42:52,170] Trial 16 finished with value: 38.516833054040426 and parameters: {'k': 5, 'ridge': 311845.0077260742}. Best is trial 6 with value: 27.822912435292995.
# Trial 017 | k = 20 | ridge =   1.84e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:42:52,922] Trial 17 failed with parameters: {'k': 20, 'ridge': 183.5697300798617} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:42:52,923] Trial 17 failed with value nan.
# Trial 018 | k = 20 | ridge =   1.34e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:42:53,645] Trial 18 failed with parameters: {'k': 20, 'ridge': 133.64849353561743} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:42:53,646] Trial 18 failed with value nan.
# Trial 019 | k = 20 | ridge =   1.70e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:42:54,368] Trial 19 failed with parameters: {'k': 20, 'ridge': 170.04698771738938} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:42:54,369] Trial 19 failed with value nan.
# Trial 020 | k = 20 | ridge =   2.35e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:42:55,091] Trial 20 failed with parameters: {'k': 20, 'ridge': 234.88156011865297} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:42:55,091] Trial 20 failed with value nan.
# Trial 021 | k = 20 | ridge =   4.93e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:42:55,811] Trial 21 failed with parameters: {'k': 20, 'ridge': 492.92827678863483} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:42:55,812] Trial 21 failed with value nan.
# Trial 022 | k = 20 | ridge =   1.54e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:42:56,537] Trial 22 failed with parameters: {'k': 20, 'ridge': 154.16657547467807} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:42:56,538] Trial 22 failed with value nan.
# Trial 023 | k = 20 | ridge =   1.52e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:42:57,258] Trial 23 failed with parameters: {'k': 20, 'ridge': 152.18522049549074} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:42:57,258] Trial 23 failed with value nan.
# Trial 024 | k = 20 | ridge =   1.38e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:42:57,991] Trial 24 failed with parameters: {'k': 20, 'ridge': 137.86674376718506} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:42:57,992] Trial 24 failed with value nan.
# Trial 025 | k = 20 | ridge =   1.91e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:42:58,719] Trial 25 failed with parameters: {'k': 20, 'ridge': 191.33408886881193} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:42:58,720] Trial 25 failed with value nan.
# Trial 026 | k = 20 | ridge =   1.99e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:42:59,444] Trial 26 failed with parameters: {'k': 20, 'ridge': 198.85433019398175} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:42:59,444] Trial 26 failed with value nan.
# Trial 027 | k = 20 | ridge =   1.59e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:00,166] Trial 27 failed with parameters: {'k': 20, 'ridge': 159.025715136382} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:00,166] Trial 27 failed with value nan.
# Trial 028 | k = 20 | ridge =   1.12e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:00,892] Trial 28 failed with parameters: {'k': 20, 'ridge': 112.05266166886415} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:00,892] Trial 28 failed with value nan.
# Trial 029 | k = 20 | ridge =   1.25e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:01,623] Trial 29 failed with parameters: {'k': 20, 'ridge': 124.58411601217635} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:01,623] Trial 29 failed with value nan.
# Trial 030 | k = 20 | ridge =   1.27e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:02,376] Trial 30 failed with parameters: {'k': 20, 'ridge': 126.61625988804565} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:02,377] Trial 30 failed with value nan.
# Trial 031 | k = 20 | ridge =   1.67e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:03,099] Trial 31 failed with parameters: {'k': 20, 'ridge': 166.60569093006464} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:03,100] Trial 31 failed with value nan.
# Trial 032 | k = 20 | ridge =   1.77e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:03,823] Trial 32 failed with parameters: {'k': 20, 'ridge': 177.27584250680096} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:03,824] Trial 32 failed with value nan.
# Trial 033 | k = 20 | ridge =   2.07e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:04,545] Trial 33 failed with parameters: {'k': 20, 'ridge': 207.43248431262964} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:04,546] Trial 33 failed with value nan.
# Trial 034 | k = 20 | ridge =   9.92e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:05,268] Trial 34 failed with parameters: {'k': 20, 'ridge': 99.15763623860558} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:05,268] Trial 34 failed with value nan.
# Trial 035 | k = 20 | ridge =   7.41e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:05,992] Trial 35 failed with parameters: {'k': 20, 'ridge': 74.0872095501175} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:05,993] Trial 35 failed with value nan.
# Trial 036 | k = 20 | ridge =   1.93e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:06,713] Trial 36 failed with parameters: {'k': 20, 'ridge': 192.6912882894001} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:06,714] Trial 36 failed with value nan.
# Trial 037 | k = 20 | ridge =   1.90e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:07,438] Trial 37 failed with parameters: {'k': 20, 'ridge': 190.17219880129758} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:07,439] Trial 37 failed with value nan.
# Trial 038 | k = 20 | ridge =   1.81e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:08,161] Trial 38 failed with parameters: {'k': 20, 'ridge': 181.4594749438788} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:08,162] Trial 38 failed with value nan.
# Trial 039 | k = 20 | ridge =   7.54e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:08,886] Trial 39 failed with parameters: {'k': 20, 'ridge': 75.44780120835922} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:08,887] Trial 39 failed with value nan.
# Trial 040 | k = 20 | ridge =   1.38e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:09,621] Trial 40 failed with parameters: {'k': 20, 'ridge': 138.27186268058577} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:09,622] Trial 40 failed with value nan.
# Trial 041 | k = 20 | ridge =   1.36e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:10,345] Trial 41 failed with parameters: {'k': 20, 'ridge': 136.03082393812076} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:10,346] Trial 41 failed with value nan.
# Trial 042 | k = 20 | ridge =   1.43e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:11,088] Trial 42 failed with parameters: {'k': 20, 'ridge': 143.43639521327765} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:11,089] Trial 42 failed with value nan.
# Trial 043 | k = 20 | ridge =   9.74e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:11,833] Trial 43 failed with parameters: {'k': 20, 'ridge': 97.35518203791179} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:11,834] Trial 43 failed with value nan.
# Trial 044 | k = 20 | ridge =   1.10e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:12,559] Trial 44 failed with parameters: {'k': 20, 'ridge': 109.53495236900685} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:12,559] Trial 44 failed with value nan.
# Trial 045 | k = 20 | ridge =   1.43e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:13,282] Trial 45 failed with parameters: {'k': 20, 'ridge': 142.72097630112066} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:13,283] Trial 45 failed with value nan.
# Trial 046 | k = 20 | ridge =   1.47e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:14,036] Trial 46 failed with parameters: {'k': 20, 'ridge': 146.65188709296936} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:14,037] Trial 46 failed with value nan.
# Trial 047 | k = 20 | ridge =   8.98e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:14,760] Trial 47 failed with parameters: {'k': 20, 'ridge': 89.81778291019448} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:14,760] Trial 47 failed with value nan.
# Trial 048 | k = 20 | ridge =   1.97e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:15,481] Trial 48 failed with parameters: {'k': 20, 'ridge': 197.08777266462369} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:15,482] Trial 48 failed with value nan.
# Trial 049 | k = 20 | ridge =   1.25e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:16,205] Trial 49 failed with parameters: {'k': 20, 'ridge': 125.1989655592741} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:16,206] Trial 49 failed with value nan.
# Trial 050 | k = 20 | ridge =   2.34e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:16,928] Trial 50 failed with parameters: {'k': 20, 'ridge': 234.21930971914972} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:16,930] Trial 50 failed with value nan.
# Trial 051 | k = 20 | ridge =   8.85e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:17,655] Trial 51 failed with parameters: {'k': 20, 'ridge': 88.49499680289198} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:17,656] Trial 51 failed with value nan.
# Trial 052 | k = 20 | ridge =   2.03e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:18,383] Trial 52 failed with parameters: {'k': 20, 'ridge': 20.250291889363776} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:18,384] Trial 52 failed with value nan.
# Trial 053 | k = 20 | ridge =   6.28e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:19,112] Trial 53 failed with parameters: {'k': 20, 'ridge': 62.802687465573214} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:19,113] Trial 53 failed with value nan.
# Trial 054 | k = 20 | ridge =   8.74e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:19,837] Trial 54 failed with parameters: {'k': 20, 'ridge': 87.36020100554327} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:19,838] Trial 54 failed with value nan.
# Trial 055 | k = 20 | ridge =   1.40e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:20,567] Trial 55 failed with parameters: {'k': 20, 'ridge': 139.77426586820263} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:20,568] Trial 55 failed with value nan.
# Trial 056 | k = 20 | ridge =   3.09e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:21,289] Trial 56 failed with parameters: {'k': 20, 'ridge': 309.4572535592932} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:21,290] Trial 56 failed with value nan.
# Trial 057 | k = 20 | ridge =   4.06e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:22,037] Trial 57 failed with parameters: {'k': 20, 'ridge': 40.616683381188835} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:22,038] Trial 57 failed with value nan.
# Trial 058 | k = 20 | ridge =   1.13e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:22,762] Trial 58 failed with parameters: {'k': 20, 'ridge': 112.69438139437419} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:22,763] Trial 58 failed with value nan.
# Trial 059 | k = 20 | ridge =   1.41e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:23,485] Trial 59 failed with parameters: {'k': 20, 'ridge': 141.15877349091198} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:23,486] Trial 59 failed with value nan.
# Trial 060 | k = 20 | ridge =   2.44e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:24,209] Trial 60 failed with parameters: {'k': 20, 'ridge': 244.2429272666633} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:24,210] Trial 60 failed with value nan.
# Trial 061 | k = 20 | ridge =   2.34e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:24,930] Trial 61 failed with parameters: {'k': 20, 'ridge': 233.8418341002416} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:24,931] Trial 61 failed with value nan.
# Trial 062 | k = 20 | ridge =   3.18e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:25,653] Trial 62 failed with parameters: {'k': 20, 'ridge': 317.95851738221825} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:25,654] Trial 62 failed with value nan.
# Trial 063 | k = 20 | ridge =   3.21e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:26,404] Trial 63 failed with parameters: {'k': 20, 'ridge': 321.05581449421555} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:26,405] Trial 63 failed with value nan.
# Trial 064 | k = 20 | ridge =   2.17e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:27,127] Trial 64 failed with parameters: {'k': 20, 'ridge': 217.02475836149077} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:27,128] Trial 64 failed with value nan.
# Trial 065 | k = 20 | ridge =   2.52e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:27,850] Trial 65 failed with parameters: {'k': 20, 'ridge': 251.559628457554} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:27,851] Trial 65 failed with value nan.
# Trial 066 | k = 20 | ridge =   1.78e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:28,570] Trial 66 failed with parameters: {'k': 20, 'ridge': 178.14183218178778} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:28,570] Trial 66 failed with value nan.
# Trial 067 | k = 20 | ridge =   1.06e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:29,292] Trial 67 failed with parameters: {'k': 20, 'ridge': 106.43240369006836} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:29,293] Trial 67 failed with value nan.
# Trial 068 | k = 20 | ridge =   2.99e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:30,012] Trial 68 failed with parameters: {'k': 20, 'ridge': 299.48026021423567} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:30,012] Trial 68 failed with value nan.
# Trial 069 | k = 20 | ridge =   9.33e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:30,738] Trial 69 failed with parameters: {'k': 20, 'ridge': 93.27050789964882} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:30,739] Trial 69 failed with value nan.
# Trial 070 | k = 20 | ridge =   2.46e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:31,459] Trial 70 failed with parameters: {'k': 20, 'ridge': 246.38123098490428} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:31,460] Trial 70 failed with value nan.
# Trial 071 | k = 20 | ridge =   7.62e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:32,190] Trial 71 failed with parameters: {'k': 20, 'ridge': 76.23581522145167} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:32,191] Trial 71 failed with value nan.
# Trial 072 | k = 20 | ridge =   1.73e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:32,909] Trial 72 failed with parameters: {'k': 20, 'ridge': 173.0754528780966} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:32,910] Trial 72 failed with value nan.
# Trial 073 | k = 20 | ridge =   2.60e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:33,628] Trial 73 failed with parameters: {'k': 20, 'ridge': 259.78281461048493} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:33,629] Trial 73 failed with value nan.
# Trial 074 | k = 20 | ridge =   4.34e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:34,349] Trial 74 failed with parameters: {'k': 20, 'ridge': 434.18113236134343} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:34,349] Trial 74 failed with value nan.
# Trial 075 | k = 20 | ridge =   1.81e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:35,080] Trial 75 failed with parameters: {'k': 20, 'ridge': 180.9557235928627} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:35,081] Trial 75 failed with value nan.
# Trial 076 | k = 20 | ridge =   1.16e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:35,802] Trial 76 failed with parameters: {'k': 20, 'ridge': 116.35657813999518} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:35,803] Trial 76 failed with value nan.
# Trial 077 | k = 20 | ridge =   2.45e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:36,523] Trial 77 failed with parameters: {'k': 20, 'ridge': 245.1332181410584} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:36,523] Trial 77 failed with value nan.
# Trial 078 | k = 20 | ridge =   2.62e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:37,247] Trial 78 failed with parameters: {'k': 20, 'ridge': 262.06131128730703} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:37,247] Trial 78 failed with value nan.
# Trial 079 | k = 20 | ridge =   5.37e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:37,970] Trial 79 failed with parameters: {'k': 20, 'ridge': 53.72550134450467} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:37,971] Trial 79 failed with value nan.
# Trial 080 | k = 20 | ridge =   1.97e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:38,707] Trial 80 failed with parameters: {'k': 20, 'ridge': 196.80368932628738} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:38,707] Trial 80 failed with value nan.
# Trial 081 | k = 20 | ridge =   1.21e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:39,428] Trial 81 failed with parameters: {'k': 20, 'ridge': 120.75617820721628} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:39,429] Trial 81 failed with value nan.
# Trial 082 | k = 20 | ridge =   2.06e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:40,151] Trial 82 failed with parameters: {'k': 20, 'ridge': 205.88458068428224} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:40,151] Trial 82 failed with value nan.
# Trial 083 | k = 20 | ridge =   1.21e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:40,901] Trial 83 failed with parameters: {'k': 20, 'ridge': 120.85933811879876} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:40,901] Trial 83 failed with value nan.
# Trial 084 | k = 20 | ridge =   1.83e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:41,623] Trial 84 failed with parameters: {'k': 20, 'ridge': 182.8036023046942} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:41,623] Trial 84 failed with value nan.
# Trial 085 | k = 20 | ridge =   3.29e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:42,362] Trial 85 failed with parameters: {'k': 20, 'ridge': 329.0003083823712} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:42,363] Trial 85 failed with value nan.
# Trial 086 | k = 20 | ridge =   9.36e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:43,084] Trial 86 failed with parameters: {'k': 20, 'ridge': 93.5694032059276} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:43,084] Trial 86 failed with value nan.
# Trial 087 | k = 20 | ridge =   2.16e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:43,806] Trial 87 failed with parameters: {'k': 20, 'ridge': 215.6213137266508} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:43,807] Trial 87 failed with value nan.
# Trial 088 | k = 20 | ridge =   9.90e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:44,529] Trial 88 failed with parameters: {'k': 20, 'ridge': 98.96573235248944} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:44,530] Trial 88 failed with value nan.
# Trial 089 | k = 20 | ridge =   1.62e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:45,252] Trial 89 failed with parameters: {'k': 20, 'ridge': 162.06549908014782} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:45,252] Trial 89 failed with value nan.
# Trial 090 | k = 20 | ridge =   9.83e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:45,972] Trial 90 failed with parameters: {'k': 20, 'ridge': 98.31965568643326} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:45,973] Trial 90 failed with value nan.
# Trial 091 | k = 20 | ridge =   3.77e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:46,698] Trial 91 failed with parameters: {'k': 20, 'ridge': 37.66883812427526} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:46,699] Trial 91 failed with value nan.
# Trial 092 | k = 20 | ridge =   6.33e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:47,420] Trial 92 failed with parameters: {'k': 20, 'ridge': 633.3711899554945} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:47,420] Trial 92 failed with value nan.
# Trial 093 | k = 20 | ridge =   2.66e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:48,142] Trial 93 failed with parameters: {'k': 20, 'ridge': 266.42224542461196} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:48,142] Trial 93 failed with value nan.
# Trial 094 | k = 20 | ridge =   7.65e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:48,864] Trial 94 failed with parameters: {'k': 20, 'ridge': 76.51630400673406} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:48,865] Trial 94 failed with value nan.
# Trial 095 | k = 20 | ridge =   1.32e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:49,590] Trial 95 failed with parameters: {'k': 20, 'ridge': 131.53911832438703} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:49,591] Trial 95 failed with value nan.
# Trial 096 | k = 20 | ridge =   7.76e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:50,313] Trial 96 failed with parameters: {'k': 20, 'ridge': 77.59337523256306} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:50,314] Trial 96 failed with value nan.
# Trial 097 | k = 20 | ridge =   4.72e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:51,035] Trial 97 failed with parameters: {'k': 20, 'ridge': 47.206523767236725} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:51,036] Trial 97 failed with value nan.
# Trial 098 | k = 20 | ridge =   2.85e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:51,754] Trial 98 failed with parameters: {'k': 20, 'ridge': 284.8393184901104} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:51,755] Trial 98 failed with value nan.
# Trial 099 | k = 20 | ridge =   7.57e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:52,485] Trial 99 failed with parameters: {'k': 20, 'ridge': 75.67495972530736} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:52,486] Trial 99 failed with value nan.
# Trial 100 | k = 20 | ridge =   3.59e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:53,218] Trial 100 failed with parameters: {'k': 20, 'ridge': 35.864389392810416} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:53,218] Trial 100 failed with value nan.
# Trial 101 | k = 20 | ridge =   1.99e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:53,940] Trial 101 failed with parameters: {'k': 20, 'ridge': 19.89914840559665} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:53,941] Trial 101 failed with value nan.
# Trial 102 | k = 20 | ridge =   1.50e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:54,663] Trial 102 failed with parameters: {'k': 20, 'ridge': 150.3311070548529} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:54,664] Trial 102 failed with value nan.
# Trial 103 | k = 20 | ridge =   1.17e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:55,385] Trial 103 failed with parameters: {'k': 20, 'ridge': 117.30955040356868} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:55,386] Trial 103 failed with value nan.
# Trial 104 | k = 20 | ridge =   1.30e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:56,108] Trial 104 failed with parameters: {'k': 20, 'ridge': 130.33862970847028} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:56,108] Trial 104 failed with value nan.
# Trial 105 | k = 20 | ridge =   1.64e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:56,828] Trial 105 failed with parameters: {'k': 20, 'ridge': 164.44254018456746} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:56,829] Trial 105 failed with value nan.
# Trial 106 | k = 20 | ridge =   1.43e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:57,549] Trial 106 failed with parameters: {'k': 20, 'ridge': 142.99927452071404} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:57,550] Trial 106 failed with value nan.
# Trial 107 | k = 20 | ridge =   7.52e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:58,272] Trial 107 failed with parameters: {'k': 20, 'ridge': 75.16589559597185} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:58,272] Trial 107 failed with value nan.
# Trial 108 | k = 20 | ridge =   2.12e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:58,992] Trial 108 failed with parameters: {'k': 20, 'ridge': 211.86295734231877} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:58,993] Trial 108 failed with value nan.
# Trial 109 | k = 20 | ridge =   3.37e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:43:59,713] Trial 109 failed with parameters: {'k': 20, 'ridge': 337.0225546520569} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:43:59,714] Trial 109 failed with value nan.
# Trial 110 | k = 20 | ridge =   2.29e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:00,437] Trial 110 failed with parameters: {'k': 20, 'ridge': 228.75537735687215} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:00,438] Trial 110 failed with value nan.
# Trial 111 | k = 20 | ridge =   2.14e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:01,160] Trial 111 failed with parameters: {'k': 20, 'ridge': 213.7830789646669} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:01,160] Trial 111 failed with value nan.
# Trial 112 | k = 20 | ridge =   2.89e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:01,879] Trial 112 failed with parameters: {'k': 20, 'ridge': 289.4518379240692} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:01,880] Trial 112 failed with value nan.
# Trial 113 | k = 20 | ridge =   5.51e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:02,607] Trial 113 failed with parameters: {'k': 20, 'ridge': 550.5828256081389} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:02,608] Trial 113 failed with value nan.
# Trial 114 | k = 20 | ridge =   1.89e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:03,329] Trial 114 failed with parameters: {'k': 20, 'ridge': 189.47061420441057} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:03,330] Trial 114 failed with value nan.
# Trial 115 | k = 20 | ridge =   1.74e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:04,049] Trial 115 failed with parameters: {'k': 20, 'ridge': 173.58116411268063} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:04,050] Trial 115 failed with value nan.
# Trial 116 | k = 20 | ridge =   1.10e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:04,771] Trial 116 failed with parameters: {'k': 20, 'ridge': 110.45648583519564} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:04,772] Trial 116 failed with value nan.
# Trial 117 | k = 20 | ridge =   9.45e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:05,493] Trial 117 failed with parameters: {'k': 20, 'ridge': 94.49078154471351} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:05,494] Trial 117 failed with value nan.
# Trial 118 | k = 20 | ridge =   6.66e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:06,214] Trial 118 failed with parameters: {'k': 20, 'ridge': 665.9632683857276} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:06,214] Trial 118 failed with value nan.
# Trial 119 | k = 20 | ridge =   1.79e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:06,935] Trial 119 failed with parameters: {'k': 20, 'ridge': 179.33727388419075} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:06,935] Trial 119 failed with value nan.
# Trial 120 | k = 20 | ridge =   7.03e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:07,656] Trial 120 failed with parameters: {'k': 20, 'ridge': 703.2736096881489} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:07,656] Trial 120 failed with value nan.
# Trial 121 | k = 20 | ridge =   1.53e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:08,380] Trial 121 failed with parameters: {'k': 20, 'ridge': 152.76335946470306} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:08,381] Trial 121 failed with value nan.
# Trial 122 | k = 20 | ridge =   2.42e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:09,111] Trial 122 failed with parameters: {'k': 20, 'ridge': 241.6898021842996} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:09,112] Trial 122 failed with value nan.
# Trial 123 | k = 20 | ridge =   1.34e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:09,835] Trial 123 failed with parameters: {'k': 20, 'ridge': 134.2431351812374} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:09,836] Trial 123 failed with value nan.
# Trial 124 | k = 20 | ridge =   2.72e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:10,557] Trial 124 failed with parameters: {'k': 20, 'ridge': 27.167983296462516} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:10,558] Trial 124 failed with value nan.
# Trial 125 | k = 20 | ridge =   7.05e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:11,300] Trial 125 failed with parameters: {'k': 20, 'ridge': 705.2524923642472} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:11,301] Trial 125 failed with value nan.
# Trial 126 | k = 20 | ridge =   2.64e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:12,024] Trial 126 failed with parameters: {'k': 20, 'ridge': 264.1779857899052} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:12,025] Trial 126 failed with value nan.
# Trial 127 | k = 20 | ridge =   6.40e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:12,759] Trial 127 failed with parameters: {'k': 20, 'ridge': 64.00429800783155} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:12,760] Trial 127 failed with value nan.
# Trial 128 | k = 20 | ridge =   2.35e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:13,481] Trial 128 failed with parameters: {'k': 20, 'ridge': 234.55450557107721} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:13,482] Trial 128 failed with value nan.
# Trial 129 | k = 20 | ridge =   4.18e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:14,205] Trial 129 failed with parameters: {'k': 20, 'ridge': 41.83665863504965} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:14,205] Trial 129 failed with value nan.
# Trial 130 | k = 20 | ridge =   1.01e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:14,925] Trial 130 failed with parameters: {'k': 20, 'ridge': 100.74714806472534} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:14,926] Trial 130 failed with value nan.
# Trial 131 | k = 20 | ridge =   1.06e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:15,649] Trial 131 failed with parameters: {'k': 20, 'ridge': 105.64987942819614} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:15,650] Trial 131 failed with value nan.
# Trial 132 | k = 20 | ridge =   1.52e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:16,373] Trial 132 failed with parameters: {'k': 20, 'ridge': 152.1047606758671} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:16,374] Trial 132 failed with value nan.
# Trial 133 | k = 20 | ridge =   2.17e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:17,095] Trial 133 failed with parameters: {'k': 20, 'ridge': 217.15503445091494} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:17,095] Trial 133 failed with value nan.
# Trial 134 | k = 20 | ridge =   2.11e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:17,817] Trial 134 failed with parameters: {'k': 20, 'ridge': 210.78569847307523} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:17,817] Trial 134 failed with value nan.
# Trial 135 | k = 20 | ridge =   1.95e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:18,540] Trial 135 failed with parameters: {'k': 20, 'ridge': 194.93155376660215} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:18,540] Trial 135 failed with value nan.
# Trial 136 | k = 20 | ridge =   6.18e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:19,261] Trial 136 failed with parameters: {'k': 20, 'ridge': 61.77091589669612} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:19,262] Trial 136 failed with value nan.
# Trial 137 | k = 20 | ridge =   4.77e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:19,982] Trial 137 failed with parameters: {'k': 20, 'ridge': 477.0398438942282} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:19,983] Trial 137 failed with value nan.
# Trial 138 | k = 20 | ridge =   9.53e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:20,704] Trial 138 failed with parameters: {'k': 20, 'ridge': 95.27502168947827} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:20,705] Trial 138 failed with value nan.
# Trial 139 | k = 20 | ridge =   1.38e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:21,425] Trial 139 failed with parameters: {'k': 20, 'ridge': 137.70015421101795} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:21,426] Trial 139 failed with value nan.
# Trial 140 | k = 20 | ridge =   6.61e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:22,149] Trial 140 failed with parameters: {'k': 20, 'ridge': 66.13716019680611} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:22,150] Trial 140 failed with value nan.
# Trial 141 | k = 20 | ridge =   2.06e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:22,876] Trial 141 failed with parameters: {'k': 20, 'ridge': 205.57759214356153} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:22,876] Trial 141 failed with value nan.
# Trial 142 | k = 20 | ridge =   3.67e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:23,609] Trial 142 failed with parameters: {'k': 20, 'ridge': 367.02632324291125} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:23,610] Trial 142 failed with value nan.
# Trial 143 | k = 20 | ridge =   9.72e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:24,333] Trial 143 failed with parameters: {'k': 20, 'ridge': 97.19423581699654} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:24,334] Trial 143 failed with value nan.
# Trial 144 | k = 20 | ridge =   1.76e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:25,052] Trial 144 failed with parameters: {'k': 20, 'ridge': 176.09276715636554} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:25,053] Trial 144 failed with value nan.
# Trial 145 | k = 20 | ridge =   7.24e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:25,777] Trial 145 failed with parameters: {'k': 20, 'ridge': 72.4049454444676} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:25,778] Trial 145 failed with value nan.
# Trial 146 | k = 20 | ridge =   1.48e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:26,499] Trial 146 failed with parameters: {'k': 20, 'ridge': 148.09010381278927} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:26,500] Trial 146 failed with value nan.
# Trial 147 | k = 20 | ridge =   2.83e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:27,219] Trial 147 failed with parameters: {'k': 20, 'ridge': 283.1225541522296} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:27,220] Trial 147 failed with value nan.
# Trial 148 | k = 20 | ridge =   9.23e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:27,940] Trial 148 failed with parameters: {'k': 20, 'ridge': 92.27535962624091} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:27,941] Trial 148 failed with value nan.
# Trial 149 | k = 20 | ridge =   1.77e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:28,663] Trial 149 failed with parameters: {'k': 20, 'ridge': 176.60839822779175} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:28,664] Trial 149 failed with value nan.
# Trial 150 | k = 20 | ridge =   1.47e+03 | MSE = 2115.967891 | MAE = 30.491207 | RMSE = 37.405351
# [I 2026-07-26 21:44:29,381] Trial 150 finished with value: 37.40535055767616 and parameters: {'k': 20, 'ridge': 1466.1442868681181}. Best is trial 6 with value: 27.822912435292995.
# Trial 151 | k = 10 | ridge =   5.51e+00 | MSE = 1246.794947 | MAE = 27.636613 | RMSE = 32.711402
# [I 2026-07-26 21:44:29,892] Trial 151 finished with value: 32.711402230097406 and parameters: {'k': 10, 'ridge': 5.508414966720798}. Best is trial 6 with value: 27.822912435292995.
# Trial 152 | k = 30 | ridge =   2.41e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:30,788] Trial 152 failed with parameters: {'k': 30, 'ridge': 24.14971254246651} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:30,789] Trial 152 failed with value nan.
# Trial 153 | k = 40 | ridge =   1.24e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:31,897] Trial 153 failed with parameters: {'k': 40, 'ridge': 124.17386655843394} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:31,898] Trial 153 failed with value nan.
# Trial 154 | k = 30 | ridge =   2.00e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:32,808] Trial 154 failed with parameters: {'k': 30, 'ridge': 199.6196946284375} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:32,809] Trial 154 failed with value nan.
# Trial 155 | k = 50 | ridge =   3.51e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:34,242] Trial 155 failed with parameters: {'k': 50, 'ridge': 35.07968280395901} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:34,243] Trial 155 failed with value nan.
# Trial 156 | k = 40 | ridge =   5.13e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:35,361] Trial 156 failed with parameters: {'k': 40, 'ridge': 51.345742022025526} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:35,362] Trial 156 failed with value nan.
# Trial 157 | k = 40 | ridge =   1.14e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:36,478] Trial 157 failed with parameters: {'k': 40, 'ridge': 114.20708786174426} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:36,479] Trial 157 failed with value nan.
# Trial 158 | k = 40 | ridge =   2.41e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:37,594] Trial 158 failed with parameters: {'k': 40, 'ridge': 24.052939415869997} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:37,595] Trial 158 failed with value nan.
# Trial 159 | k = 30 | ridge =   4.78e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:38,493] Trial 159 failed with parameters: {'k': 30, 'ridge': 47.79823411480824} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:38,494] Trial 159 failed with value nan.
# Trial 160 | k = 40 | ridge =   4.77e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:39,601] Trial 160 failed with parameters: {'k': 40, 'ridge': 47.698399405085716} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:39,602] Trial 160 failed with value nan.
# Trial 161 | k = 50 | ridge =   2.34e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:40,964] Trial 161 failed with parameters: {'k': 50, 'ridge': 23.380964818089893} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:40,965] Trial 161 failed with value nan.
# Trial 162 | k = 50 | ridge =   7.27e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:42,319] Trial 162 failed with parameters: {'k': 50, 'ridge': 72.70835539219476} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:42,320] Trial 162 failed with value nan.
# Trial 163 | k = 40 | ridge =   3.20e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:43,444] Trial 163 failed with parameters: {'k': 40, 'ridge': 31.964974136605964} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:43,445] Trial 163 failed with value nan.
# Trial 164 | k = 40 | ridge =   5.55e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:44,558] Trial 164 failed with parameters: {'k': 40, 'ridge': 55.54386317299705} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:44,559] Trial 164 failed with value nan.
# Trial 165 | k = 30 | ridge =   3.99e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:45,458] Trial 165 failed with parameters: {'k': 30, 'ridge': 39.920592222076} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:45,459] Trial 165 failed with value nan.
# Trial 166 | k = 40 | ridge =   6.09e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:46,568] Trial 166 failed with parameters: {'k': 40, 'ridge': 60.941235483263654} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:46,569] Trial 166 failed with value nan.
# Trial 167 | k = 50 | ridge =   4.52e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:47,929] Trial 167 failed with parameters: {'k': 50, 'ridge': 45.20216845685248} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:47,930] Trial 167 failed with value nan.
# Trial 168 | k = 50 | ridge =   4.70e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:49,284] Trial 168 failed with parameters: {'k': 50, 'ridge': 46.97815490318226} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:49,285] Trial 168 failed with value nan.
# Trial 169 | k = 50 | ridge =   4.96e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:50,646] Trial 169 failed with parameters: {'k': 50, 'ridge': 49.63947425181992} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:50,647] Trial 169 failed with value nan.
# Trial 170 | k = 30 | ridge =   5.42e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:51,546] Trial 170 failed with parameters: {'k': 30, 'ridge': 54.190511280261624} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:51,547] Trial 170 failed with value nan.
# Trial 171 | k = 30 | ridge =   6.19e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:52,444] Trial 171 failed with parameters: {'k': 30, 'ridge': 61.869512609898194} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:52,444] Trial 171 failed with value nan.
# Trial 172 | k = 30 | ridge =   4.08e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:53,368] Trial 172 failed with parameters: {'k': 30, 'ridge': 40.78632450176591} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:53,369] Trial 172 failed with value nan.
# Trial 173 | k = 40 | ridge =   9.22e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:54,482] Trial 173 failed with parameters: {'k': 40, 'ridge': 92.17441196508925} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:54,483] Trial 173 failed with value nan.
# Trial 174 | k = 50 | ridge =   2.97e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:55,838] Trial 174 failed with parameters: {'k': 50, 'ridge': 29.69681827833219} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:55,839] Trial 174 failed with value nan.
# Trial 175 | k = 50 | ridge =   5.48e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:57,191] Trial 175 failed with parameters: {'k': 50, 'ridge': 54.80577791169343} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:57,192] Trial 175 failed with value nan.
# Trial 176 | k = 40 | ridge =   2.78e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:58,315] Trial 176 failed with parameters: {'k': 40, 'ridge': 27.778236440451483} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:58,316] Trial 176 failed with value nan.
# Trial 177 | k = 50 | ridge =   1.01e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:44:59,673] Trial 177 failed with parameters: {'k': 50, 'ridge': 100.74903176407918} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:44:59,674] Trial 177 failed with value nan.
# Trial 178 | k = 50 | ridge =   1.54e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:01,030] Trial 178 failed with parameters: {'k': 50, 'ridge': 15.44076172125797} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:01,031] Trial 178 failed with value nan.
# Trial 179 | k = 40 | ridge =   2.73e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:02,153] Trial 179 failed with parameters: {'k': 40, 'ridge': 27.273213727974742} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:02,153] Trial 179 failed with value nan.
# Trial 180 | k = 40 | ridge =   2.82e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:03,282] Trial 180 failed with parameters: {'k': 40, 'ridge': 28.15338409547076} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:03,283] Trial 180 failed with value nan.
# Trial 181 | k = 50 | ridge =   1.52e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:04,641] Trial 181 failed with parameters: {'k': 50, 'ridge': 151.67086722869172} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:04,642] Trial 181 failed with value nan.
# Trial 182 | k = 50 | ridge =   4.03e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:06,096] Trial 182 failed with parameters: {'k': 50, 'ridge': 40.30290976088798} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:06,097] Trial 182 failed with value nan.
# Trial 183 | k = 40 | ridge =   2.34e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:07,307] Trial 183 failed with parameters: {'k': 40, 'ridge': 23.390084954359622} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:07,308] Trial 183 failed with value nan.
# Trial 184 | k = 40 | ridge =   5.04e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:08,556] Trial 184 failed with parameters: {'k': 40, 'ridge': 50.37362513935602} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:08,557] Trial 184 failed with value nan.
# Trial 185 | k = 50 | ridge =   1.22e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:10,011] Trial 185 failed with parameters: {'k': 50, 'ridge': 122.34906433061605} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:10,012] Trial 185 failed with value nan.
# Trial 186 | k = 40 | ridge =   3.27e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:11,219] Trial 186 failed with parameters: {'k': 40, 'ridge': 32.65948578780895} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:11,220] Trial 186 failed with value nan.
# Trial 187 | k = 50 | ridge =   6.19e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:12,704] Trial 187 failed with parameters: {'k': 50, 'ridge': 61.880504205591386} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:12,705] Trial 187 failed with value nan.
# Trial 188 | k = 40 | ridge =   3.63e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:13,909] Trial 188 failed with parameters: {'k': 40, 'ridge': 36.30214481382008} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:13,910] Trial 188 failed with value nan.
# Trial 189 | k = 50 | ridge =   2.26e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:15,365] Trial 189 failed with parameters: {'k': 50, 'ridge': 22.589656345708814} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:15,366] Trial 189 failed with value nan.
# Trial 190 | k = 40 | ridge =   7.69e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:16,566] Trial 190 failed with parameters: {'k': 40, 'ridge': 76.8801660208724} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:16,567] Trial 190 failed with value nan.
# Trial 191 | k = 50 | ridge =   3.76e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:18,026] Trial 191 failed with parameters: {'k': 50, 'ridge': 37.61698744087913} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:18,027] Trial 191 failed with value nan.
# Trial 192 | k = 50 | ridge =   4.04e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:19,476] Trial 192 failed with parameters: {'k': 50, 'ridge': 40.41468012681057} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:19,477] Trial 192 failed with value nan.
# Trial 193 | k = 50 | ridge =   5.59e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:20,931] Trial 193 failed with parameters: {'k': 50, 'ridge': 55.89595050232983} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:20,932] Trial 193 failed with value nan.
# Trial 194 | k = 40 | ridge =   5.43e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:22,047] Trial 194 failed with parameters: {'k': 40, 'ridge': 54.27419569160296} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:22,048] Trial 194 failed with value nan.
# Trial 195 | k = 40 | ridge =   1.18e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:23,166] Trial 195 failed with parameters: {'k': 40, 'ridge': 117.79915623968591} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:23,167] Trial 195 failed with value nan.
# Trial 196 | k = 40 | ridge =   6.86e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:24,288] Trial 196 failed with parameters: {'k': 40, 'ridge': 68.59600560688936} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:24,288] Trial 196 failed with value nan.
# Trial 197 | k = 50 | ridge =   3.21e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:25,650] Trial 197 failed with parameters: {'k': 50, 'ridge': 32.09032480144488} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:25,651] Trial 197 failed with value nan.
# Trial 198 | k = 40 | ridge =   2.58e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:26,760] Trial 198 failed with parameters: {'k': 40, 'ridge': 25.83452301220487} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:26,761] Trial 198 failed with value nan.
# Trial 199 | k = 50 | ridge =   5.32e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 21:45:28,125] Trial 199 failed with parameters: {'k': 50, 'ridge': 53.237367873268596} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 21:45:28,126] Trial 199 failed with value nan.
#
# ==== Optimal NG-RC Configuration ====
#
# Optimal delay dimension (k) : 20
# Optimal ridge parameter     : 1.56e+05
# Best validation MSE         : 1036.970205
# Best validation MAE         : 23.606986
# Best validation RMSE        : 27.822912
# Execution time              : 169.77 seconds

# %%
# ============================================================
# 8. Select Optimal NG-RC Model
# ============================================================

valid_results = [r for r in results if np.isfinite(r["rmse"])]

if not valid_results:
    raise RuntimeError("No valid hyperparameter configuration found.")

best_result = min(valid_results, key=lambda r: r["rmse"])

best_k = best_result["k"]
best_ridge = best_result["ridge"]
best_mse = best_result["mse"]
best_mae = best_result["mae"]
best_rmse = best_result["rmse"]

print("\n==== Optimal NG-RC Configuration ====\n")
print(f"Delay dimension (k)    : {best_k}")
print(f"Ridge regularization   : {best_ridge:.2e}")
print(f"Validation MSE         : {best_mse:.6f}")
print(f"Validation MAE         : {best_mae:.6f}")
print(f"Validation RMSE        : {best_rmse:.6f}")


# ============================================================
# 9. Retrain NG-RC Using Optimal Hyperparameters
# ============================================================

train_start = warmup_pts - 1
train_end = warmtrain_pts - 1

# Construct NVAR training features
train_features, _ = build_features(X_soln, best_k, train_start, train_end)

# One-step latent increments
delta_x = X_soln[:, warmup_pts:warmtrain_pts] - X_soln[:, warmup_pts - 1 : warmtrain_pts - 1]

# Feature Dimensions
d_linear = d * best_k
d_quadratic = (d_linear * (d_linear + 1)) // 2
d_total = 1 + d_linear + d_quadratic

# Ridge Regression System
cov_matrix = train_features @ train_features.T
reg_matrix = cov_matrix + best_ridge * np.eye(d_total)

try:
    W_out = np.linalg.solve(reg_matrix.T, (delta_x @ train_features.T).T).T
except np.linalg.LinAlgError:
    W_out = delta_x @ train_features.T @ np.linalg.pinv(reg_matrix)


# ============================================================
# 10. Autonomous Forecast Evaluation on TEST Dataset
# ============================================================

test_start = val_end
test_end = maxtime_pts

window_size = 90
stride = 1
horizons = [10, 30, 60, 90]

# Containers (Latent Space)
all_true, all_pred = [], []
all_mse, all_mae, all_rmse = [], [], []

# Containers (Original SST Space)
all_rec_sst, all_true_sst = [], []
all_mse_sst, all_mae_sst, all_rmse_sst = [], [], []

# Horizon-wise Storage
horizon_mses = {h: [] for h in horizons}
horizon_maes = {h: [] for h in horizons}
horizon_sst_mses = {h: [] for h in horizons}
horizon_sst_maes = {h: [] for h in horizons}

# Pre-index upper-triangular terms for fast vectorization in rollout
r_idx, c_idx = np.triu_indices(d_linear)

print("\n==== NG-RC TEST Evaluation ====\n")

for start in range(test_start, test_end - window_size + 1, stride):
    end = start + window_size

    # Initialize Delay History
    history = [X_soln[:, start - best_k + i].copy() for i in range(best_k)]
    prediction = np.zeros((d, window_size))

    # Autonomous Rollout
    for step in range(window_size):
        z = np.hstack([history[-1 - delay] for delay in range(best_k)])

        test_features = np.ones(d_total)
        test_features[1 : 1 + d_linear] = z
        test_features[1 + d_linear :] = z[r_idx] * z[c_idx]

        delta_pred = W_out @ test_features
        next_state = history[-1] + delta_pred

        prediction[:, step] = next_state
        history.append(next_state)

    truth = X_soln[:, start:end]

    # Reconstruct SST Fields
    predicted_pcs = prediction.T
    reconstructed_sst = pca.inverse_transform(predicted_pcs)
    true_sst = sst_time_major[start:end]

    all_rec_sst.append(reconstructed_sst)
    all_true_sst.append(true_sst)

    # ------------------------------------------------------------
    # Point-in-Time Horizon Errors (Matches Adaptive NVAR)
    # ------------------------------------------------------------
    for h in horizons:
        if h > window_size:
            continue

        idx = h - 1  # Target exact lead step

        # Latent Space (per-variable error at lead step h)
        horizon_mses[h].append((truth[:, idx] - prediction[:, idx]) ** 2)
        horizon_maes[h].append(np.abs(truth[:, idx] - prediction[:, idx]))

        # Reconstructed SST Space (spatial average error at lead step h)
        horizon_sst_mses[h].append((true_sst[idx] - reconstructed_sst[idx]) ** 2)
        horizon_sst_maes[h].append(np.abs(true_sst[idx] - reconstructed_sst[idx]))

    # ------------------------------------------------------------
    # Full-window Errors
    # ------------------------------------------------------------
    # Latent Space
    full_mse = np.mean((truth - prediction) ** 2)
    full_mae = np.mean(np.abs(truth - prediction))
    full_rmse = np.sqrt(full_mse)

    all_mse.append(full_mse)
    all_mae.append(full_mae)
    all_rmse.append((start, end, full_rmse))

    # SST Space
    full_mse_sst = np.mean((true_sst - reconstructed_sst) ** 2)
    full_mae_sst = np.mean(np.abs(true_sst - reconstructed_sst))
    full_rmse_sst = np.sqrt(full_mse_sst)

    all_mse_sst.append(full_mse_sst)
    all_mae_sst.append(full_mae_sst)
    all_rmse_sst.append((start, end, full_rmse_sst))

    all_true.append(truth)
    all_pred.append(prediction)


# ============================================================
# 11. Aggregate Array Formatting
# ============================================================

all_true = np.hstack(all_true) if all_true else np.empty((d, 0))
all_pred = np.hstack(all_pred) if all_pred else np.empty((d, 0))
all_rec_sst = np.concatenate(all_rec_sst) if all_rec_sst else np.empty((0, sst_time_major.shape[1]))
all_true_sst = np.concatenate(all_true_sst) if all_true_sst else np.empty((0, sst_time_major.shape[1]))


# ============================================================
# 12. Horizon-wise Forecast Skill Summary
# ============================================================

latent_variables = [f"PC {i+1}" for i in range(d)]

# --- 1. LATENT SPACE METRICS ---
print("\n==== TEST Horizon-wise Forecast Skill (LATENT SPACE) ====\n")

for h in horizons:
    if not horizon_mses[h]:
        continue

    mse_array = np.vstack(horizon_mses[h])
    mae_array = np.vstack(horizon_maes[h])

    mean_mse_per_variable = np.mean(mse_array, axis=0)
    mean_mae_per_variable = np.mean(mae_array, axis=0)
    rmse_per_variable = np.sqrt(mean_mse_per_variable)

    overall_mse = np.mean(mean_mse_per_variable)
    overall_mae = np.mean(mean_mae_per_variable)
    overall_rmse = np.sqrt(overall_mse)

    print(f"-- Forecast Horizon: Step {h} --")
    for i, var in enumerate(latent_variables):
        print(f"{var:<8} | MSE : {mean_mse_per_variable[i]:.6f} | MAE : {mean_mae_per_variable[i]:.6f} | RMSE : {rmse_per_variable[i]:.6f}")

    print(f"\nOverall MSE  : {overall_mse:.6f}")
    print(f"Overall MAE  : {overall_mae:.6f}")
    print(f"Overall RMSE : {overall_rmse:.6f}\n")


# --- 2. RECONSTRUCTED SST SPACE METRICS ---
print("\n==== TEST Horizon-wise Forecast Skill (RECONSTRUCTED SST) ====\n")

for h in horizons:
    if not horizon_sst_mses[h]:
        continue

    mse_array_sst = np.vstack(horizon_sst_mses[h])
    mae_array_sst = np.vstack(horizon_sst_maes[h])

    overall_mse_sst = np.mean(mse_array_sst)
    overall_mae_sst = np.mean(mae_array_sst)
    overall_rmse_sst = np.sqrt(overall_mse_sst)

    print(f"-- Forecast Horizon: Step {h} --")
    print(f"Overall SST MSE  : {overall_mse_sst:.6f}")
    print(f"Overall SST MAE  : {overall_mae_sst:.6f}")
    print(f"Overall SST RMSE : {overall_rmse_sst:.6f}\n")


# --- 3. OVERALL TEST SUMMARY ---
print("==== Overall TEST Summary ====\n")

print(f"Average Full-Window MSE (Latent)  : {np.mean(all_mse):.6f}")
print(f"Average Full-Window MAE (Latent)  : {np.mean(all_mae):.6f}")
print(f"Average Full-Window RMSE (Latent) : {np.mean([x[2] for x in all_rmse]):.6f}\n")

print(f"Average Full-Window MSE (SST)     : {np.mean(all_mse_sst):.6f}")
print(f"Average Full-Window MAE (SST)     : {np.mean(all_mae_sst):.6f}")
print(f"Average Full-Window RMSE (SST)    : {np.mean([x[2] for x in all_rmse_sst]):.6f}\n")

print(f"TEST Window Size                 : {window_size}")
print(f"TEST Stride                      : {stride}")
print(f"Total TEST Windows               : {len(all_rmse)}")
# Out:
# ==== Optimal NG-RC Configuration ====
#
# Delay dimension (k)    : 20
# Ridge regularization   : 1.56e+05
# Validation MSE         : 1036.970205
# Validation MAE         : 23.606986
# Validation RMSE        : 27.822912
#
# ==== NG-RC TEST Evaluation ====
#
#
# ==== TEST Horizon-wise Forecast Skill (LATENT SPACE) ====
#
# -- Forecast Horizon: Step 10 --
# PC 1     | MSE : 62.952177 | MAE : 5.250268 | RMSE : 7.934241
#
# Overall MSE  : 62.952177
# Overall MAE  : 5.250268
# Overall RMSE : 7.934241
#
# -- Forecast Horizon: Step 30 --
# PC 1     | MSE : 413.791235 | MAE : 16.320658 | RMSE : 20.341859
#
# Overall MSE  : 413.791235
# Overall MAE  : 16.320658
# Overall RMSE : 20.341859
#
# -- Forecast Horizon: Step 60 --
# PC 1     | MSE : 1575.222873 | MAE : 33.533593 | RMSE : 39.689077
#
# Overall MSE  : 1575.222873
# Overall MAE  : 33.533593
# Overall RMSE : 39.689077
#
# -- Forecast Horizon: Step 90 --
# PC 1     | MSE : 2590.830083 | MAE : 43.708072 | RMSE : 50.900197
#
# Overall MSE  : 2590.830083
# Overall MAE  : 43.708072
# Overall RMSE : 50.900197
#
#
# ==== TEST Horizon-wise Forecast Skill (RECONSTRUCTED SST) ====
#
# -- Forecast Horizon: Step 10 --
# Overall SST MSE  : 0.073476
# Overall SST MAE  : 0.213165
# Overall SST RMSE : 0.271065
#
# -- Forecast Horizon: Step 30 --
# Overall SST MSE  : 0.198077
# Overall SST MAE  : 0.359168
# Overall SST RMSE : 0.445058
#
# -- Forecast Horizon: Step 60 --
# Overall SST MSE  : 0.610684
# Overall SST MAE  : 0.648273
# Overall SST RMSE : 0.781463
#
# -- Forecast Horizon: Step 90 --
# Overall SST MSE  : 0.969077
# Overall SST MAE  : 0.835613
# Overall SST RMSE : 0.984417
#
# ==== Overall TEST Summary ====
#
# Average Full-Window MSE (Latent)  : 1088.408496
# Average Full-Window MAE (Latent)  : 24.398320
# Average Full-Window RMSE (Latent) : 28.804183
#
# Average Full-Window MSE (SST)     : 0.437404
# Average Full-Window MAE (SST)     : 0.506090
# Average Full-Window RMSE (SST)    : 0.601648
#
# TEST Window Size                 : 90
# TEST Stride                      : 1
# Total TEST Windows               : 411

# %%
# ============================================================
# Continuous Autonomous SST Forecast Visualization
# Standard NVAR
# ============================================================

import numpy as np
import matplotlib.pyplot as plt

# ============================================================
# 1. FORECAST LENGTH & EVALUATION SETUP
# ============================================================

plot_len = 90

window_idx = 330      # 0 = first window, 1 = second, ...
test_stride = 1

test_start = val_end + window_idx * test_stride
# Initialize Delay History
history = [
    X_soln[:, test_start - best_k + i].copy()
    for i in range(best_k)
]

# Feature Dimensions & Pre-indexed Upper-Triangular Mapping
d_linear = d * best_k
d_quadratic = (d_linear * (d_linear + 1)) // 2
d_total = 1 + d_linear + d_quadratic

r_idx, c_idx = np.triu_indices(d_linear)

# ============================================================
# 2. CONTINUOUS AUTONOMOUS ROLLOUT
# ============================================================

continuous_pred = np.zeros((d, plot_len))

for j in range(plot_len):

    # Delay Embedding Vector
    z = np.hstack([history[-1 - i] for i in range(best_k)])

    # Construct NVAR Feature Vector
    out_test = np.ones(d_total)
    out_test[1 : 1 + d_linear] = z
    out_test[1 + d_linear :] = z[r_idx] * z[c_idx]

    # Predict Increment & Advance State
    delta_pred = W_out @ out_test
    next_x = history[-1] + delta_pred

    # Store Prediction & Update History
    continuous_pred[:, j] = next_x
    history.append(next_x)

# ============================================================
# 3. RECONSTRUCT SST FIELDS & ERROR
# ============================================================

pc_pred = continuous_pred.T
pred_field = pca.inverse_transform(pc_pred)
true_field = sst_time_major[test_start : test_start + plot_len]

# Absolute SST Error
sst_error = np.abs(true_field - pred_field)

# Enforce shared color scale for True and Predicted fields
vmin_sst = min(true_field.min(), pred_field.min())
vmax_sst = max(true_field.max(), pred_field.max())

# ============================================================
# 4. SUBPLOTS SETUP
# ============================================================

fig, axes = plt.subplots(3, 1, figsize=(14, 10), sharex=True)

# --- TRUE SST FIELD ---
im0 = axes[0].imshow(
    true_field.T,
    aspect='auto',
    origin='lower',
    cmap='coolwarm',
    vmin=vmin_sst,
    vmax=vmax_sst
)
axes[0].set_title('True SST Field', fontsize=14, fontweight='bold')
axes[0].set_ylabel('Spatial Grid Index', fontsize=12)

# --- PREDICTED SST FIELD ---
im1 = axes[1].imshow(
    pred_field.T,
    aspect='auto',
    origin='lower',
    cmap='coolwarm',
    vmin=vmin_sst,
    vmax=vmax_sst
)
axes[1].set_title('Standard NVAR Predicted SST Field', fontsize=14, fontweight='bold')
axes[1].set_ylabel('Spatial Grid Index', fontsize=12)

# --- ABSOLUTE ERROR FIELD ---
im2 = axes[2].imshow(
    sst_error.T,
    aspect='auto',
    origin='lower',
    cmap='inferno',
    vmin=0,
    vmax=sst_error.max()
)
axes[2].set_title('Absolute SST Error', fontsize=14, fontweight='bold')
axes[2].set_xlabel('Forecast Time Step', fontsize=12)
axes[2].set_ylabel('Spatial Grid Index', fontsize=12)

# ============================================================
# 5. COLORBARS & EXPORT
# ============================================================

cbar0 = fig.colorbar(im0, ax=axes[0], fraction=0.02, pad=0.02)
cbar0.set_label('SST', fontsize=10)

cbar1 = fig.colorbar(im1, ax=axes[1], fraction=0.02, pad=0.02)
cbar1.set_label('SST', fontsize=10)

cbar2 = fig.colorbar(im2, ax=axes[2], fraction=0.02, pad=0.02)
cbar2.set_label('Abs Error', fontsize=10)

plt.tight_layout()

plt.savefig(
    "standard_nvar_sst_field_evolution_East_Sea.png",
    dpi=300,
    bbox_inches='tight'
)

plt.show()
