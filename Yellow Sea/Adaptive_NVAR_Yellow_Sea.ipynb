# %%
# ============================================================
# Imports & Setup
# ============================================================
import warnings
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from matplotlib.ticker import MaxNLocator

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# Torch defaults
torch.set_default_dtype(torch.float32)

# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device in use: {device}")
if device.type == "cuda":
    print(f"CUDA device: {torch.cuda.current_device()} - {torch.cuda.get_device_name(0)}")

# Suppress unnecessary warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Device in use: cuda
# CUDA device: 0 - A100-PCIE-40GB

# %%
# ============================================================
# 1. Load SST Dataset
# ============================================================
sst_data = np.load("sst_normalized_5k.npy")

# Shape transformation to time-major: (time, spatial_points)
sst_time_major = sst_data.T
print("Original SST shape (time-major):", sst_time_major.shape)

# ============================================================
# 2. Time Setup & Data Splits
# ============================================================
dt = 1.0
warmup    = 100.0
traintime = 3900.0
valtime   = 500.0
testtime  = 500.0

maxtime = warmup + traintime + valtime + testtime

warmup_pts    = int(round(warmup / dt))
traintime_pts = int(round(traintime / dt))
valtime_pts   = int(round(valtime / dt))
testtime_pts  = int(round(testtime / dt))

warmtrain_pts = warmup_pts + traintime_pts
val_end       = warmtrain_pts + valtime_pts
maxtime_pts   = int(round(maxtime / dt))

print("\n==== Data Splits ====")
print(f"Warmup : {warmup_pts}")
print(f"Train  : {traintime_pts}")
print(f"Val    : {valtime_pts}")
print(f"Test   : {testtime_pts}")
# Out:
# Original SST shape (time-major): (5001, 2078)
#
# ==== Data Splits ====
# Warmup : 100
# Train  : 3900
# Val    : 500
# Test   : 500

# %%
# ============================================================
# 3. Fit PCA/SVD on TRAINING DATA ONLY
# ============================================================
pca_train_end = warmtrain_pts
n_components = 1

train_sst = sst_time_major[:pca_train_end]

pca = PCA(n_components=n_components, svd_solver='full')
pca.fit(train_sst)

# Transform entire dataset using TRAIN PCA basis
sst_pca = pca.transform(sst_time_major)
explained_variance = pca.explained_variance_ratio_

print("\n==== PCA/SVD Summary ====")
print(f"Retained components      : {n_components}")
print(f"Explained variance ratio : {explained_variance}")

# ============================================================
# 4. Prepare Latent SST Dataset
# ============================================================
latent_sst = sst_pca.T
X_soln = latent_sst[:, :maxtime_pts + 1]
d, T_full = X_soln.shape

print(f"\nLatent SST shape: {X_soln.shape}")
# Out:
# ==== PCA/SVD Summary ====
# Retained components      : 1
# Explained variance ratio : [0.98293175]
#
# Latent SST shape: (1, 5001)

# %%
# ============================================================
# Professional PCA / EOF Visualization
# ============================================================

# Refit with more components for diagnostic spectrum plotting
n_plot_components = 10
pca_plot = PCA(n_components=n_plot_components, svd_solver='full')
pca_plot.fit(train_sst)

explained_variance_plot = pca_plot.explained_variance_ratio_
cumulative_variance_plot = np.cumsum(explained_variance_plot)

# ------------------------------------------------------------
# Figure 1: Explained Variance Spectrum
# ------------------------------------------------------------
fig, ax = plt.subplots(figsize=(8, 5))
components = np.arange(1, n_plot_components + 1)

# Variance plots
ax.plot(components, explained_variance_plot, marker='o', linewidth=2.2, markersize=6, label='Individual Variance Ratio')
ax.plot(components, cumulative_variance_plot, marker='s', linewidth=2.2, markersize=5, label='Cumulative Variance Ratio')

# Highlight retained dimensions
ax.axvline(x=n_components, linestyle='--', linewidth=2, color='tab:red', label=f'Retained Components = {n_components}')

# Axis Formatting
ax.set_xlabel('Principal Component Index', fontsize=14)
ax.set_ylabel('Explained Variance Ratio', fontsize=14)
ax.set_title('PCA Explained Variance Spectrum', fontsize=16, pad=12)
ax.set_xticks(components)
ax.tick_params(axis='both', labelsize=12)
ax.grid(True, linestyle='--', alpha=0.5)
ax.legend(fontsize=11, frameon=True)

plt.tight_layout()
plt.savefig('pca_explained_variance_professional.png', dpi=600, bbox_inches='tight')
plt.show()

# ------------------------------------------------------------
# Figure 2: Leading Principal Component Time Series
# ------------------------------------------------------------
fig, ax = plt.subplots(figsize=(11, 4))
time_axis = np.arange(X_soln.shape[1])

ax.plot(time_axis, X_soln[0], linewidth=1.2, color='tab:blue')

# Axis Formatting
ax.set_xlabel('Time Step', fontsize=14)
ax.set_ylabel('PC1 Amplitude', fontsize=14)
ax.set_title('Leading Principal Component Time Series', fontsize=16, pad=12)
ax.tick_params(axis='both', labelsize=12)
ax.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.savefig('pc1_timeseries_professional.png', dpi=600, bbox_inches='tight')
plt.show()

# ------------------------------------------------------------
# Figure 3: Latent SST Dynamics Overview
# ------------------------------------------------------------
num_components_to_plot = min(n_components, 10)
time_steps = np.arange(latent_sst.shape[1])

plt.figure(figsize=(12, 2.5 * num_components_to_plot))

for i in range(num_components_to_plot):
    plt.subplot(num_components_to_plot, 1, i + 1)
    plt.plot(time_steps, latent_sst[i], linewidth=1.0, label=f'PC {i+1}')
    plt.ylabel(f'PC {i+1}')
    plt.grid(True, alpha=0.3)
    plt.legend(loc='upper right')

    if i == 0:
        plt.title("Latent SST Dynamics in PCA Space", fontsize=14)
    if i == num_components_to_plot - 1:
        plt.xlabel("Time Step")

plt.tight_layout()
plt.show()

# ------------------------------------------------------------
# Variance Summary Output
# ------------------------------------------------------------
print("\n==== PCA Visualization Summary ====\n")
for i, var in enumerate(explained_variance_plot):
    print(f"PC{i+1:02d} Variance Ratio: {var:.6f}")

print(f"\nCumulative Variance (first {n_plot_components} PCs): {cumulative_variance_plot[-1]:.6f}")
# Out:
# ==== PCA Visualization Summary ====
#
# PC01 Variance Ratio: 0.982932
# PC02 Variance Ratio: 0.008131
# PC03 Variance Ratio: 0.002208
# PC04 Variance Ratio: 0.001542
# PC05 Variance Ratio: 0.000693
# PC06 Variance Ratio: 0.000550
# PC07 Variance Ratio: 0.000369
# PC08 Variance Ratio: 0.000279
# PC09 Variance Ratio: 0.000236
# PC10 Variance Ratio: 0.000186
#
# Cumulative Variance (first 10 PCs): 0.997127

# %%
# ============================================================
# Dataset Splits & Setup
# ============================================================
X_noisy_dataset = X_soln.T
X = torch.tensor(X_noisy_dataset, dtype=torch.float32)       # noisy input
X_true = torch.tensor(X_noisy_dataset, dtype=torch.float32)  # clean reference

# Dataset splits
warmup_len, train_len, val_len, test_len = 100, 3900, 500, 500

X_warmup = X[:warmup_len].to(device)
X_train_clean = X[warmup_len:warmup_len + train_len]
X_val  = X[warmup_len + train_len : warmup_len + train_len + val_len].to(device)
X_test = X[warmup_len + train_len + val_len : warmup_len + train_len + val_len + test_len].to(device)

# Ground truth references
X_val_true  = X_true[warmup_len + train_len : warmup_len + train_len + val_len].to(device)
X_test_true = X_true[warmup_len + train_len + val_len : warmup_len + train_len + val_len + test_len].to(device)
X_val_true_raw = X_true[warmup_len + train_len : warmup_len + train_len + val_len]
X_test_true_raw = sst_time_major[warmup_len + train_len + val_len : warmup_len + train_len + val_len + test_len]

# Training-time noise (regularization for noise-free case: train_noise_scale = 0.0)
train_noise_scale = 0.0
signal_std = X_train_clean.std(dim=0, keepdim=True).cpu().numpy()
train_noise = np.random.normal(0.0, train_noise_scale * signal_std, X_train_clean.shape)
X_train = torch.tensor((X_train_clean.cpu().numpy() + train_noise).astype(np.float32), device=device)


# ============================================================
# Adaptive NVAR Model Definition
# ============================================================
class FeatureMLP(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, output_dim)
        )

    def forward(self, x):
        return self.net(x)


class AdaptiveNVARModel(nn.Module):
    def __init__(self, dk, m, d, hidden_dim):
        super().__init__()
        self.mlp = FeatureMLP(dk, hidden_dim, m)
        self.readout = nn.Linear(dk + m, d, bias=False)

    def forward(self, H_lin):
        H_nn = self.mlp(H_lin)
        H_total = torch.cat([H_lin, H_nn], dim=1)
        return self.readout(H_total)


# ============================================================
# Helper Functions & Model Training
# ============================================================
def construct_H_lin(X, k):
    """Constructs delay-embedded features from time series."""
    T = X.shape[0]
    return torch.cat([X[i:T - k + i] for i in range(k)], dim=1)


def init_weights_stable(m):
    """Stable Xavier initialization for linear layers."""
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            nn.init.zeros_(m.bias)
        with torch.no_grad():
            m.weight.mul_(1.0)


def train_joint_model(
    X, k, m, hidden_dim=200,
    lr_adam=1e-4,
    max_epochs_adam=5000,
    save_path="best_joint_model.pth",
    adam_patience=200,
    tolerance=1e-8,
    device=None
):
    """Train Adaptive NVAR model using Adam optimization only."""
    device = device or torch.device("cuda" if torch.cuda.is_available() else "cpu")
    X = X.to(device)

    # Prepare features & targets
    H_lin = construct_H_lin(X, k)       # [n, dk]
    Y = X[k:] - X[k-1:-1]               # [n, d]
    n, dk = H_lin.shape
    d = Y.shape[1]

    # Initialize model
    model = AdaptiveNVARModel(dk, m, d, hidden_dim).to(device)
    model.apply(init_weights_stable)

    optimizer = torch.optim.Adam(model.parameters(), lr=lr_adam)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="min", factor=0.5, patience=200
    )

    best_loss = float("inf")
    epochs_no_improve = 0

    for epoch in range(max_epochs_adam):
        model.train()

        Y_hat = model(H_lin)
        loss = F.mse_loss(Y_hat, Y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step(loss.item())

        if best_loss - loss.item() > tolerance:
            best_loss = loss.item()
            epochs_no_improve = 0
            torch.save(model.state_dict(), save_path)
        else:
            epochs_no_improve += 1

        if epochs_no_improve >= adam_patience:
            break

    model.load_state_dict(torch.load(save_path))
    return model

# %%
# ============================================================
# Adaptive NVAR Hyperparameter Optimization (Optuna)
# ============================================================
import time
import optuna
import numpy as np
import torch

# Validation Setup
window_size = 90
stride = 1
horizons = [10, 30, 60, 90]
base_seed = 2025
n_trials = 200
num_runs = 5  # Number of independent models per trial

all_results = []

def objective(trial):
    # Hyperparameter Search Space
    k = trial.suggest_categorical("k", [2, 5, 10, 20, 30, 40, 50])
    hidden_dim = trial.suggest_categorical("hidden_dim", [20, 50, 100])
    lr_adam = trial.suggest_float("lr_adam", 1e-4, 1e-1, log=True)

    # Dimensions
    d = X_train.shape[1]
    dk = d * k
    m = int((dk * (dk + 1)) / 2)  # Adaptive nonlinear feature dimension

    # Containers across 3 independent runs
    runs_avg_mses = {h: [] for h in horizons}
    runs_avg_maes = {h: [] for h in horizons}
    runs_avg_rmses = {h: [] for h in horizons}

    for run in range(num_runs):
        # Unique seed per run for independent initializations/training
        run_seed = base_seed + run
        torch.manual_seed(run_seed)
        torch.cuda.manual_seed_all(run_seed)
        np.random.seed(run_seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

        model_path = f"optuna_model_k{k}_hd{hidden_dim}_adam{lr_adam:.2e}_run{run}.pth"

        # Train Model
        try:
            model = train_joint_model(
                X=X_train, k=k, m=m, hidden_dim=hidden_dim,
                lr_adam=lr_adam, save_path=model_path, device=device
            )
        except Exception as e:
            print(f"Training failed on run {run}: {e}")
            return np.inf

        model.eval()

        # Metric Storage for this run
        horizon_mses = {h: [] for h in horizons}
        horizon_maes = {h: [] for h in horizons}
        horizon_rmses = {h: [] for h in horizons}

        # Overlapping Rolling Validation
        for start in range(0, len(X_val_true) - window_size + 1, stride):
            end = start + window_size
            X_val_true_window = X_val_true[start:end]

            init_start = warmup_len + train_len + start - k
            init_end = warmup_len + train_len + start

            X_init = X[init_start:init_end].to(device)
            x_t = [x.clone() for x in X_init.unbind(0)]
            H_lin = torch.cat(x_t, dim=-1).unsqueeze(0)

            predictions = []
            unstable = False

            for step in range(window_size):
                with torch.no_grad():
                    delta_x = model(H_lin)

                x_next = x_t[-1] + delta_x.squeeze(0)

                if torch.isnan(x_next).any() or torch.isinf(x_next).any():
                    unstable = True
                    break

                predictions.append(x_next)
                x_t = x_t[1:] + [x_next]
                H_lin = torch.cat(x_t, dim=-1).unsqueeze(0)

            if unstable:
                return np.inf

            predictions_np = torch.stack(predictions).cpu().numpy()
            y_true_np = X_val_true_window.cpu().numpy()

            for h in horizons:
                if h > len(predictions_np):
                    continue

                mse_h = np.mean((y_true_np[:h] - predictions_np[:h]) ** 2)
                mae_h = np.mean(np.abs(y_true_np[:h] - predictions_np[:h]))
                rmse_h = np.sqrt(mse_h)

                if not np.isfinite(rmse_h):
                    return np.inf

                horizon_mses[h].append(mse_h)
                horizon_maes[h].append(mae_h)
                horizon_rmses[h].append(rmse_h)

        # Average performance for this specific run
        for h in horizons:
            runs_avg_mses[h].append(np.mean(horizon_mses[h]))
            runs_avg_maes[h].append(np.mean(horizon_maes[h]))
            runs_avg_rmses[h].append(np.mean(horizon_rmses[h]))

    # Mean performance across all 3 independent runs
    final_avg_mse = {h: np.mean(runs_avg_mses[h]) for h in horizons}
    final_avg_mae = {h: np.mean(runs_avg_maes[h]) for h in horizons}
    final_avg_rmse = {h: np.mean(runs_avg_rmses[h]) for h in horizons}

    all_results.append({
        "k": k, "hidden_dim": hidden_dim, "lr_adam": lr_adam,
        "mse": final_avg_mse, "mae": final_avg_mae, "rmse": final_avg_rmse
    })

    log_str = f"Trial {trial.number:03d} | k={k:<2d} | hidden_dim={hidden_dim:<4d} | Adam LR={lr_adam:.2e} | "
    log_str += ", ".join([f"h={h}: Mean RMSE={final_avg_rmse[h]:.6f}" for h in horizons])
    print(log_str)

    return final_avg_rmse[90]


# Execute Study
start_time = time.time()
print("\n==== Adaptive NVAR Hyperparameter Optimization (3 Runs Averaged) ====\n")

study = optuna.create_study(
    direction="minimize",
    sampler=optuna.samplers.TPESampler(seed=base_seed)
)

study.optimize(objective, n_trials=n_trials, show_progress_bar=True)

# Best Model Summary
best_config = study.best_params
best_rmse = study.best_value
best_result = min(all_results, key=lambda x: x["rmse"][90])

print("\n==== Best Adaptive NVAR Configuration ====\n")
print(f"k             : {best_config['k']}")
print(f"hidden_dim    : {best_config['hidden_dim']}")
print(f"Adam LR       : {best_config['lr_adam']:.2e}")
print(f"Best MSE@90   : {best_result['mse'][90]:.6f}")
print(f"Best MAE@90   : {best_result['mae'][90]:.6f}")
print(f"Best RMSE@90  : {best_rmse:.6f}")
print(f"Execution time: {time.time() - start_time:.2f} seconds")
# Out:
# [I 2026-07-25 22:12:32,625] A new study created in memory with name: no-name-48fbaae3-e4d6-4174-9354-bded63d8eb82
# ==== Adaptive NVAR Hyperparameter Optimization (3 Runs Averaged) ====
#   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 000 | k=10 | hidden_dim=50   | Adam LR=2.32e-03 | h=10: Mean RMSE=4.183524, h=30: Mean RMSE=8.990221, h=60: Mean RMSE=15.344160, h=90: Mean RMSE=20.822428
# [I 2026-07-25 22:15:16,605] Trial 0 finished with value: 20.82242774963379 and parameters: {'k': 10, 'hidden_dim': 50, 'lr_adam': 0.002320683185722375}. Best is trial 0 with value: 20.82242774963379.
# Trial 001 | k=50 | hidden_dim=100  | Adam LR=9.17e-02 | h=10: Mean RMSE=3.731691, h=30: Mean RMSE=6.215345, h=60: Mean RMSE=8.090757, h=90: Mean RMSE=10.254324
# [I 2026-07-25 22:20:37,419] Trial 1 finished with value: 10.254323959350586 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.09174844927586977}. Best is trial 1 with value: 10.254323959350586.
# Trial 002 | k=20 | hidden_dim=100  | Adam LR=3.46e-03 | h=10: Mean RMSE=4.393953, h=30: Mean RMSE=7.728947, h=60: Mean RMSE=12.148788, h=90: Mean RMSE=16.973095
# [I 2026-07-25 22:27:11,607] Trial 2 finished with value: 16.973094940185547 and parameters: {'k': 20, 'hidden_dim': 100, 'lr_adam': 0.003462771731035132}. Best is trial 1 with value: 10.254323959350586.
# Trial 003 | k=40 | hidden_dim=20   | Adam LR=4.89e-02 | h=10: Mean RMSE=4.052932, h=30: Mean RMSE=7.775149, h=60: Mean RMSE=11.218280, h=90: Mean RMSE=14.747320
# [I 2026-07-25 22:33:32,727] Trial 3 finished with value: 14.747320175170898 and parameters: {'k': 40, 'hidden_dim': 20, 'lr_adam': 0.04894860753318619}. Best is trial 1 with value: 10.254323959350586.
# Trial 004 | k=5  | hidden_dim=20   | Adam LR=1.72e-04 | h=10: Mean RMSE=5.186018, h=30: Mean RMSE=13.426321, h=60: Mean RMSE=25.344414, h=90: Mean RMSE=45.255562
# [I 2026-07-25 22:40:17,163] Trial 4 finished with value: 45.25556182861328 and parameters: {'k': 5, 'hidden_dim': 20, 'lr_adam': 0.0001715181000930745}. Best is trial 1 with value: 10.254323959350586.
# Trial 005 | k=5  | hidden_dim=50   | Adam LR=9.43e-02 | h=10: Mean RMSE=4.490231, h=30: Mean RMSE=11.153915, h=60: Mean RMSE=21.326256, h=90: Mean RMSE=31.060886
# [I 2026-07-25 22:46:24,154] Trial 5 finished with value: 31.06088638305664 and parameters: {'k': 5, 'hidden_dim': 50, 'lr_adam': 0.09427622839017512}. Best is trial 1 with value: 10.254323959350586.
# Trial 006 | k=2  | hidden_dim=50   | Adam LR=1.96e-04 | h=10: Mean RMSE=4.888263, h=30: Mean RMSE=12.646965, h=60: Mean RMSE=29.575165, h=90: Mean RMSE=133.511490
# [I 2026-07-25 22:52:55,486] Trial 6 finished with value: 133.51148986816406 and parameters: {'k': 2, 'hidden_dim': 50, 'lr_adam': 0.00019551586581276307}. Best is trial 1 with value: 10.254323959350586.
# Trial 007 | k=20 | hidden_dim=50   | Adam LR=2.55e-04 | h=10: Mean RMSE=3.977268, h=30: Mean RMSE=7.239586, h=60: Mean RMSE=11.430393, h=90: Mean RMSE=16.327038
# [I 2026-07-25 22:59:35,431] Trial 7 finished with value: 16.327037811279297 and parameters: {'k': 20, 'hidden_dim': 50, 'lr_adam': 0.0002552196236773345}. Best is trial 1 with value: 10.254323959350586.
# Trial 008 | k=30 | hidden_dim=100  | Adam LR=6.54e-04 | h=10: Mean RMSE=4.597101, h=30: Mean RMSE=8.186388, h=60: Mean RMSE=12.495794, h=90: Mean RMSE=16.670040
# [I 2026-07-25 23:06:15,553] Trial 8 finished with value: 16.670040130615234 and parameters: {'k': 30, 'hidden_dim': 100, 'lr_adam': 0.0006541737568595412}. Best is trial 1 with value: 10.254323959350586.
# Trial 009 | k=50 | hidden_dim=20   | Adam LR=1.05e-03 | h=10: Mean RMSE=4.428088, h=30: Mean RMSE=7.474031, h=60: Mean RMSE=9.996827, h=90: Mean RMSE=12.617151
# [I 2026-07-25 23:13:04,691] Trial 9 finished with value: 12.617151260375977 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.0010505938260479337}. Best is trial 1 with value: 10.254323959350586.
# Trial 010 | k=50 | hidden_dim=100  | Adam LR=1.77e-02 | h=10: Mean RMSE=3.987207, h=30: Mean RMSE=6.637801, h=60: Mean RMSE=8.916842, h=90: Mean RMSE=11.603003
# [I 2026-07-25 23:19:33,324] Trial 10 finished with value: 11.603002548217773 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.017720739134423014}. Best is trial 1 with value: 10.254323959350586.
# Trial 011 | k=50 | hidden_dim=100  | Adam LR=2.43e-02 | h=10: Mean RMSE=4.012578, h=30: Mean RMSE=6.769094, h=60: Mean RMSE=8.994009, h=90: Mean RMSE=11.485385
# [I 2026-07-25 23:26:00,682] Trial 11 finished with value: 11.485384941101074 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.024295768876512285}. Best is trial 1 with value: 10.254323959350586.
# Trial 012 | k=50 | hidden_dim=100  | Adam LR=1.59e-02 | h=10: Mean RMSE=4.020759, h=30: Mean RMSE=6.836900, h=60: Mean RMSE=9.256464, h=90: Mean RMSE=11.786520
# [I 2026-07-25 23:32:23,694] Trial 12 finished with value: 11.786520004272461 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.015939322129423287}. Best is trial 1 with value: 10.254323959350586.
# Trial 013 | k=50 | hidden_dim=100  | Adam LR=1.53e-02 | h=10: Mean RMSE=4.076663, h=30: Mean RMSE=6.976807, h=60: Mean RMSE=9.362992, h=90: Mean RMSE=11.520412
# [I 2026-07-25 23:38:45,929] Trial 13 finished with value: 11.52041244506836 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.015278748450402255}. Best is trial 1 with value: 10.254323959350586.
# Trial 014 | k=50 | hidden_dim=100  | Adam LR=4.78e-02 | h=10: Mean RMSE=3.664152, h=30: Mean RMSE=6.003318, h=60: Mean RMSE=7.694509, h=90: Mean RMSE=9.494291
# [I 2026-07-25 23:45:01,845] Trial 14 finished with value: 9.494291305541992 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.0478380612872434}. Best is trial 14 with value: 9.494291305541992.
# Trial 015 | k=30 | hidden_dim=100  | Adam LR=9.32e-02 | h=10: Mean RMSE=4.051074, h=30: Mean RMSE=7.642587, h=60: Mean RMSE=10.921757, h=90: Mean RMSE=14.883937
# [I 2026-07-25 23:51:26,279] Trial 15 finished with value: 14.883936882019043 and parameters: {'k': 30, 'hidden_dim': 100, 'lr_adam': 0.09317685534829934}. Best is trial 14 with value: 9.494291305541992.
# Trial 016 | k=40 | hidden_dim=100  | Adam LR=4.40e-02 | h=10: Mean RMSE=3.841736, h=30: Mean RMSE=6.684711, h=60: Mean RMSE=9.005069, h=90: Mean RMSE=11.661547
# [I 2026-07-25 23:57:44,639] Trial 16 finished with value: 11.66154670715332 and parameters: {'k': 40, 'hidden_dim': 100, 'lr_adam': 0.04401332666898656}. Best is trial 14 with value: 9.494291305541992.
# Trial 017 | k=2  | hidden_dim=100  | Adam LR=6.48e-03 | h=10: Mean RMSE=4.887347, h=30: Mean RMSE=12.378845, h=60: Mean RMSE=23.835300, h=90: Mean RMSE=34.234535
# [I 2026-07-26 00:04:11,282] Trial 17 finished with value: 34.234535217285156 and parameters: {'k': 2, 'hidden_dim': 100, 'lr_adam': 0.00647819744402442}. Best is trial 14 with value: 9.494291305541992.
# Trial 018 | k=10 | hidden_dim=100  | Adam LR=6.34e-03 | h=10: Mean RMSE=4.363278, h=30: Mean RMSE=8.896837, h=60: Mean RMSE=14.909978, h=90: Mean RMSE=20.696194
# [I 2026-07-26 00:10:37,922] Trial 18 finished with value: 20.69619369506836 and parameters: {'k': 10, 'hidden_dim': 100, 'lr_adam': 0.006339661643217383}. Best is trial 14 with value: 9.494291305541992.
# Trial 019 | k=50 | hidden_dim=20   | Adam LR=4.70e-02 | h=10: Mean RMSE=3.590323, h=30: Mean RMSE=6.153874, h=60: Mean RMSE=8.342501, h=90: Mean RMSE=10.029181
# [I 2026-07-26 00:16:56,678] Trial 19 finished with value: 10.029180526733398 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.047038483146110595}. Best is trial 14 with value: 9.494291305541992.
# Trial 020 | k=50 | hidden_dim=20   | Adam LR=3.39e-02 | h=10: Mean RMSE=3.725421, h=30: Mean RMSE=6.528856, h=60: Mean RMSE=9.083611, h=90: Mean RMSE=11.597423
# [I 2026-07-26 00:23:13,718] Trial 20 finished with value: 11.59742259979248 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.033921169284497}. Best is trial 14 with value: 9.494291305541992.
# Trial 021 | k=50 | hidden_dim=20   | Adam LR=6.16e-02 | h=10: Mean RMSE=3.583899, h=30: Mean RMSE=6.159896, h=60: Mean RMSE=8.642969, h=90: Mean RMSE=11.263250
# [I 2026-07-26 00:29:26,679] Trial 21 finished with value: 11.263250350952148 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.06159776690438794}. Best is trial 14 with value: 9.494291305541992.
# Trial 022 | k=50 | hidden_dim=20   | Adam LR=1.09e-02 | h=10: Mean RMSE=3.814167, h=30: Mean RMSE=6.418923, h=60: Mean RMSE=9.032110, h=90: Mean RMSE=12.151286
# [I 2026-07-26 00:35:45,320] Trial 22 finished with value: 12.151286125183105 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.01094800571609657}. Best is trial 14 with value: 9.494291305541992.
# Trial 023 | k=50 | hidden_dim=20   | Adam LR=3.08e-02 | h=10: Mean RMSE=3.743412, h=30: Mean RMSE=6.842162, h=60: Mean RMSE=10.056395, h=90: Mean RMSE=12.866870
# [I 2026-07-26 00:42:04,054] Trial 23 finished with value: 12.866869926452637 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.030829066852071728}. Best is trial 14 with value: 9.494291305541992.
# Trial 024 | k=50 | hidden_dim=100  | Adam LR=6.39e-02 | h=10: Mean RMSE=3.758948, h=30: Mean RMSE=6.318583, h=60: Mean RMSE=8.429699, h=90: Mean RMSE=10.768123
# [I 2026-07-26 00:48:33,927] Trial 24 finished with value: 10.768122673034668 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.06387883100377734}. Best is trial 14 with value: 9.494291305541992.
# Trial 025 | k=50 | hidden_dim=20   | Adam LR=9.20e-03 | h=10: Mean RMSE=3.998428, h=30: Mean RMSE=6.845591, h=60: Mean RMSE=9.827503, h=90: Mean RMSE=13.065916
# [I 2026-07-26 00:55:09,460] Trial 25 finished with value: 13.065916061401367 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.009201938732080837}. Best is trial 14 with value: 9.494291305541992.
# Trial 026 | k=2  | hidden_dim=100  | Adam LR=9.93e-02 | h=10: Mean RMSE=4.819454, h=30: Mean RMSE=12.647310, h=60: Mean RMSE=24.681280, h=90: Mean RMSE=35.635731
# [I 2026-07-26 01:01:26,664] Trial 26 finished with value: 35.6357307434082 and parameters: {'k': 2, 'hidden_dim': 100, 'lr_adam': 0.09933761270374124}. Best is trial 14 with value: 9.494291305541992.
# Trial 027 | k=10 | hidden_dim=100  | Adam LR=2.60e-02 | h=10: Mean RMSE=4.240489, h=30: Mean RMSE=8.969961, h=60: Mean RMSE=14.719111, h=90: Mean RMSE=19.488266
# [I 2026-07-26 01:07:36,385] Trial 27 finished with value: 19.488265991210938 and parameters: {'k': 10, 'hidden_dim': 100, 'lr_adam': 0.02603110152764253}. Best is trial 14 with value: 9.494291305541992.
# Trial 028 | k=5  | hidden_dim=20   | Adam LR=5.74e-02 | h=10: Mean RMSE=4.520617, h=30: Mean RMSE=11.032860, h=60: Mean RMSE=20.602610, h=90: Mean RMSE=29.101004
# [I 2026-07-26 01:13:43,783] Trial 28 finished with value: 29.101003646850586 and parameters: {'k': 5, 'hidden_dim': 20, 'lr_adam': 0.05742762862586993}. Best is trial 14 with value: 9.494291305541992.
# Trial 029 | k=40 | hidden_dim=50   | Adam LR=1.55e-03 | h=10: Mean RMSE=4.929875, h=30: Mean RMSE=8.375804, h=60: Mean RMSE=11.526881, h=90: Mean RMSE=15.229665
# [I 2026-07-26 01:20:23,854] Trial 29 finished with value: 15.22966480255127 and parameters: {'k': 40, 'hidden_dim': 50, 'lr_adam': 0.0015498268880273032}. Best is trial 14 with value: 9.494291305541992.
# Trial 030 | k=30 | hidden_dim=50   | Adam LR=3.48e-03 | h=10: Mean RMSE=4.206658, h=30: Mean RMSE=7.166805, h=60: Mean RMSE=10.240325, h=90: Mean RMSE=13.884128
# [I 2026-07-26 01:27:01,287] Trial 30 finished with value: 13.884127616882324 and parameters: {'k': 30, 'hidden_dim': 50, 'lr_adam': 0.003478555009114041}. Best is trial 14 with value: 9.494291305541992.
# Trial 031 | k=50 | hidden_dim=100  | Adam LR=5.61e-02 | h=10: Mean RMSE=3.761729, h=30: Mean RMSE=6.316366, h=60: Mean RMSE=8.380108, h=90: Mean RMSE=10.553992
# [I 2026-07-26 01:33:38,327] Trial 31 finished with value: 10.55399227142334 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.05607120732597447}. Best is trial 14 with value: 9.494291305541992.
# Trial 032 | k=20 | hidden_dim=100  | Adam LR=3.88e-02 | h=10: Mean RMSE=3.987701, h=30: Mean RMSE=8.014185, h=60: Mean RMSE=13.058329, h=90: Mean RMSE=19.125645
# [I 2026-07-26 01:39:52,029] Trial 32 finished with value: 19.12564468383789 and parameters: {'k': 20, 'hidden_dim': 100, 'lr_adam': 0.03876104513862619}. Best is trial 14 with value: 9.494291305541992.
# Trial 033 | k=50 | hidden_dim=100  | Adam LR=6.62e-02 | h=10: Mean RMSE=3.690458, h=30: Mean RMSE=6.217343, h=60: Mean RMSE=8.298265, h=90: Mean RMSE=10.362766
# [I 2026-07-26 01:46:30,493] Trial 33 finished with value: 10.36276626586914 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.06617769065821445}. Best is trial 14 with value: 9.494291305541992.
# Trial 034 | k=50 | hidden_dim=100  | Adam LR=6.77e-02 | h=10: Mean RMSE=3.770585, h=30: Mean RMSE=6.383749, h=60: Mean RMSE=8.462072, h=90: Mean RMSE=11.027419
# [I 2026-07-26 01:53:07,779] Trial 34 finished with value: 11.027419090270996 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.06769147684935664}. Best is trial 14 with value: 9.494291305541992.
# Trial 035 | k=10 | hidden_dim=100  | Adam LR=2.08e-02 | h=10: Mean RMSE=5.023158, h=30: Mean RMSE=14.608356, h=60: Mean RMSE=36.265736, h=90: Mean RMSE=73.866577
# [I 2026-07-26 01:59:15,632] Trial 35 finished with value: 73.8665771484375 and parameters: {'k': 10, 'hidden_dim': 100, 'lr_adam': 0.020841491991590945}. Best is trial 14 with value: 9.494291305541992.
# Trial 036 | k=50 | hidden_dim=20   | Adam LR=4.46e-02 | h=10: Mean RMSE=3.619237, h=30: Mean RMSE=6.239994, h=60: Mean RMSE=8.449976, h=90: Mean RMSE=10.270209
# [I 2026-07-26 02:05:30,589] Trial 36 finished with value: 10.270209312438965 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.044634343471275865}. Best is trial 14 with value: 9.494291305541992.
# Trial 037 | k=20 | hidden_dim=20   | Adam LR=3.84e-02 | h=10: Mean RMSE=4.005204, h=30: Mean RMSE=8.433381, h=60: Mean RMSE=14.077166, h=90: Mean RMSE=20.371977
# [I 2026-07-26 02:11:44,169] Trial 37 finished with value: 20.371976852416992 and parameters: {'k': 20, 'hidden_dim': 20, 'lr_adam': 0.0383967075996561}. Best is trial 14 with value: 9.494291305541992.
# Trial 038 | k=40 | hidden_dim=20   | Adam LR=1.05e-02 | h=10: Mean RMSE=4.281756, h=30: Mean RMSE=7.621825, h=60: Mean RMSE=10.645827, h=90: Mean RMSE=13.951820
# [I 2026-07-26 02:18:17,412] Trial 38 finished with value: 13.951820373535156 and parameters: {'k': 40, 'hidden_dim': 20, 'lr_adam': 0.010468910967735497}. Best is trial 14 with value: 9.494291305541992.
# Trial 039 | k=5  | hidden_dim=20   | Adam LR=3.96e-04 | h=10: Mean RMSE=4.263940, h=30: Mean RMSE=10.698679, h=60: Mean RMSE=20.807283, h=90: Mean RMSE=29.859156
# [I 2026-07-26 02:24:56,635] Trial 39 finished with value: 29.859155654907227 and parameters: {'k': 5, 'hidden_dim': 20, 'lr_adam': 0.0003960665936551372}. Best is trial 14 with value: 9.494291305541992.
# Trial 040 | k=50 | hidden_dim=20   | Adam LR=1.03e-04 | h=10: Mean RMSE=4.228618, h=30: Mean RMSE=7.312578, h=60: Mean RMSE=9.701047, h=90: Mean RMSE=11.830502
# [I 2026-07-26 02:31:45,549] Trial 40 finished with value: 11.830501556396484 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.00010304111678883815}. Best is trial 14 with value: 9.494291305541992.
# Trial 041 | k=50 | hidden_dim=50   | Adam LR=8.13e-02 | h=10: Mean RMSE=3.760939, h=30: Mean RMSE=6.415001, h=60: Mean RMSE=8.886932, h=90: Mean RMSE=11.859195
# [I 2026-07-26 02:38:00,558] Trial 41 finished with value: 11.8591947555542 and parameters: {'k': 50, 'hidden_dim': 50, 'lr_adam': 0.08128049201532611}. Best is trial 14 with value: 9.494291305541992.
# Trial 042 | k=50 | hidden_dim=20   | Adam LR=3.93e-02 | h=10: Mean RMSE=3.633585, h=30: Mean RMSE=6.260959, h=60: Mean RMSE=8.396423, h=90: Mean RMSE=10.235633
# [I 2026-07-26 02:44:05,979] Trial 42 finished with value: 10.23563289642334 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.03927195781311919}. Best is trial 14 with value: 9.494291305541992.
# Trial 043 | k=50 | hidden_dim=20   | Adam LR=4.56e-02 | h=10: Mean RMSE=3.645888, h=30: Mean RMSE=6.262467, h=60: Mean RMSE=8.673083, h=90: Mean RMSE=10.863240
# [I 2026-07-26 02:50:21,416] Trial 43 finished with value: 10.863240242004395 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.045643790667000195}. Best is trial 14 with value: 9.494291305541992.
# Trial 044 | k=50 | hidden_dim=20   | Adam LR=2.88e-02 | h=10: Mean RMSE=3.731402, h=30: Mean RMSE=7.116862, h=60: Mean RMSE=10.728490, h=90: Mean RMSE=13.693311
# [I 2026-07-26 02:56:44,850] Trial 44 finished with value: 13.693310737609863 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.028775662734684446}. Best is trial 14 with value: 9.494291305541992.
# Trial 045 | k=50 | hidden_dim=20   | Adam LR=2.04e-02 | h=10: Mean RMSE=3.765649, h=30: Mean RMSE=6.831583, h=60: Mean RMSE=9.872066, h=90: Mean RMSE=12.859752
# [I 2026-07-26 03:03:06,486] Trial 45 finished with value: 12.85975170135498 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.020395250645910128}. Best is trial 14 with value: 9.494291305541992.
# Trial 046 | k=2  | hidden_dim=20   | Adam LR=1.53e-02 | h=10: Mean RMSE=4.846685, h=30: Mean RMSE=12.640650, h=60: Mean RMSE=24.882116, h=90: Mean RMSE=36.289505
# [I 2026-07-26 03:09:33,744] Trial 46 finished with value: 36.28950500488281 and parameters: {'k': 2, 'hidden_dim': 20, 'lr_adam': 0.015254249570033549}. Best is trial 14 with value: 9.494291305541992.
# Trial 047 | k=30 | hidden_dim=20   | Adam LR=4.07e-02 | h=10: Mean RMSE=4.046350, h=30: Mean RMSE=8.136271, h=60: Mean RMSE=11.800488, h=90: Mean RMSE=14.875229
# [I 2026-07-26 03:15:47,181] Trial 47 finished with value: 14.875228881835938 and parameters: {'k': 30, 'hidden_dim': 20, 'lr_adam': 0.04069895877824771}. Best is trial 14 with value: 9.494291305541992.
# Trial 048 | k=50 | hidden_dim=50   | Adam LR=9.83e-02 | h=10: Mean RMSE=3.712991, h=30: Mean RMSE=6.385392, h=60: Mean RMSE=8.726176, h=90: Mean RMSE=11.080948
# [I 2026-07-26 03:22:12,565] Trial 48 finished with value: 11.080947875976562 and parameters: {'k': 50, 'hidden_dim': 50, 'lr_adam': 0.09832336687930132}. Best is trial 14 with value: 9.494291305541992.
# Trial 049 | k=5  | hidden_dim=20   | Adam LR=3.01e-03 | h=10: Mean RMSE=4.251136, h=30: Mean RMSE=10.648758, h=60: Mean RMSE=20.446884, h=90: Mean RMSE=29.378912
# [I 2026-07-26 03:28:42,857] Trial 49 finished with value: 29.3789119720459 and parameters: {'k': 5, 'hidden_dim': 20, 'lr_adam': 0.003008019477020423}. Best is trial 14 with value: 9.494291305541992.
# Trial 050 | k=20 | hidden_dim=20   | Adam LR=7.59e-02 | h=10: Mean RMSE=4.051535, h=30: Mean RMSE=8.710544, h=60: Mean RMSE=14.380814, h=90: Mean RMSE=20.121387
# [I 2026-07-26 03:34:57,266] Trial 50 finished with value: 20.121387481689453 and parameters: {'k': 20, 'hidden_dim': 20, 'lr_adam': 0.07594865004651134}. Best is trial 14 with value: 9.494291305541992.
# Trial 051 | k=50 | hidden_dim=100  | Adam LR=4.81e-02 | h=10: Mean RMSE=3.729381, h=30: Mean RMSE=6.127656, h=60: Mean RMSE=7.845503, h=90: Mean RMSE=9.475527
# [I 2026-07-26 03:41:29,970] Trial 51 finished with value: 9.475526809692383 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04810015311077473}. Best is trial 51 with value: 9.475526809692383.
# Trial 052 | k=50 | hidden_dim=100  | Adam LR=4.94e-02 | h=10: Mean RMSE=3.773736, h=30: Mean RMSE=6.267732, h=60: Mean RMSE=8.135328, h=90: Mean RMSE=10.170732
# [I 2026-07-26 03:48:00,140] Trial 52 finished with value: 10.170731544494629 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04936771194940777}. Best is trial 51 with value: 9.475526809692383.
# Trial 053 | k=50 | hidden_dim=100  | Adam LR=3.03e-02 | h=10: Mean RMSE=3.868468, h=30: Mean RMSE=6.628464, h=60: Mean RMSE=9.167962, h=90: Mean RMSE=11.721784
# [I 2026-07-26 03:54:28,751] Trial 53 finished with value: 11.721783638000488 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.030325576358634736}. Best is trial 51 with value: 9.475526809692383.
# Trial 054 | k=50 | hidden_dim=100  | Adam LR=5.34e-02 | h=10: Mean RMSE=3.791109, h=30: Mean RMSE=6.299701, h=60: Mean RMSE=8.199591, h=90: Mean RMSE=10.489273
# [I 2026-07-26 04:01:03,030] Trial 54 finished with value: 10.489273071289062 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.05341461751095508}. Best is trial 51 with value: 9.475526809692383.
# Trial 055 | k=50 | hidden_dim=100  | Adam LR=2.23e-02 | h=10: Mean RMSE=3.977951, h=30: Mean RMSE=6.769600, h=60: Mean RMSE=8.882550, h=90: Mean RMSE=10.770961
# [I 2026-07-26 04:07:29,881] Trial 55 finished with value: 10.770960807800293 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.022328680218924427}. Best is trial 51 with value: 9.475526809692383.
# Trial 056 | k=50 | hidden_dim=100  | Adam LR=8.14e-02 | h=10: Mean RMSE=3.750910, h=30: Mean RMSE=6.389934, h=60: Mean RMSE=8.917356, h=90: Mean RMSE=12.067544
# [I 2026-07-26 04:14:11,511] Trial 56 finished with value: 12.067543983459473 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.08138293247476867}. Best is trial 51 with value: 9.475526809692383.
# Trial 057 | k=50 | hidden_dim=100  | Adam LR=3.39e-02 | h=10: Mean RMSE=3.716019, h=30: Mean RMSE=6.141631, h=60: Mean RMSE=8.062827, h=90: Mean RMSE=9.996008
# [I 2026-07-26 04:20:31,639] Trial 57 finished with value: 9.996007919311523 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.033859175597599094}. Best is trial 51 with value: 9.475526809692383.
# Trial 058 | k=50 | hidden_dim=100  | Adam LR=1.37e-02 | h=10: Mean RMSE=3.952129, h=30: Mean RMSE=6.730708, h=60: Mean RMSE=8.954618, h=90: Mean RMSE=11.119435
# [I 2026-07-26 04:26:51,068] Trial 58 finished with value: 11.11943531036377 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.013729847665806837}. Best is trial 51 with value: 9.475526809692383.
# Trial 059 | k=10 | hidden_dim=100  | Adam LR=5.72e-03 | h=10: Mean RMSE=4.419750, h=30: Mean RMSE=9.222372, h=60: Mean RMSE=15.641446, h=90: Mean RMSE=22.219692
# [I 2026-07-26 04:33:18,248] Trial 59 finished with value: 22.21969223022461 and parameters: {'k': 10, 'hidden_dim': 100, 'lr_adam': 0.0057162059421541215}. Best is trial 51 with value: 9.475526809692383.
# Trial 060 | k=40 | hidden_dim=100  | Adam LR=3.41e-02 | h=10: Mean RMSE=3.989090, h=30: Mean RMSE=7.048075, h=60: Mean RMSE=9.799417, h=90: Mean RMSE=12.886627
# [I 2026-07-26 04:39:43,205] Trial 60 finished with value: 12.886627197265625 and parameters: {'k': 40, 'hidden_dim': 100, 'lr_adam': 0.0340784775735466}. Best is trial 51 with value: 9.475526809692383.
# Trial 061 | k=50 | hidden_dim=100  | Adam LR=4.96e-02 | h=10: Mean RMSE=3.782283, h=30: Mean RMSE=6.373296, h=60: Mean RMSE=8.321459, h=90: Mean RMSE=10.668187
# [I 2026-07-26 04:46:10,754] Trial 61 finished with value: 10.668187141418457 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04956540510236771}. Best is trial 51 with value: 9.475526809692383.
# Trial 062 | k=50 | hidden_dim=100  | Adam LR=2.62e-02 | h=10: Mean RMSE=3.893649, h=30: Mean RMSE=6.526491, h=60: Mean RMSE=8.361370, h=90: Mean RMSE=10.375566
# [I 2026-07-26 04:52:35,140] Trial 62 finished with value: 10.375565528869629 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.026177680749501917}. Best is trial 51 with value: 9.475526809692383.
# Trial 063 | k=50 | hidden_dim=100  | Adam LR=7.63e-02 | h=10: Mean RMSE=3.737180, h=30: Mean RMSE=6.327775, h=60: Mean RMSE=8.533072, h=90: Mean RMSE=11.258921
# [I 2026-07-26 04:59:16,733] Trial 63 finished with value: 11.258920669555664 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.07629619603493829}. Best is trial 51 with value: 9.475526809692383.
# Trial 064 | k=2  | hidden_dim=100  | Adam LR=5.49e-02 | h=10: Mean RMSE=5.012642, h=30: Mean RMSE=13.119769, h=60: Mean RMSE=24.853195, h=90: Mean RMSE=35.472118
# [I 2026-07-26 05:05:30,402] Trial 64 finished with value: 35.47211837768555 and parameters: {'k': 2, 'hidden_dim': 100, 'lr_adam': 0.05489847747941514}. Best is trial 51 with value: 9.475526809692383.
# Trial 065 | k=30 | hidden_dim=100  | Adam LR=3.64e-02 | h=10: Mean RMSE=3.960097, h=30: Mean RMSE=7.241080, h=60: Mean RMSE=10.340456, h=90: Mean RMSE=14.702963
# [I 2026-07-26 05:11:43,561] Trial 65 finished with value: 14.702962875366211 and parameters: {'k': 30, 'hidden_dim': 100, 'lr_adam': 0.03639759750562355}. Best is trial 51 with value: 9.475526809692383.
# Trial 066 | k=50 | hidden_dim=100  | Adam LR=6.30e-02 | h=10: Mean RMSE=3.822521, h=30: Mean RMSE=6.453401, h=60: Mean RMSE=8.771422, h=90: Mean RMSE=11.858212
# [I 2026-07-26 05:18:18,716] Trial 66 finished with value: 11.8582124710083 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.06300905884097631}. Best is trial 51 with value: 9.475526809692383.
# Trial 067 | k=50 | hidden_dim=100  | Adam LR=1.71e-02 | h=10: Mean RMSE=3.967516, h=30: Mean RMSE=6.710096, h=60: Mean RMSE=8.925545, h=90: Mean RMSE=11.065366
# [I 2026-07-26 05:24:40,123] Trial 67 finished with value: 11.0653657913208 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.017109719372413137}. Best is trial 51 with value: 9.475526809692383.
# Trial 068 | k=50 | hidden_dim=50   | Adam LR=4.96e-02 | h=10: Mean RMSE=3.650622, h=30: Mean RMSE=6.157006, h=60: Mean RMSE=8.339998, h=90: Mean RMSE=10.683063
# [I 2026-07-26 05:30:53,850] Trial 68 finished with value: 10.683062553405762 and parameters: {'k': 50, 'hidden_dim': 50, 'lr_adam': 0.04961751208664862}. Best is trial 51 with value: 9.475526809692383.
# Trial 069 | k=50 | hidden_dim=100  | Adam LR=7.27e-04 | h=10: Mean RMSE=5.427357, h=30: Mean RMSE=8.648805, h=60: Mean RMSE=12.114058, h=90: Mean RMSE=16.237213
# [I 2026-07-26 05:37:35,996] Trial 69 finished with value: 16.237213134765625 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.0007274715797197102}. Best is trial 51 with value: 9.475526809692383.
# Trial 070 | k=5  | hidden_dim=100  | Adam LR=3.06e-02 | h=10: Mean RMSE=4.436446, h=30: Mean RMSE=11.298065, h=60: Mean RMSE=21.959354, h=90: Mean RMSE=32.075401
# [I 2026-07-26 05:43:44,034] Trial 70 finished with value: 32.075401306152344 and parameters: {'k': 5, 'hidden_dim': 100, 'lr_adam': 0.03056925401923106}. Best is trial 51 with value: 9.475526809692383.
# Trial 071 | k=50 | hidden_dim=20   | Adam LR=4.27e-02 | h=10: Mean RMSE=3.715186, h=30: Mean RMSE=6.593860, h=60: Mean RMSE=9.309459, h=90: Mean RMSE=12.083540
# [I 2026-07-26 05:49:57,296] Trial 71 finished with value: 12.083539962768555 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.04272768652125266}. Best is trial 51 with value: 9.475526809692383.
# Trial 072 | k=50 | hidden_dim=20   | Adam LR=8.71e-02 | h=10: Mean RMSE=3.657254, h=30: Mean RMSE=6.299635, h=60: Mean RMSE=8.478231, h=90: Mean RMSE=10.532433
# [I 2026-07-26 05:56:13,673] Trial 72 finished with value: 10.532432556152344 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.08710568920361936}. Best is trial 51 with value: 9.475526809692383.
# Trial 073 | k=50 | hidden_dim=20   | Adam LR=2.32e-02 | h=10: Mean RMSE=3.795089, h=30: Mean RMSE=6.954944, h=60: Mean RMSE=10.163168, h=90: Mean RMSE=12.961557
# [I 2026-07-26 06:02:40,064] Trial 73 finished with value: 12.961557388305664 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.023203246664140354}. Best is trial 51 with value: 9.475526809692383.
# Trial 074 | k=50 | hidden_dim=100  | Adam LR=4.52e-02 | h=10: Mean RMSE=3.678870, h=30: Mean RMSE=6.114023, h=60: Mean RMSE=8.024094, h=90: Mean RMSE=9.705617
# [I 2026-07-26 06:09:16,028] Trial 74 finished with value: 9.70561695098877 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04517431432073299}. Best is trial 51 with value: 9.475526809692383.
# Trial 075 | k=20 | hidden_dim=100  | Adam LR=7.00e-02 | h=10: Mean RMSE=3.884288, h=30: Mean RMSE=7.571898, h=60: Mean RMSE=12.187562, h=90: Mean RMSE=18.119812
# [I 2026-07-26 06:15:28,495] Trial 75 finished with value: 18.11981201171875 and parameters: {'k': 20, 'hidden_dim': 100, 'lr_adam': 0.0699530876441823}. Best is trial 51 with value: 9.475526809692383.
# Trial 076 | k=50 | hidden_dim=100  | Adam LR=3.32e-02 | h=10: Mean RMSE=3.767133, h=30: Mean RMSE=6.268159, h=60: Mean RMSE=8.148767, h=90: Mean RMSE=10.104246
# [I 2026-07-26 06:21:52,998] Trial 76 finished with value: 10.104246139526367 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.03323754395664611}. Best is trial 51 with value: 9.475526809692383.
# Trial 077 | k=50 | hidden_dim=100  | Adam LR=1.31e-02 | h=10: Mean RMSE=4.054217, h=30: Mean RMSE=6.882406, h=60: Mean RMSE=9.041788, h=90: Mean RMSE=11.435828
# [I 2026-07-26 06:28:07,911] Trial 77 finished with value: 11.43582820892334 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.01305873473544238}. Best is trial 51 with value: 9.475526809692383.
# Trial 078 | k=10 | hidden_dim=100  | Adam LR=3.53e-02 | h=10: Mean RMSE=4.304769, h=30: Mean RMSE=9.372005, h=60: Mean RMSE=16.689180, h=90: Mean RMSE=24.662571
# [I 2026-07-26 06:34:16,743] Trial 78 finished with value: 24.66257095336914 and parameters: {'k': 10, 'hidden_dim': 100, 'lr_adam': 0.0352624517690549}. Best is trial 51 with value: 9.475526809692383.
# Trial 079 | k=50 | hidden_dim=100  | Adam LR=1.99e-02 | h=10: Mean RMSE=4.004790, h=30: Mean RMSE=6.979182, h=60: Mean RMSE=9.361959, h=90: Mean RMSE=11.533758
# [I 2026-07-26 06:40:36,648] Trial 79 finished with value: 11.533758163452148 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.019937961381803464}. Best is trial 51 with value: 9.475526809692383.
# Trial 080 | k=50 | hidden_dim=100  | Adam LR=2.62e-02 | h=10: Mean RMSE=3.907528, h=30: Mean RMSE=6.626896, h=60: Mean RMSE=8.783922, h=90: Mean RMSE=10.919085
# [I 2026-07-26 06:46:59,018] Trial 80 finished with value: 10.919084548950195 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.02623748567801711}. Best is trial 51 with value: 9.475526809692383.
# Trial 081 | k=50 | hidden_dim=100  | Adam LR=5.42e-02 | h=10: Mean RMSE=3.755042, h=30: Mean RMSE=6.282294, h=60: Mean RMSE=8.269485, h=90: Mean RMSE=10.544549
# [I 2026-07-26 06:53:33,267] Trial 81 finished with value: 10.544548988342285 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.054159305745619286}. Best is trial 51 with value: 9.475526809692383.
# Trial 082 | k=40 | hidden_dim=100  | Adam LR=4.24e-02 | h=10: Mean RMSE=3.860049, h=30: Mean RMSE=6.748808, h=60: Mean RMSE=9.143568, h=90: Mean RMSE=12.103559
# [I 2026-07-26 07:00:02,440] Trial 82 finished with value: 12.103559494018555 and parameters: {'k': 40, 'hidden_dim': 100, 'lr_adam': 0.04244584275415178}. Best is trial 51 with value: 9.475526809692383.
# Trial 083 | k=50 | hidden_dim=100  | Adam LR=5.74e-02 | h=10: Mean RMSE=3.808995, h=30: Mean RMSE=6.415961, h=60: Mean RMSE=8.361261, h=90: Mean RMSE=10.491357
# [I 2026-07-26 07:06:35,696] Trial 83 finished with value: 10.49135684967041 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.057377641305030674}. Best is trial 51 with value: 9.475526809692383.
# Trial 084 | k=50 | hidden_dim=100  | Adam LR=6.75e-02 | h=10: Mean RMSE=3.746663, h=30: Mean RMSE=6.359506, h=60: Mean RMSE=8.599432, h=90: Mean RMSE=11.592947
# [I 2026-07-26 07:13:14,510] Trial 84 finished with value: 11.592947006225586 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.06747801251522959}. Best is trial 51 with value: 9.475526809692383.
# Trial 085 | k=2  | hidden_dim=50   | Adam LR=3.32e-02 | h=10: Mean RMSE=4.963606, h=30: Mean RMSE=12.719831, h=60: Mean RMSE=24.215414, h=90: Mean RMSE=34.558510
# [I 2026-07-26 07:19:13,673] Trial 85 finished with value: 34.558509826660156 and parameters: {'k': 2, 'hidden_dim': 50, 'lr_adam': 0.033160054438840396}. Best is trial 51 with value: 9.475526809692383.
# Trial 086 | k=30 | hidden_dim=100  | Adam LR=9.63e-02 | h=10: Mean RMSE=4.024712, h=30: Mean RMSE=7.547295, h=60: Mean RMSE=10.512993, h=90: Mean RMSE=13.968000
# [I 2026-07-26 07:25:35,259] Trial 86 finished with value: 13.968000411987305 and parameters: {'k': 30, 'hidden_dim': 100, 'lr_adam': 0.09629927714794415}. Best is trial 51 with value: 9.475526809692383.
# Trial 087 | k=50 | hidden_dim=100  | Adam LR=4.76e-02 | h=10: Mean RMSE=3.693521, h=30: Mean RMSE=6.140617, h=60: Mean RMSE=7.991570, h=90: Mean RMSE=10.002075
# [I 2026-07-26 07:32:03,793] Trial 87 finished with value: 10.0020751953125 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.047569875354635104}. Best is trial 51 with value: 9.475526809692383.
# Trial 088 | k=50 | hidden_dim=100  | Adam LR=4.51e-02 | h=10: Mean RMSE=3.686866, h=30: Mean RMSE=6.145953, h=60: Mean RMSE=7.935561, h=90: Mean RMSE=9.656945
# [I 2026-07-26 07:38:30,813] Trial 88 finished with value: 9.65694522857666 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.045066381239698715}. Best is trial 51 with value: 9.475526809692383.
# Trial 089 | k=50 | hidden_dim=100  | Adam LR=4.77e-02 | h=10: Mean RMSE=3.757160, h=30: Mean RMSE=6.362263, h=60: Mean RMSE=8.461557, h=90: Mean RMSE=10.854153
# [I 2026-07-26 07:45:03,950] Trial 89 finished with value: 10.85415267944336 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04770227917601603}. Best is trial 51 with value: 9.475526809692383.
# Trial 090 | k=50 | hidden_dim=100  | Adam LR=2.76e-02 | h=10: Mean RMSE=3.860323, h=30: Mean RMSE=6.605025, h=60: Mean RMSE=8.780922, h=90: Mean RMSE=10.990366
# [I 2026-07-26 07:51:32,414] Trial 90 finished with value: 10.990365982055664 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.027607842232732466}. Best is trial 51 with value: 9.475526809692383.
# Trial 091 | k=50 | hidden_dim=100  | Adam LR=3.96e-02 | h=10: Mean RMSE=3.743090, h=30: Mean RMSE=6.331494, h=60: Mean RMSE=8.512073, h=90: Mean RMSE=10.816389
# [I 2026-07-26 07:57:55,297] Trial 91 finished with value: 10.816389083862305 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.03956183559759552}. Best is trial 51 with value: 9.475526809692383.
# Trial 092 | k=50 | hidden_dim=100  | Adam LR=3.70e-02 | h=10: Mean RMSE=3.803362, h=30: Mean RMSE=6.473428, h=60: Mean RMSE=8.625552, h=90: Mean RMSE=10.719687
# [I 2026-07-26 08:04:13,851] Trial 92 finished with value: 10.719686508178711 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.036950315076336795}. Best is trial 51 with value: 9.475526809692383.
# Trial 093 | k=50 | hidden_dim=100  | Adam LR=4.61e-02 | h=10: Mean RMSE=3.726327, h=30: Mean RMSE=6.194199, h=60: Mean RMSE=8.222240, h=90: Mean RMSE=10.266475
# [I 2026-07-26 08:10:41,657] Trial 93 finished with value: 10.266474723815918 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04606693304377091}. Best is trial 51 with value: 9.475526809692383.
# Trial 094 | k=50 | hidden_dim=100  | Adam LR=3.17e-02 | h=10: Mean RMSE=3.816737, h=30: Mean RMSE=6.378380, h=60: Mean RMSE=8.389771, h=90: Mean RMSE=10.440605
# [I 2026-07-26 08:17:08,385] Trial 94 finished with value: 10.440605163574219 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.03168009508444343}. Best is trial 51 with value: 9.475526809692383.
# Trial 095 | k=50 | hidden_dim=100  | Adam LR=1.75e-03 | h=10: Mean RMSE=5.327718, h=30: Mean RMSE=9.091351, h=60: Mean RMSE=12.357828, h=90: Mean RMSE=15.282086
# [I 2026-07-26 08:23:45,137] Trial 95 finished with value: 15.282086372375488 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.0017539642607007646}. Best is trial 51 with value: 9.475526809692383.
# Trial 096 | k=5  | hidden_dim=100  | Adam LR=5.90e-02 | h=10: Mean RMSE=4.680739, h=30: Mean RMSE=12.116184, h=60: Mean RMSE=23.780855, h=90: Mean RMSE=35.300270
# [I 2026-07-26 08:30:02,988] Trial 96 finished with value: 35.300270080566406 and parameters: {'k': 5, 'hidden_dim': 100, 'lr_adam': 0.05900237270891148}. Best is trial 51 with value: 9.475526809692383.
# Trial 097 | k=50 | hidden_dim=100  | Adam LR=1.91e-02 | h=10: Mean RMSE=4.056509, h=30: Mean RMSE=6.701999, h=60: Mean RMSE=8.901057, h=90: Mean RMSE=10.965717
# [I 2026-07-26 08:36:33,333] Trial 97 finished with value: 10.965717315673828 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.019096844191531646}. Best is trial 51 with value: 9.475526809692383.
# Trial 098 | k=20 | hidden_dim=50   | Adam LR=2.50e-02 | h=10: Mean RMSE=4.041169, h=30: Mean RMSE=8.431358, h=60: Mean RMSE=14.256086, h=90: Mean RMSE=20.670099
# [I 2026-07-26 08:42:44,571] Trial 98 finished with value: 20.67009925842285 and parameters: {'k': 20, 'hidden_dim': 50, 'lr_adam': 0.025006666532608354}. Best is trial 51 with value: 9.475526809692383.
# Trial 099 | k=50 | hidden_dim=20   | Adam LR=7.38e-02 | h=10: Mean RMSE=3.644596, h=30: Mean RMSE=6.308744, h=60: Mean RMSE=8.817897, h=90: Mean RMSE=11.411314
# [I 2026-07-26 08:49:02,263] Trial 99 finished with value: 11.411314010620117 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.07376105089809144}. Best is trial 51 with value: 9.475526809692383.
# Trial 100 | k=10 | hidden_dim=100  | Adam LR=4.93e-02 | h=10: Mean RMSE=4.240586, h=30: Mean RMSE=9.335193, h=60: Mean RMSE=17.667341, h=90: Mean RMSE=26.150501
# [I 2026-07-26 08:55:04,461] Trial 100 finished with value: 26.150501251220703 and parameters: {'k': 10, 'hidden_dim': 100, 'lr_adam': 0.049302322401225916}. Best is trial 51 with value: 9.475526809692383.
# Trial 101 | k=50 | hidden_dim=100  | Adam LR=8.69e-02 | h=10: Mean RMSE=3.780667, h=30: Mean RMSE=6.315620, h=60: Mean RMSE=8.326349, h=90: Mean RMSE=10.941156
# [I 2026-07-26 08:56:38,102] Trial 101 finished with value: 10.941156387329102 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.08690651062255292}. Best is trial 51 with value: 9.475526809692383.
# Trial 102 | k=50 | hidden_dim=100  | Adam LR=6.30e-02 | h=10: Mean RMSE=3.743242, h=30: Mean RMSE=6.168777, h=60: Mean RMSE=8.190341, h=90: Mean RMSE=11.083487
# [I 2026-07-26 08:58:03,671] Trial 102 finished with value: 11.083486557006836 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.06299987654202387}. Best is trial 51 with value: 9.475526809692383.
# Trial 103 | k=50 | hidden_dim=100  | Adam LR=4.02e-02 | h=10: Mean RMSE=3.705157, h=30: Mean RMSE=6.183775, h=60: Mean RMSE=8.211986, h=90: Mean RMSE=10.139354
# [I 2026-07-26 08:59:11,076] Trial 103 finished with value: 10.13935375213623 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.040194837797482764}. Best is trial 51 with value: 9.475526809692383.
# Trial 104 | k=50 | hidden_dim=100  | Adam LR=4.04e-02 | h=10: Mean RMSE=3.722554, h=30: Mean RMSE=6.229444, h=60: Mean RMSE=8.067212, h=90: Mean RMSE=9.686445
# [I 2026-07-26 09:00:21,470] Trial 104 finished with value: 9.686445236206055 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04036000319811111}. Best is trial 51 with value: 9.475526809692383.
# Trial 105 | k=50 | hidden_dim=100  | Adam LR=4.28e-02 | h=10: Mean RMSE=3.711510, h=30: Mean RMSE=6.280885, h=60: Mean RMSE=8.380511, h=90: Mean RMSE=10.678204
# [I 2026-07-26 09:01:35,494] Trial 105 finished with value: 10.678203582763672 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04281211314378525}. Best is trial 51 with value: 9.475526809692383.
# Trial 106 | k=40 | hidden_dim=100  | Adam LR=2.95e-02 | h=10: Mean RMSE=3.973712, h=30: Mean RMSE=6.964030, h=60: Mean RMSE=9.568731, h=90: Mean RMSE=12.760477
# [I 2026-07-26 09:02:41,235] Trial 106 finished with value: 12.760477066040039 and parameters: {'k': 40, 'hidden_dim': 100, 'lr_adam': 0.029481668007948172}. Best is trial 51 with value: 9.475526809692383.
# Trial 107 | k=50 | hidden_dim=100  | Adam LR=2.32e-02 | h=10: Mean RMSE=3.895114, h=30: Mean RMSE=6.704620, h=60: Mean RMSE=9.291306, h=90: Mean RMSE=11.862684
# [I 2026-07-26 09:03:54,121] Trial 107 finished with value: 11.86268424987793 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.023166282648747823}. Best is trial 51 with value: 9.475526809692383.
# Trial 108 | k=50 | hidden_dim=100  | Adam LR=5.22e-02 | h=10: Mean RMSE=3.778482, h=30: Mean RMSE=6.292968, h=60: Mean RMSE=8.282804, h=90: Mean RMSE=10.475808
# [I 2026-07-26 09:05:15,747] Trial 108 finished with value: 10.475808143615723 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.052188321464665004}. Best is trial 51 with value: 9.475526809692383.
# Trial 109 | k=2  | hidden_dim=100  | Adam LR=3.97e-02 | h=10: Mean RMSE=4.847894, h=30: Mean RMSE=12.616110, h=60: Mean RMSE=24.442924, h=90: Mean RMSE=34.933140
# [I 2026-07-26 09:06:14,763] Trial 109 finished with value: 34.93313980102539 and parameters: {'k': 2, 'hidden_dim': 100, 'lr_adam': 0.039657564998529085}. Best is trial 51 with value: 9.475526809692383.
# Trial 110 | k=50 | hidden_dim=100  | Adam LR=3.34e-02 | h=10: Mean RMSE=3.827913, h=30: Mean RMSE=6.455684, h=60: Mean RMSE=8.616911, h=90: Mean RMSE=10.782202
# [I 2026-07-26 09:07:33,448] Trial 110 finished with value: 10.782201766967773 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.033383137601386455}. Best is trial 51 with value: 9.475526809692383.
# Trial 111 | k=50 | hidden_dim=20   | Adam LR=3.89e-02 | h=10: Mean RMSE=3.665796, h=30: Mean RMSE=6.398850, h=60: Mean RMSE=8.838611, h=90: Mean RMSE=10.913719
# [I 2026-07-26 09:08:36,454] Trial 111 finished with value: 10.913719177246094 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.038885402635828535}. Best is trial 51 with value: 9.475526809692383.
# Trial 112 | k=50 | hidden_dim=100  | Adam LR=4.72e-02 | h=10: Mean RMSE=3.792104, h=30: Mean RMSE=6.265062, h=60: Mean RMSE=8.292593, h=90: Mean RMSE=10.700552
# [I 2026-07-26 09:09:51,601] Trial 112 finished with value: 10.700551986694336 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.047242319380574174}. Best is trial 51 with value: 9.475526809692383.
# Trial 113 | k=50 | hidden_dim=100  | Adam LR=5.92e-02 | h=10: Mean RMSE=3.769653, h=30: Mean RMSE=6.328314, h=60: Mean RMSE=8.352743, h=90: Mean RMSE=10.785484
# [I 2026-07-26 09:11:13,340] Trial 113 finished with value: 10.785484313964844 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.059194158712633484}. Best is trial 51 with value: 9.475526809692383.
# Trial 114 | k=50 | hidden_dim=100  | Adam LR=3.59e-02 | h=10: Mean RMSE=3.776054, h=30: Mean RMSE=6.367414, h=60: Mean RMSE=8.572128, h=90: Mean RMSE=11.121011
# [I 2026-07-26 09:12:23,220] Trial 114 finished with value: 11.121010780334473 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.03587573509293109}. Best is trial 51 with value: 9.475526809692383.
# Trial 115 | k=30 | hidden_dim=20   | Adam LR=6.73e-02 | h=10: Mean RMSE=4.086110, h=30: Mean RMSE=8.383269, h=60: Mean RMSE=12.662889, h=90: Mean RMSE=16.596455
# [I 2026-07-26 09:13:22,973] Trial 115 finished with value: 16.596454620361328 and parameters: {'k': 30, 'hidden_dim': 20, 'lr_adam': 0.06725715200724407}. Best is trial 51 with value: 9.475526809692383.
# Trial 116 | k=50 | hidden_dim=100  | Adam LR=8.15e-03 | h=10: Mean RMSE=4.173327, h=30: Mean RMSE=7.192007, h=60: Mean RMSE=9.524999, h=90: Mean RMSE=11.875189
# [I 2026-07-26 09:14:36,284] Trial 116 finished with value: 11.875188827514648 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.008145531552722024}. Best is trial 51 with value: 9.475526809692383.
# Trial 117 | k=50 | hidden_dim=100  | Adam LR=2.82e-02 | h=10: Mean RMSE=3.860144, h=30: Mean RMSE=6.387125, h=60: Mean RMSE=8.134302, h=90: Mean RMSE=9.913791
# [I 2026-07-26 09:15:49,232] Trial 117 finished with value: 9.913790702819824 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.028219942085204158}. Best is trial 51 with value: 9.475526809692383.
# Trial 118 | k=50 | hidden_dim=100  | Adam LR=2.72e-02 | h=10: Mean RMSE=3.911200, h=30: Mean RMSE=6.541850, h=60: Mean RMSE=8.359105, h=90: Mean RMSE=10.167685
# [I 2026-07-26 09:17:00,894] Trial 118 finished with value: 10.167684555053711 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.027219651911097965}. Best is trial 51 with value: 9.475526809692383.
# Trial 119 | k=50 | hidden_dim=100  | Adam LR=3.01e-02 | h=10: Mean RMSE=3.882339, h=30: Mean RMSE=6.532075, h=60: Mean RMSE=8.413893, h=90: Mean RMSE=10.243689
# [I 2026-07-26 09:18:22,798] Trial 119 finished with value: 10.243688583374023 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.030085696667356502}. Best is trial 51 with value: 9.475526809692383.
# Trial 120 | k=50 | hidden_dim=100  | Adam LR=2.17e-02 | h=10: Mean RMSE=3.960347, h=30: Mean RMSE=6.572520, h=60: Mean RMSE=8.619059, h=90: Mean RMSE=10.638188
# [I 2026-07-26 09:19:34,944] Trial 120 finished with value: 10.638188362121582 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.021654294939305995}. Best is trial 51 with value: 9.475526809692383.
# Trial 121 | k=50 | hidden_dim=100  | Adam LR=2.71e-02 | h=10: Mean RMSE=3.912579, h=30: Mean RMSE=6.564735, h=60: Mean RMSE=8.480505, h=90: Mean RMSE=10.292219
# [I 2026-07-26 09:20:46,398] Trial 121 finished with value: 10.292219161987305 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.027082296414149543}. Best is trial 51 with value: 9.475526809692383.
# Trial 122 | k=50 | hidden_dim=100  | Adam LR=4.25e-02 | h=10: Mean RMSE=3.799927, h=30: Mean RMSE=6.465024, h=60: Mean RMSE=8.659503, h=90: Mean RMSE=11.008766
# [I 2026-07-26 09:21:59,124] Trial 122 finished with value: 11.008766174316406 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.042482068100785544}. Best is trial 51 with value: 9.475526809692383.
# Trial 123 | k=50 | hidden_dim=100  | Adam LR=5.05e-02 | h=10: Mean RMSE=3.697206, h=30: Mean RMSE=6.228969, h=60: Mean RMSE=8.190211, h=90: Mean RMSE=10.307841
# [I 2026-07-26 09:23:18,238] Trial 123 finished with value: 10.307841300964355 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.050471850158666766}. Best is trial 51 with value: 9.475526809692383.
# Trial 124 | k=50 | hidden_dim=100  | Adam LR=3.61e-02 | h=10: Mean RMSE=3.710594, h=30: Mean RMSE=6.206655, h=60: Mean RMSE=8.082515, h=90: Mean RMSE=9.775259
# [I 2026-07-26 09:24:24,366] Trial 124 finished with value: 9.775259017944336 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.036081567417471795}. Best is trial 51 with value: 9.475526809692383.
# Trial 125 | k=5  | hidden_dim=100  | Adam LR=3.30e-02 | h=10: Mean RMSE=4.717608, h=30: Mean RMSE=12.696647, h=60: Mean RMSE=24.828442, h=90: Mean RMSE=36.270882
# [I 2026-07-26 09:25:18,010] Trial 125 finished with value: 36.27088165283203 and parameters: {'k': 5, 'hidden_dim': 100, 'lr_adam': 0.032964609064697885}. Best is trial 51 with value: 9.475526809692383.
# Trial 126 | k=50 | hidden_dim=100  | Adam LR=1.84e-02 | h=10: Mean RMSE=4.039247, h=30: Mean RMSE=6.755029, h=60: Mean RMSE=8.825541, h=90: Mean RMSE=10.584853
# [I 2026-07-26 09:26:29,898] Trial 126 finished with value: 10.584853172302246 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.018397146857617185}. Best is trial 51 with value: 9.475526809692383.
# Trial 127 | k=50 | hidden_dim=100  | Adam LR=2.76e-02 | h=10: Mean RMSE=3.877347, h=30: Mean RMSE=6.586961, h=60: Mean RMSE=8.752451, h=90: Mean RMSE=11.114014
# [I 2026-07-26 09:27:45,866] Trial 127 finished with value: 11.114013671875 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.027627539034359078}. Best is trial 51 with value: 9.475526809692383.
# Trial 128 | k=20 | hidden_dim=50   | Adam LR=1.61e-02 | h=10: Mean RMSE=3.966036, h=30: Mean RMSE=7.797360, h=60: Mean RMSE=13.235896, h=90: Mean RMSE=20.433725
# [I 2026-07-26 09:29:02,083] Trial 128 finished with value: 20.433725357055664 and parameters: {'k': 20, 'hidden_dim': 50, 'lr_adam': 0.01613424241732186}. Best is trial 51 with value: 9.475526809692383.
# Trial 129 | k=50 | hidden_dim=100  | Adam LR=4.45e-03 | h=10: Mean RMSE=4.672273, h=30: Mean RMSE=7.991005, h=60: Mean RMSE=10.585984, h=90: Mean RMSE=13.258191
# [I 2026-07-26 09:30:19,427] Trial 129 finished with value: 13.258191108703613 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.004452485758567133}. Best is trial 51 with value: 9.475526809692383.
# Trial 130 | k=50 | hidden_dim=100  | Adam LR=3.81e-02 | h=10: Mean RMSE=3.746475, h=30: Mean RMSE=6.346791, h=60: Mean RMSE=8.405480, h=90: Mean RMSE=10.387886
# [I 2026-07-26 09:31:26,704] Trial 130 finished with value: 10.387886047363281 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.03813485533978888}. Best is trial 51 with value: 9.475526809692383.
# Trial 131 | k=50 | hidden_dim=100  | Adam LR=4.63e-02 | h=10: Mean RMSE=3.738711, h=30: Mean RMSE=6.364627, h=60: Mean RMSE=8.508680, h=90: Mean RMSE=10.637030
# ...
# Trial 157 | k=5  | hidden_dim=100  | Adam LR=3.04e-02 | h=10: Mean RMSE=5.704031, h=30: Mean RMSE=16.239038, h=60: Mean RMSE=33.693886, h=90: Mean RMSE=60.633400
# [I 2026-07-26 10:04:03,319] Trial 157 finished with value: 60.633399963378906 and parameters: {'k': 5, 'hidden_dim': 100, 'lr_adam': 0.03038864841865319}. Best is trial 51 with value: 9.475526809692383.
# Trial 158 | k=50 | hidden_dim=100  | Adam LR=6.64e-02 | h=10: Mean RMSE=3.713505, h=30: Mean RMSE=6.203504, h=60: Mean RMSE=8.056064, h=90: Mean RMSE=10.212855
# [I 2026-07-26 10:05:28,826] Trial 158 finished with value: 10.212855339050293 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.06643586710042473}. Best is trial 51 with value: 9.475526809692383.
# Trial 159 | k=50 | hidden_dim=100  | Adam LR=3.66e-02 | h=10: Mean RMSE=3.688890, h=30: Mean RMSE=6.163291, h=60: Mean RMSE=7.865070, h=90: Mean RMSE=9.301863
# [I 2026-07-26 10:06:36,085] Trial 159 finished with value: 9.301862716674805 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.03664899529403995}. Best is trial 159 with value: 9.301862716674805.
# Trial 160 | k=20 | hidden_dim=100  | Adam LR=3.96e-02 | h=10: Mean RMSE=4.062952, h=30: Mean RMSE=8.348611, h=60: Mean RMSE=13.450745, h=90: Mean RMSE=19.165592
# [I 2026-07-26 10:07:36,091] Trial 160 finished with value: 19.165592193603516 and parameters: {'k': 20, 'hidden_dim': 100, 'lr_adam': 0.03961307279228171}. Best is trial 159 with value: 9.301862716674805.
# Trial 161 | k=50 | hidden_dim=100  | Adam LR=3.48e-02 | h=10: Mean RMSE=3.746726, h=30: Mean RMSE=6.239976, h=60: Mean RMSE=8.068657, h=90: Mean RMSE=9.919481
# [I 2026-07-26 10:08:46,286] Trial 161 finished with value: 9.91948127746582 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.03478468294491963}. Best is trial 159 with value: 9.301862716674805.
# Trial 162 | k=50 | hidden_dim=100  | Adam LR=4.62e-02 | h=10: Mean RMSE=3.673145, h=30: Mean RMSE=6.107316, h=60: Mean RMSE=7.892735, h=90: Mean RMSE=9.430696
# [I 2026-07-26 10:10:06,052] Trial 162 finished with value: 9.430696487426758 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04619142163913863}. Best is trial 159 with value: 9.301862716674805.
# Trial 163 | k=50 | hidden_dim=100  | Adam LR=3.53e-02 | h=10: Mean RMSE=3.783527, h=30: Mean RMSE=6.359593, h=60: Mean RMSE=8.284525, h=90: Mean RMSE=10.275742
# [I 2026-07-26 10:11:14,618] Trial 163 finished with value: 10.275741577148438 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.03533962757173434}. Best is trial 159 with value: 9.301862716674805.
# Trial 164 | k=50 | hidden_dim=100  | Adam LR=4.52e-02 | h=10: Mean RMSE=3.697326, h=30: Mean RMSE=6.186563, h=60: Mean RMSE=8.050352, h=90: Mean RMSE=9.673693
# [I 2026-07-26 10:12:26,231] Trial 164 finished with value: 9.67369270324707 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04522382162190289}. Best is trial 159 with value: 9.301862716674805.
# Trial 165 | k=50 | hidden_dim=100  | Adam LR=2.89e-02 | h=10: Mean RMSE=3.915273, h=30: Mean RMSE=6.603049, h=60: Mean RMSE=8.819925, h=90: Mean RMSE=11.185001
# [I 2026-07-26 10:13:41,314] Trial 165 finished with value: 11.185001373291016 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.028871177244207392}. Best is trial 159 with value: 9.301862716674805.
# Trial 166 | k=50 | hidden_dim=100  | Adam LR=5.77e-02 | h=10: Mean RMSE=3.819767, h=30: Mean RMSE=6.469644, h=60: Mean RMSE=8.551214, h=90: Mean RMSE=10.948385
# [I 2026-07-26 10:15:02,187] Trial 166 finished with value: 10.948385238647461 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.05771044268514929}. Best is trial 159 with value: 9.301862716674805.
# Trial 167 | k=50 | hidden_dim=100  | Adam LR=2.20e-02 | h=10: Mean RMSE=3.970538, h=30: Mean RMSE=6.746992, h=60: Mean RMSE=9.035039, h=90: Mean RMSE=11.141102
# [I 2026-07-26 10:16:15,766] Trial 167 finished with value: 11.141101837158203 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.021959922437676}. Best is trial 159 with value: 9.301862716674805.
# Trial 168 | k=50 | hidden_dim=100  | Adam LR=4.22e-02 | h=10: Mean RMSE=3.714096, h=30: Mean RMSE=6.182802, h=60: Mean RMSE=7.962189, h=90: Mean RMSE=9.702330
# [I 2026-07-26 10:17:26,437] Trial 168 finished with value: 9.702329635620117 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04223510147056184}. Best is trial 159 with value: 9.301862716674805.
# Trial 169 | k=10 | hidden_dim=100  | Adam LR=4.34e-02 | h=10: Mean RMSE=4.304587, h=30: Mean RMSE=9.719637, h=60: Mean RMSE=18.281284, h=90: Mean RMSE=27.431110
# [I 2026-07-26 10:18:21,330] Trial 169 finished with value: 27.431110382080078 and parameters: {'k': 10, 'hidden_dim': 100, 'lr_adam': 0.04341962466332053}. Best is trial 159 with value: 9.301862716674805.
# Trial 170 | k=50 | hidden_dim=100  | Adam LR=5.19e-02 | h=10: Mean RMSE=3.721830, h=30: Mean RMSE=6.144456, h=60: Mean RMSE=8.088122, h=90: Mean RMSE=10.315264
# [I 2026-07-26 10:19:44,357] Trial 170 finished with value: 10.315263748168945 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.05188048511775411}. Best is trial 159 with value: 9.301862716674805.
# Trial 171 | k=50 | hidden_dim=100  | Adam LR=3.71e-02 | h=10: Mean RMSE=3.808495, h=30: Mean RMSE=6.382611, h=60: Mean RMSE=8.568228, h=90: Mean RMSE=10.924718
# [I 2026-07-26 10:20:59,685] Trial 171 finished with value: 10.924717903137207 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.037114143278727904}. Best is trial 159 with value: 9.301862716674805.
# Trial 172 | k=50 | hidden_dim=100  | Adam LR=3.27e-02 | h=10: Mean RMSE=3.801231, h=30: Mean RMSE=6.406943, h=60: Mean RMSE=8.391141, h=90: Mean RMSE=10.554499
# [I 2026-07-26 10:22:06,406] Trial 172 finished with value: 10.554498672485352 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.03266770126627874}. Best is trial 159 with value: 9.301862716674805.
# Trial 173 | k=50 | hidden_dim=100  | Adam LR=4.18e-02 | h=10: Mean RMSE=3.665963, h=30: Mean RMSE=6.097572, h=60: Mean RMSE=7.956323, h=90: Mean RMSE=9.556597
# [I 2026-07-26 10:23:17,777] Trial 173 finished with value: 9.556596755981445 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04178767018727472}. Best is trial 159 with value: 9.301862716674805.
# Trial 174 | k=50 | hidden_dim=100  | Adam LR=4.22e-02 | h=10: Mean RMSE=3.737411, h=30: Mean RMSE=6.187147, h=60: Mean RMSE=7.698560, h=90: Mean RMSE=8.986952
# [I 2026-07-26 10:24:32,176] Trial 174 finished with value: 8.98695182800293 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04223021555396682}. Best is trial 174 with value: 8.98695182800293.
# Trial 175 | k=50 | hidden_dim=100  | Adam LR=4.32e-02 | h=10: Mean RMSE=3.698828, h=30: Mean RMSE=6.161886, h=60: Mean RMSE=8.024443, h=90: Mean RMSE=9.813693
# [I 2026-07-26 10:25:45,357] Trial 175 finished with value: 9.813693046569824 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04315455183204429}. Best is trial 174 with value: 8.98695182800293.
# Trial 176 | k=50 | hidden_dim=100  | Adam LR=4.53e-02 | h=10: Mean RMSE=3.691397, h=30: Mean RMSE=6.185287, h=60: Mean RMSE=8.146106, h=90: Mean RMSE=10.285551
# [I 2026-07-26 10:26:57,377] Trial 176 finished with value: 10.285551071166992 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04526113549197874}. Best is trial 174 with value: 8.98695182800293.
# Trial 177 | k=40 | hidden_dim=100  | Adam LR=6.04e-02 | h=10: Mean RMSE=3.979443, h=30: Mean RMSE=7.362917, h=60: Mean RMSE=10.263989, h=90: Mean RMSE=12.970861
# [I 2026-07-26 10:28:12,385] Trial 177 finished with value: 12.970861434936523 and parameters: {'k': 40, 'hidden_dim': 100, 'lr_adam': 0.060447435064162336}. Best is trial 174 with value: 8.98695182800293.
# Trial 178 | k=50 | hidden_dim=100  | Adam LR=4.80e-02 | h=10: Mean RMSE=3.748487, h=30: Mean RMSE=6.299537, h=60: Mean RMSE=8.389444, h=90: Mean RMSE=10.453642
# [I 2026-07-26 10:29:33,360] Trial 178 finished with value: 10.453641891479492 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.048026807956458785}. Best is trial 174 with value: 8.98695182800293.
# Trial 179 | k=50 | hidden_dim=100  | Adam LR=4.06e-02 | h=10: Mean RMSE=3.710163, h=30: Mean RMSE=6.223361, h=60: Mean RMSE=8.170872, h=90: Mean RMSE=10.002929
# [I 2026-07-26 10:30:47,373] Trial 179 finished with value: 10.002928733825684 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.040564050259925086}. Best is trial 174 with value: 8.98695182800293.
# Trial 180 | k=2  | hidden_dim=100  | Adam LR=7.81e-02 | h=10: Mean RMSE=4.981261, h=30: Mean RMSE=13.060750, h=60: Mean RMSE=25.280962, h=90: Mean RMSE=36.883598
# [I 2026-07-26 10:31:44,505] Trial 180 finished with value: 36.88359832763672 and parameters: {'k': 2, 'hidden_dim': 100, 'lr_adam': 0.07806409645655794}. Best is trial 174 with value: 8.98695182800293.
# Trial 181 | k=50 | hidden_dim=100  | Adam LR=4.11e-02 | h=10: Mean RMSE=3.730362, h=30: Mean RMSE=6.277081, h=60: Mean RMSE=8.137951, h=90: Mean RMSE=9.872348
# [I 2026-07-26 10:32:55,926] Trial 181 finished with value: 9.872347831726074 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04110846081843285}. Best is trial 174 with value: 8.98695182800293.
# Trial 182 | k=50 | hidden_dim=100  | Adam LR=5.25e-02 | h=10: Mean RMSE=3.867917, h=30: Mean RMSE=6.517750, h=60: Mean RMSE=8.596307, h=90: Mean RMSE=10.895522
# [I 2026-07-26 10:34:16,022] Trial 182 finished with value: 10.895522117614746 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.0524844666338507}. Best is trial 174 with value: 8.98695182800293.
# Trial 183 | k=50 | hidden_dim=100  | Adam LR=4.12e-02 | h=10: Mean RMSE=3.761508, h=30: Mean RMSE=6.382436, h=60: Mean RMSE=8.348170, h=90: Mean RMSE=10.270536
# [I 2026-07-26 10:35:33,161] Trial 183 finished with value: 10.270536422729492 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04121381827580771}. Best is trial 174 with value: 8.98695182800293.
# Trial 184 | k=50 | hidden_dim=100  | Adam LR=5.59e-02 | h=10: Mean RMSE=3.771432, h=30: Mean RMSE=6.254832, h=60: Mean RMSE=8.216311, h=90: Mean RMSE=10.501157
# [I 2026-07-26 10:36:54,902] Trial 184 finished with value: 10.5011568069458 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.05587069849102447}. Best is trial 174 with value: 8.98695182800293.
# Trial 185 | k=50 | hidden_dim=100  | Adam LR=4.76e-02 | h=10: Mean RMSE=3.687507, h=30: Mean RMSE=6.151283, h=60: Mean RMSE=8.047621, h=90: Mean RMSE=10.218788
# [I 2026-07-26 10:38:15,017] Trial 185 finished with value: 10.218788146972656 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04762781030681412}. Best is trial 174 with value: 8.98695182800293.
# Trial 186 | k=50 | hidden_dim=100  | Adam LR=4.17e-02 | h=10: Mean RMSE=3.745088, h=30: Mean RMSE=6.238883, h=60: Mean RMSE=8.071539, h=90: Mean RMSE=9.971393
# [I 2026-07-26 10:39:26,648] Trial 186 finished with value: 9.971392631530762 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.041677718590308145}. Best is trial 174 with value: 8.98695182800293.
# Trial 187 | k=50 | hidden_dim=100  | Adam LR=6.79e-02 | h=10: Mean RMSE=3.730714, h=30: Mean RMSE=6.179942, h=60: Mean RMSE=7.952558, h=90: Mean RMSE=9.954378
# [I 2026-07-26 10:40:54,029] Trial 187 finished with value: 9.954378128051758 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.06791353576043319}. Best is trial 174 with value: 8.98695182800293.
# Trial 188 | k=30 | hidden_dim=100  | Adam LR=3.77e-02 | h=10: Mean RMSE=4.028808, h=30: Mean RMSE=7.189572, h=60: Mean RMSE=9.963418, h=90: Mean RMSE=13.740850
# [I 2026-07-26 10:41:57,883] Trial 188 finished with value: 13.740850448608398 and parameters: {'k': 30, 'hidden_dim': 100, 'lr_adam': 0.037689112703369644}. Best is trial 174 with value: 8.98695182800293.
# Trial 189 | k=50 | hidden_dim=100  | Adam LR=8.77e-04 | h=10: Mean RMSE=5.540103, h=30: Mean RMSE=9.613565, h=60: Mean RMSE=14.210260, h=90: Mean RMSE=19.011454
# [I 2026-07-26 10:43:29,593] Trial 189 finished with value: 19.01145362854004 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.0008772982399967914}. Best is trial 174 with value: 8.98695182800293.
# Trial 190 | k=50 | hidden_dim=50   | Adam LR=5.00e-02 | h=10: Mean RMSE=3.677370, h=30: Mean RMSE=6.152532, h=60: Mean RMSE=8.014631, h=90: Mean RMSE=10.074148
# [I 2026-07-26 10:44:32,835] Trial 190 finished with value: 10.074148178100586 and parameters: {'k': 50, 'hidden_dim': 50, 'lr_adam': 0.05003236869020424}. Best is trial 174 with value: 8.98695182800293.
# Trial 191 | k=50 | hidden_dim=100  | Adam LR=3.44e-02 | h=10: Mean RMSE=3.771692, h=30: Mean RMSE=6.363299, h=60: Mean RMSE=8.513578, h=90: Mean RMSE=10.766973
# [I 2026-07-26 10:45:39,317] Trial 191 finished with value: 10.766973495483398 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.034445451001864906}. Best is trial 174 with value: 8.98695182800293.
# Trial 192 | k=50 | hidden_dim=100  | Adam LR=4.39e-02 | h=10: Mean RMSE=3.726758, h=30: Mean RMSE=6.166345, h=60: Mean RMSE=8.141294, h=90: Mean RMSE=10.305349
# [I 2026-07-26 10:46:50,933] Trial 192 finished with value: 10.305349349975586 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04394819634195407}. Best is trial 174 with value: 8.98695182800293.
# Trial 193 | k=50 | hidden_dim=100  | Adam LR=3.74e-02 | h=10: Mean RMSE=3.787032, h=30: Mean RMSE=6.350307, h=60: Mean RMSE=8.184253, h=90: Mean RMSE=9.998387
# [I 2026-07-26 10:48:04,040] Trial 193 finished with value: 9.998387336730957 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.0374289404059215}. Best is trial 174 with value: 8.98695182800293.
# Trial 194 | k=50 | hidden_dim=100  | Adam LR=2.78e-02 | h=10: Mean RMSE=3.928823, h=30: Mean RMSE=6.635082, h=60: Mean RMSE=8.971764, h=90: Mean RMSE=11.510904
# [I 2026-07-26 10:49:17,532] Trial 194 finished with value: 11.510904312133789 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.02777892335468138}. Best is trial 174 with value: 8.98695182800293.
# Trial 195 | k=50 | hidden_dim=100  | Adam LR=4.18e-02 | h=10: Mean RMSE=3.727840, h=30: Mean RMSE=6.176276, h=60: Mean RMSE=7.918988, h=90: Mean RMSE=9.527089
# [I 2026-07-26 10:50:29,620] Trial 195 finished with value: 9.52708911895752 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04181160833587356}. Best is trial 174 with value: 8.98695182800293.
# Trial 196 | k=50 | hidden_dim=100  | Adam LR=5.96e-02 | h=10: Mean RMSE=3.825722, h=30: Mean RMSE=6.502449, h=60: Mean RMSE=8.648955, h=90: Mean RMSE=10.895187
# [I 2026-07-26 10:52:02,992] Trial 196 finished with value: 10.895187377929688 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.05959986807042328}. Best is trial 174 with value: 8.98695182800293.
# Trial 197 | k=50 | hidden_dim=100  | Adam LR=4.56e-02 | h=10: Mean RMSE=3.706569, h=30: Mean RMSE=6.194123, h=60: Mean RMSE=8.040244, h=90: Mean RMSE=9.897799
# [I 2026-07-26 10:53:17,736] Trial 197 finished with value: 9.897798538208008 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04560326265104188}. Best is trial 174 with value: 8.98695182800293.
# Trial 198 | k=50 | hidden_dim=100  | Adam LR=4.86e-02 | h=10: Mean RMSE=3.715152, h=30: Mean RMSE=6.225353, h=60: Mean RMSE=8.219699, h=90: Mean RMSE=10.188569
# [I 2026-07-26 10:54:35,428] Trial 198 finished with value: 10.188569068908691 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04859697570299783}. Best is trial 174 with value: 8.98695182800293.
# Trial 199 | k=50 | hidden_dim=100  | Adam LR=4.41e-02 | h=10: Mean RMSE=3.721697, h=30: Mean RMSE=6.127499, h=60: Mean RMSE=7.902028, h=90: Mean RMSE=9.519389
# [I 2026-07-26 10:55:51,755] Trial 199 finished with value: 9.519389152526855 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04408330581465932}. Best is trial 174 with value: 8.98695182800293.
#
# ==== Best Adaptive NVAR Configuration ====
#
# k             : 50
# hidden_dim    : 100
# Adam LR       : 4.22e-02
# Best MSE@90   : 100.093277
# Best MAE@90   : 7.592456
# Best RMSE@90  : 8.986952
# Execution time: 45799.13 seconds

# %%
import numpy as np
import torch

# ============================================================
# TEST DATASET EVALUATION (Overlapping Windows)
# Adaptive NVAR
# ============================================================

test_window_size = 90
test_stride = 1
horizons = [10, 30, 60, 90]

# Containers (Latent Space)
all_test_preds, all_test_true, all_test_noisy = [], [], []
all_test_mse, all_test_mae, all_test_rmse = [], [], []

# Containers (Original SST Space)
all_test_rec_sst, all_test_true_sst = [], []
all_test_mse_sst, all_test_mae_sst, all_test_rmse_sst = [], [], []

# ============================================================
# Persistence Baseline Containers (SST Space)
# ============================================================
all_persist_mse_sst = []
all_persist_mae_sst = []
all_persist_rmse_sst = []

horizon_persist_mses_sst = {h: [] for h in horizons}
horizon_persist_maes_sst = {h: [] for h in horizons}

# Horizon-wise Storage
horizon_mses = {h: [] for h in horizons}
horizon_maes = {h: [] for h in horizons}
horizon_mses_sst = {h: [] for h in horizons}
horizon_maes_sst = {h: [] for h in horizons}

# ============================================================
# Reload Best Models (Ensemble of 3 Runs)
# ============================================================

best_k = best_config["k"]
best_hidden = best_config["hidden_dim"]
best_lr_adam = best_config["lr_adam"]

d = X_train.shape[1]
best_dk = d * best_k
best_m = int((best_dk * (best_dk + 1)) / 2)

num_runs = 5
best_models = []

for run in range(num_runs):
    best_model_path = f"optuna_model_k{best_k}_hd{best_hidden}_adam{best_lr_adam:.2e}_run{run}.pth"
    print(f"Loading model ({run + 1}/{num_runs}): {best_model_path}")

    model = AdaptiveNVARModel(
        dk=best_dk, m=best_m, d=d, hidden_dim=best_hidden
    ).to(device)

    model.load_state_dict(torch.load(best_model_path, map_location=device))
    model.eval()
    best_models.append(model)

# ============================================================
# TEST Rollout Predictions (Averaged Across 3 Runs)
# ============================================================

print("\n==== Adaptive NVAR TEST Evaluation (3-Model Ensemble) ====\n")

num_windows = len(X_test_true) - test_window_size + 1

for start in range(0, num_windows, test_stride):
    end = start + test_window_size

    X_test_true_window = X_test_true[start:end]
    X_test_noisy_window = X_test[start:end]

    # Global TEST Indices
    global_test_start = warmup_len + train_len + val_len + start
    global_test_end = global_test_start + test_window_size

    # Delay Context Initialization
    init_start = global_test_start - best_k
    init_end = global_test_start
    X_init = X[init_start:init_end].to(device)

    # Rollout predictions for each of the 3 independent models
    run_predictions = []

    for model in best_models:
        x_t = [x.clone() for x in X_init.unbind(0)]
        H_lin = torch.cat(x_t, dim=-1).unsqueeze(0)

        preds = []
        for step in range(test_window_size):
            with torch.no_grad():
                delta_x = model(H_lin)

            x_next = x_t[-1] + delta_x.squeeze(0)
            preds.append(x_next)

            # Update delay buffer
            x_t = x_t[1:] + [x_next]
            H_lin = torch.cat(x_t, dim=-1).unsqueeze(0)

        run_predictions.append(torch.stack(preds).cpu().numpy())

    # Average rollout predictions across the 3 models
    pred_np = np.mean(run_predictions, axis=0)
    true_np = X_test_true_window.cpu().numpy()
    noisy_np = X_test_noisy_window.cpu().numpy()

    # Spatial SST Reconstruction (Original Space)
    reconstructed_sst = pca.inverse_transform(pred_np)
    true_sst = sst_time_major[global_test_start:global_test_end]

    assert reconstructed_sst.shape == true_sst.shape

    # Standard Persistence Forecast (SST Space)
    persistent_sst = np.repeat(true_sst[0][None, :], test_window_size, axis=0)

    all_test_rec_sst.append(reconstructed_sst)
    all_test_true_sst.append(true_sst)




    # ------------------------------------------------------------
    # Horizon-wise Metrics (Exact Lead Step: index h - 1)
    # ------------------------------------------------------------
    for h in horizons:
        if h > pred_np.shape[0]:
            continue
        
        idx = h - 1
        
        # Latent Space
        horizon_mses[h].append((true_np[idx] - pred_np[idx]) ** 2)
        horizon_maes[h].append(np.abs(true_np[idx] - pred_np[idx]))

        # Original SST Space
        horizon_mses_sst[h].append((true_sst[idx] - reconstructed_sst[idx]) ** 2)
        horizon_maes_sst[h].append(np.abs(true_sst[idx] - reconstructed_sst[idx]))

        # Persistence Baseline (SST Space)
        horizon_persist_mses_sst[h].append((true_sst[idx] - persistent_sst[idx]) ** 2)
        horizon_persist_maes_sst[h].append(np.abs(true_sst[idx] - persistent_sst[idx]))

    # ------------------------------------------------------------
    # Full-window Metrics (Latent Space)
    # ------------------------------------------------------------
    full_mse = np.mean((true_np - pred_np) ** 2)
    full_mae = np.mean(np.abs(true_np - pred_np))
    full_rmse = np.sqrt(full_mse)

    all_test_mse.append(full_mse)
    all_test_mae.append(full_mae)
    all_test_rmse.append((start, end, full_rmse))

    all_test_preds.append(pred_np)
    all_test_true.append(true_np)
    all_test_noisy.append(noisy_np)

    # ------------------------------------------------------------
    # Full-window Metrics (Original SST Space)
    # ------------------------------------------------------------
    full_mse_sst = np.mean((true_sst - reconstructed_sst) ** 2)
    full_mae_sst = np.mean(np.abs(true_sst - reconstructed_sst))
    full_rmse_sst = np.sqrt(full_mse_sst)

    all_test_mse_sst.append(full_mse_sst)
    all_test_mae_sst.append(full_mae_sst)
    all_test_rmse_sst.append((start, end, full_rmse_sst))

    # ------------------------------------------------------------
    # Persistence Baseline (Full Window)
    # ------------------------------------------------------------
    persist_mse_sst = np.mean((true_sst - persistent_sst) ** 2)
    persist_mae_sst = np.mean(np.abs(true_sst - persistent_sst))
    persist_rmse_sst = np.sqrt(persist_mse_sst)

    all_persist_mse_sst.append(persist_mse_sst)
    all_persist_mae_sst.append(persist_mae_sst)
    all_persist_rmse_sst.append((start, end, persist_rmse_sst))


# ============================================================
# SUMMARY DIAGNOSTICS
# ============================================================

latent_variables = [f"PC {i+1}" for i in range(d)]

# --- 1. LATENT SPACE METRICS ---
print("\n" + "=" * 60)
print("  TEST Horizon-wise Forecast Skill (LATENT SPACE)")
print("=" * 60)

for h in horizons:
    if not horizon_mses[h]:
        continue

    mse_array = np.vstack(horizon_mses[h])
    mae_array = np.vstack(horizon_maes[h])

    mean_mse_per_var = np.mean(mse_array, axis=0)
    mean_mae_per_var = np.mean(mae_array, axis=0)
    rmse_per_var = np.sqrt(mean_mse_per_var)

    overall_mse = np.mean(mean_mse_per_var)
    overall_mae = np.mean(mean_mae_per_var)
    overall_rmse = np.sqrt(overall_mse)

    print(f"\n-- Forecast Horizon: Step {h} --")
    for i, var in enumerate(latent_variables):
        print(f"{var:<8} | MSE : {mean_mse_per_var[i]:.6f} | MAE : {mean_mae_per_var[i]:.6f} | RMSE : {rmse_per_var[i]:.6f}")

    print(f"Overall   | MSE : {overall_mse:.6f} | MAE : {overall_mae:.6f} | RMSE : {overall_rmse:.6f}")


# --- 2. RECONSTRUCTED SST SPACE METRICS ---
print("\n" + "=" * 60)
print("  TEST Horizon-wise Forecast Skill (RECONSTRUCTED SST)")
print("=" * 60)

for h in horizons:
    if not horizon_mses_sst[h]:
        continue

    # Adaptive NVAR Metrics
    mse_array_sst = np.vstack(horizon_mses_sst[h])
    mae_array_sst = np.vstack(horizon_maes_sst[h])

    overall_mse_sst = np.mean(mse_array_sst)
    overall_mae_sst = np.mean(mae_array_sst)
    overall_rmse_sst = np.sqrt(overall_mse_sst)

    # Persistence Metrics
    persist_mse = np.mean(np.vstack(horizon_persist_mses_sst[h]))
    persist_mae = np.mean(np.vstack(horizon_persist_maes_sst[h]))
    persist_rmse = np.sqrt(persist_mse)

    # Percentage Improvements
    imp_mse = ((persist_mse - overall_mse_sst) / persist_mse) * 100
    imp_mae = ((persist_mae - overall_mae_sst) / persist_mae) * 100
    imp_rmse = ((persist_rmse - overall_rmse_sst) / persist_rmse) * 100

    print(f"\n-- Forecast Horizon: Step {h} --")
    print(f"Adaptive NVAR | MSE : {overall_mse_sst:.6f} | MAE : {overall_mae_sst:.6f} | RMSE : {overall_rmse_sst:.6f}")
    print(f"Persistence   | MSE : {persist_mse:.6f} | MAE : {persist_mae:.6f} | RMSE : {persist_rmse:.6f}")
    print(f"Improvement   | MSE : {imp_mse:+.2f}%   | MAE : {imp_mae:+.2f}%   | RMSE : {imp_rmse:+.2f}%")


# --- 3. OVERALL TEST SUMMARY ---
print("\n" + "=" * 60)
print("  Overall TEST Summary (Full Window Averages)")
print("=" * 60 + "\n")

overall_nvar_mse_sst = np.mean(all_test_mse_sst)
overall_nvar_mae_sst = np.mean(all_test_mae_sst)
overall_nvar_rmse_sst = np.mean([x[2] for x in all_test_rmse_sst])

overall_per_mse_sst = np.mean(all_persist_mse_sst)
overall_per_mae_sst = np.mean(all_persist_mae_sst)
overall_per_rmse_sst = np.mean([x[2] for x in all_persist_rmse_sst])

# Overall Improvements
overall_imp_mse = ((overall_per_mse_sst - overall_nvar_mse_sst) / overall_per_mse_sst) * 100
overall_imp_mae = ((overall_per_mae_sst - overall_nvar_mae_sst) / overall_per_mae_sst) * 100
overall_imp_rmse = ((overall_per_rmse_sst - overall_nvar_rmse_sst) / overall_per_rmse_sst) * 100

print(f"Latent Space (Adaptive NVAR) | MSE : {np.mean(all_test_mse):.6f} | MAE : {np.mean(all_test_mae):.6f} | RMSE : {np.mean([x[2] for x in all_test_rmse]):.6f}")
print(f"SST Space (Adaptive NVAR)    | MSE : {overall_nvar_mse_sst:.6f} | MAE : {overall_nvar_mae_sst:.6f} | RMSE : {overall_nvar_rmse_sst:.6f}")
print(f"SST Space (Persistence)      | MSE : {overall_per_mse_sst:.6f} | MAE : {overall_per_mae_sst:.6f} | RMSE : {overall_per_rmse_sst:.6f}")
print(f"Improvement vs Persistence   | MSE : {overall_imp_mse:+.2f}%   | MAE : {overall_imp_mae:+.2f}%   | RMSE : {overall_imp_rmse:+.2f}%")

print("-" * 60)
print(f"TEST Window Size   : {test_window_size}")
print(f"TEST Stride        : {test_stride}")
print(f"Total TEST Windows : {len(all_test_rmse)}")
print("=" * 60)
# Out:
# Loading model (1/5): optuna_model_k50_hd100_adam4.22e-02_run0.pth
# Loading model (2/5): optuna_model_k50_hd100_adam4.22e-02_run1.pth
# Loading model (3/5): optuna_model_k50_hd100_adam4.22e-02_run2.pth
# Loading model (4/5): optuna_model_k50_hd100_adam4.22e-02_run3.pth
# Loading model (5/5): optuna_model_k50_hd100_adam4.22e-02_run4.pth
#
# ==== Adaptive NVAR TEST Evaluation (3-Model Ensemble) ====
#
#
# ============================================================
#   TEST Horizon-wise Forecast Skill (LATENT SPACE)
# ============================================================
#
# -- Forecast Horizon: Step 10 --
# PC 1     | MSE : 26.149012 | MAE : 3.537890 | RMSE : 5.113610
# Overall   | MSE : 26.149012 | MAE : 3.537890 | RMSE : 5.113610
#
# -- Forecast Horizon: Step 30 --
# PC 1     | MSE : 65.406395 | MAE : 6.121669 | RMSE : 8.087422
# Overall   | MSE : 65.406395 | MAE : 6.121669 | RMSE : 8.087422
#
# -- Forecast Horizon: Step 60 --
# PC 1     | MSE : 119.687103 | MAE : 8.225707 | RMSE : 10.940160
# Overall   | MSE : 119.687103 | MAE : 8.225707 | RMSE : 10.940160
#
# -- Forecast Horizon: Step 90 --
# PC 1     | MSE : 109.742188 | MAE : 8.544115 | RMSE : 10.475791
# Overall   | MSE : 109.742188 | MAE : 8.544115 | RMSE : 10.475791
#
# ============================================================
#   TEST Horizon-wise Forecast Skill (RECONSTRUCTED SST)
# ============================================================
#
# -- Forecast Horizon: Step 10 --
# Adaptive NVAR | MSE : 0.039163 | MAE : 0.153966 | RMSE : 0.197896
# Persistence   | MSE : 0.046467 | MAE : 0.171928 | RMSE : 0.215562
# Improvement   | MSE : +15.72%   | MAE : +10.45%   | RMSE : +8.20%
#
# -- Forecast Horizon: Step 30 --
# Adaptive NVAR | MSE : 0.057721 | MAE : 0.192384 | RMSE : 0.240252
# Persistence   | MSE : 0.324089 | MAE : 0.479715 | RMSE : 0.569288
# Improvement   | MSE : +82.19%   | MAE : +59.90%   | RMSE : +57.80%
#
# -- Forecast Horizon: Step 60 --
# Adaptive NVAR | MSE : 0.082635 | MAE : 0.230155 | RMSE : 0.287463
# Persistence   | MSE : 1.156891 | MAE : 0.919451 | RMSE : 1.075589
# Improvement   | MSE : +92.86%   | MAE : +74.97%   | RMSE : +73.27%
#
# -- Forecast Horizon: Step 90 --
# Adaptive NVAR | MSE : 0.077501 | MAE : 0.229994 | RMSE : 0.278390
# Persistence   | MSE : 2.226893 | MAE : 1.271644 | RMSE : 1.492278
# Improvement   | MSE : +96.52%   | MAE : +81.91%   | RMSE : +81.34%
#
# ============================================================
#   Overall TEST Summary (Full Window Averages)
# ============================================================
#
# Latent Space (Adaptive NVAR) | MSE : 83.044121 | MAE : 6.667856 | RMSE : 7.826945
# SST Space (Adaptive NVAR)    | MSE : 0.065529 | MAE : 0.203256 | RMSE : 0.247450
# SST Space (Persistence)      | MSE : 0.846956 | MAE : 0.691785 | RMSE : 0.824934
# Improvement vs Persistence   | MSE : +92.26%   | MAE : +70.62%   | RMSE : +70.00%
# ------------------------------------------------------------
# TEST Window Size   : 90
# TEST Stride        : 1
# Total TEST Windows : 411
# ============================================================

# %%
import matplotlib.pyplot as plt
import numpy as np

# ============================================================
# 1. VARIABLE RESOLUTION & SETUP
# ============================================================
plot_len = 90    # Set forecast horizon to visualize
window_idx = 60  # 0 = first window, 1 = second, ...

# Fallback check to ensure data variables exist in memory
if 'y_test_rec_sst' in globals() and len(y_test_rec_sst) > 0:
    X_rec_norm = y_test_rec_sst
    X_test_true_raw = y_test_true_sst
elif 'all_test_rec_sst' in globals() and len(all_test_rec_sst) > 0:
    X_rec_norm = all_test_rec_sst[window_idx]
    X_test_true_raw = all_test_true_sst[window_idx]
else:
    raise NameError(
        "Evaluation data not found in memory! "
        "Please run your test evaluation loop first."
    )

# Slice arrays to the requested plot length
true_field = X_test_true_raw[:plot_len]
pred_field = X_rec_norm[:plot_len]

# ============================================================
# 2. ABSOLUTE ERROR & COLORMAP RANGES
# ============================================================
sst_error = np.abs(true_field - pred_field)

# Enforce shared color scale for True and Predicted fields
vmin_sst = min(true_field.min(), pred_field.min())
vmax_sst = max(true_field.max(), pred_field.max())

# ============================================================
# 3. SUBPLOTS SETUP
# ============================================================
fig, axes = plt.subplots(3, 1, figsize=(14, 10), sharex=True)

# --- TRUE SST FIELD ---
im0 = axes[0].imshow(
    true_field.T,
    aspect='auto',
    origin='lower',
    cmap='coolwarm',
    vmin=vmin_sst,
    vmax=vmax_sst
)
axes[0].set_title('True SST Field', fontsize=14, fontweight='bold')
axes[0].set_ylabel('Spatial Grid Index', fontsize=12)

# --- PREDICTED SST FIELD (3-Model Ensemble) ---
im1 = axes[1].imshow(
    pred_field.T,
    aspect='auto',
    origin='lower',
    cmap='coolwarm',
    vmin=vmin_sst,
    vmax=vmax_sst
)
axes[1].set_title('Adaptive NVAR Predicted SST Field', fontsize=14, fontweight='bold')
axes[1].set_ylabel('Spatial Grid Index', fontsize=12)

# --- ABSOLUTE ERROR FIELD ---
im2 = axes[2].imshow(
    sst_error.T,
    aspect='auto',
    origin='lower',
    cmap='inferno',
    vmin=0,
    vmax=sst_error.max()
)
axes[2].set_title('Absolute SST Error', fontsize=14, fontweight='bold')
axes[2].set_xlabel('Forecast Time Step', fontsize=12)
axes[2].set_ylabel('Spatial Grid Index', fontsize=12)

# ============================================================
# 4. COLORBARS & EXPORT
# ============================================================
cbar0 = fig.colorbar(im0, ax=axes[0], fraction=0.02, pad=0.02)
cbar0.set_label('SST', fontsize=10)

cbar1 = fig.colorbar(im1, ax=axes[1], fraction=0.02, pad=0.02)
cbar1.set_label('SST', fontsize=10)

cbar2 = fig.colorbar(im2, ax=axes[2], fraction=0.02, pad=0.02)
cbar2.set_label('Abs Error', fontsize=10)

plt.tight_layout()

plt.savefig(
    "adaptive_nvar_ensemble_sst_field_evolution_Yellow_Sea.png",
    dpi=300,
    bbox_inches='tight'
)

plt.show()
