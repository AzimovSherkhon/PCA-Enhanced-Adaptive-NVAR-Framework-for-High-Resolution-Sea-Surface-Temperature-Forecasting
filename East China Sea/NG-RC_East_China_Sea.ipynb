# %%
# ============================================================
# High-Resolution SST Forecasting in the East Sea via SVD-Enhanced NG-RC
# ============================================================
# Author: Azimov Sherkhon Azizkhon Ugli
# Email:  sherxonazimov94@pusan.ac.kr
# GitHub: @AzimovSherkhon
# ============================================================

# %%
# ============================================================
# Imports
# ============================================================
import numpy as np
import matplotlib.pyplot as plt
import itertools
import warnings

from sklearn.decomposition import PCA

# Suppress unnecessary warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# ============================================================
# Reproducibility
# ============================================================

seed = 2025

np.random.seed(seed)

# %%
# ============================================================
# 1. Load SST Dataset
# ============================================================

sst_data = np.load("sst_normalized_5k.npy")

# Shape:
# (spatial_points, time)

sst_time_major = sst_data.T

print("Original SST shape:", sst_time_major.shape)
# Out:
# Original SST shape: (5001, 2989)

# %%
# ============================================================
# 2. Time Setup
# ============================================================
dt = 1.0
warmup   = 100.0
traintime = 3900.0
valtime   = 500.0
testtime  = 500.0

maxtime = warmup + traintime + valtime + testtime

warmup_pts    = int(round(warmup / dt))
traintime_pts = int(round(traintime / dt))
valtime_pts   = int(round(valtime / dt))
testtime_pts  = int(round(testtime / dt))

warmtrain_pts = warmup_pts + traintime_pts
val_end       = warmtrain_pts + valtime_pts
maxtime_pts   = int(round(maxtime / dt))

print("==== Data Splits ====")
print(f"Warmup : {warmup_pts}")
print(f"Train  : {traintime_pts}")
print(f"Val    : {valtime_pts}")
print(f"Test   : {testtime_pts}")
# Out:
# ==== Data Splits ====
# Warmup : 100
# Train  : 3900
# Val    : 500
# Test   : 500

# %%
# ============================================================
# 3. Fit PCA/SVD on TRAINING DATA ONLY
# ============================================================
pca_train_end = warmtrain_pts

n_components = 1

train_sst = sst_time_major[:pca_train_end]

pca = PCA(
    n_components=n_components,
    svd_solver='full'
)

pca.fit(train_sst)

# Transform entire dataset using TRAIN PCA basis
sst_pca = pca.transform(sst_time_major)

explained_variance = pca.explained_variance_ratio_

print("\n==== PCA/SVD Summary ====")
print(f"Retained components      : {n_components}")
print(f"Explained variance ratio : {explained_variance}")
# Out:
# ==== PCA/SVD Summary ====
# Retained components      : 1
# Explained variance ratio : [0.9650954]

# %%
# ============================================================
# 4. Prepare Latent SST Dataset
# ============================================================

latent_sst = sst_pca.T

X_soln = latent_sst[:, :maxtime_pts + 1]

d, T_full = X_soln.shape

print(f"\nLatent SST shape: {X_soln.shape}")
# Out:
# Latent SST shape: (1, 5001)

# %%
# ============================================================
# Visualization of Latent SST Dynamics (PCA Components)
# ============================================================

# latent_sst shape:
# (n_components, time)

num_components_to_plot = min(n_components, 10)

time = np.arange(latent_sst.shape[1])

plt.figure(figsize=(12, 2.5 * num_components_to_plot))

for i in range(num_components_to_plot):

    plt.subplot(num_components_to_plot, 1, i + 1)

    plt.plot(
        time,
        latent_sst[i],
        linewidth=1.0,
        label=f'PC {i+1}'
    )

    plt.ylabel(f'PC {i+1}')

    plt.grid(True, alpha=0.3)

    plt.legend(loc='upper right')

    if i == 0:
        plt.title(
            "Latent SST Dynamics in PCA Space",
            fontsize=14
        )

    if i == num_components_to_plot - 1:
        plt.xlabel("Time Step")

plt.tight_layout()
plt.show()

# %%
# ============================================================
# 5. NG-RC / NVAR Hyperparameter Optimization Configuration
# ============================================================

import time
import optuna
import numpy as np

# Validation configuration
window_size = 90
stride = 1  # fully overlapping rolling windows

# Number of Optuna trials
n_trials = 200

# Store optimization history
results = []


# ============================================================
# 6. Vectorized Feature Construction for NG-RC
# ============================================================

def build_features(data, k, start_idx, end_idx):
    """
    Construct nonlinear vector autoregressive (NVAR) features using vectorization.

    Parameters
    ----------
    data : ndarray
        Input latent-state data with shape (d, T)
    k : int
        Delay embedding dimension
    start_idx : int
        Starting time index
    end_idx : int
        Ending time index (exclusive)

    Returns
    -------
    features : ndarray
        Full NVAR feature matrix of shape (d_total, length)
    linear_block : ndarray
        Delay-coordinate linear features of shape (d_linear, length)
    """
    d, _ = data.shape

    if start_idx < (k - 1):
        raise ValueError("Insufficient history for selected delay dimension k.")

    length = end_idx - start_idx
    d_linear = d * k
    d_quadratic = (d_linear * (d_linear + 1)) // 2
    d_total = 1 + d_linear + d_quadratic

    # 1. Construct Linear Delay Embedding
    linear_block = np.zeros((d_linear, length))
    for delay in range(k):
        linear_block[delay * d : (delay + 1) * d, :] = data[:, start_idx - delay : end_idx - delay]

    # 2. Construct Full Feature Matrix
    features = np.ones((d_total, length))
    features[1 : 1 + d_linear, :] = linear_block

    # 3. Vectorized Quadratic Terms
    r_idx, c_idx = np.triu_indices(d_linear)
    features[1 + d_linear :, :] = linear_block[r_idx, :] * linear_block[c_idx, :]

    return features, linear_block


# ============================================================
# 7. Optuna Objective Function
# ============================================================

def objective(trial):
    # Search Space
    k = trial.suggest_categorical("k", [2, 5, 10, 20, 30, 40, 50])
    ridge_param = trial.suggest_float("ridge", 1e-7, 1e6, log=True)

    d_linear = d * k
    d_quadratic = (d_linear * (d_linear + 1)) // 2
    d_total = 1 + d_linear + d_quadratic

    train_start = warmup_pts - 1
    train_end = warmtrain_pts - 1

    if train_start < (k - 1):
        return np.inf

    # --- Training Phase ---
    train_features, _ = build_features(X_soln, k, train_start, train_end)
    delta_x = X_soln[:, warmup_pts:warmtrain_pts] - X_soln[:, warmup_pts - 1 : warmtrain_pts - 1]

    # Ridge Regression Solution
    cov_matrix = train_features @ train_features.T
    reg_matrix = cov_matrix + ridge_param * np.eye(d_total)

    try:
        # Solve (W_out @ reg_matrix) = (delta_x @ train_features.T)
        W_out = np.linalg.solve(reg_matrix.T, (delta_x @ train_features.T).T).T
    except np.linalg.LinAlgError:
        W_out = delta_x @ train_features.T @ np.linalg.pinv(reg_matrix)

    # Pre-index upper-triangular elements for fast test feature construction
    r_idx, c_idx = np.triu_indices(d_linear)

    # --- Validation Phase ---
    validation_mses, validation_maes, validation_rmses = [], [], []

    for start in range(warmtrain_pts, val_end - window_size + 1, stride):
        end = start + window_size

        # Initialize Delay History
        history = [X_soln[:, start - k + i].copy() for i in range(k)]
        prediction = np.zeros((d, window_size))

        # Autonomous Rollout
        for step in range(window_size):
            z = np.hstack([history[-1 - delay] for delay in range(k)])

            test_features = np.ones(d_total)
            test_features[1 : 1 + d_linear] = z
            test_features[1 + d_linear :] = z[r_idx] * z[c_idx]

            delta_pred = W_out @ test_features
            next_state = history[-1] + delta_pred

            prediction[:, step] = next_state
            history.append(next_state)

        # Validation Metrics
        truth = X_soln[:, start:end]
        mse = np.mean((truth - prediction) ** 2)
        mae = np.mean(np.abs(truth - prediction))
        rmse = np.sqrt(mse)

        validation_mses.append(mse)
        validation_maes.append(mae)
        validation_rmses.append(rmse)

    # --- Aggregate Scores ---
    avg_mse = np.mean(validation_mses) if validation_mses else np.inf
    avg_mae = np.mean(validation_maes) if validation_maes else np.inf
    avg_rmse = np.mean(validation_rmses) if validation_rmses else np.inf

    results.append({
        "k": k,
        "ridge": ridge_param,
        "mse": avg_mse,
        "mae": avg_mae,
        "rmse": avg_rmse
    })

    print(
        f"Trial {trial.number:03d} | "
        f"k = {k:<2d} | "
        f"ridge = {ridge_param:>10.2e} | "
        f"MSE = {avg_mse:.6f} | "
        f"MAE = {avg_mae:.6f} | "
        f"RMSE = {avg_rmse:.6f}"
    )

    return avg_rmse


# ============================================================
# 8. Run Optuna Optimization
# ============================================================

start_time = time.time()
print("\n==== NG-RC Hyperparameter Optimization ====\n")

study = optuna.create_study(
    direction="minimize",
    sampler=optuna.samplers.TPESampler(seed=seed)
)

study.optimize(
    objective,
    n_trials=n_trials,
    show_progress_bar=True
)


# ============================================================
# 9. Best Hyperparameters Summary
# ============================================================

best_k = study.best_params["k"]
best_ridge = study.best_params["ridge"]
best_rmse = study.best_value

best_result = min(results, key=lambda x: x["rmse"])
best_mse = best_result["mse"]
best_mae = best_result["mae"]

print("\n==== Optimal NG-RC Configuration ====\n")
print(f"Optimal delay dimension (k) : {best_k}")
print(f"Optimal ridge parameter     : {best_ridge:.2e}")
print(f"Best validation MSE         : {best_mse:.6f}")
print(f"Best validation MAE         : {best_mae:.6f}")
print(f"Best validation RMSE        : {best_rmse:.6f}")
print(f"Execution time              : {time.time() - start_time:.2f} seconds")
# Out:
# [I 2026-07-26 22:09:25,025] A new study created in memory with name: no-name-9d881ad6-fa33-4b85-879d-4df98068147a
# ==== NG-RC Hyperparameter Optimization ====
#   0%|          | 0/200 [00:00<?, ?it/s]
# /tmp/ipykernel_109070/3564220722.py:124: RuntimeWarning: overflow encountered in multiply
#   test_features[1 + d_linear :] = z[r_idx] * z[c_idx]
# /tmp/ipykernel_109070/3564220722.py:126: RuntimeWarning: invalid value encountered in matmul
#   delta_pred = W_out @ test_features
# /tmp/ipykernel_109070/3564220722.py:134: RuntimeWarning: overflow encountered in square
#   mse = np.mean((truth - prediction) ** 2)
# Trial 000 | k = 10 | ridge =   2.54e-01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:25,545] Trial 0 failed with parameters: {'k': 10, 'ridge': 0.25352464752029175} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:25,545] Trial 0 failed with value nan.
# Trial 001 | k = 2  | ridge =   6.41e-04 | MSE = 2101.782110 | MAE = 36.587876 | RMSE = 42.788182
# [I 2026-07-26 22:09:25,947] Trial 1 finished with value: 42.78818211679377 and parameters: {'k': 2, 'ridge': 0.0006405043692191096}. Best is trial 1 with value: 42.78818211679377.
# Trial 002 | k = 40 | ridge =   4.01e-06 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:27,066] Trial 2 failed with parameters: {'k': 40, 'ridge': 4.006230508002568e-06} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:27,067] Trial 2 failed with value nan.
# Trial 003 | k = 5  | ridge =   7.62e+05 | MSE = 2025.877437 | MAE = 35.359341 | RMSE = 41.171352
# [I 2026-07-26 22:09:27,496] Trial 3 finished with value: 41.17135222698412 and parameters: {'k': 5, 'ridge': 761517.1767224498}. Best is trial 3 with value: 41.17135222698412.
# Trial 004 | k = 50 | ridge =   1.29e-02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:28,845] Trial 4 failed with parameters: {'k': 50, 'ridge': 0.012862009967543995} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:28,846] Trial 4 failed with value nan.
# Trial 005 | k = 2  | ridge =   2.65e-03 | MSE = 2101.782189 | MAE = 36.587877 | RMSE = 42.788183
# [I 2026-07-26 22:09:29,240] Trial 5 finished with value: 42.78818290993283 and parameters: {'k': 2, 'ridge': 0.0026483767982816643}. Best is trial 3 with value: 41.17135222698412.
# Trial 006 | k = 20 | ridge =   1.56e+05 | MSE = 769.398385 | MAE = 19.871598 | RMSE = 23.574432
# [I 2026-07-26 22:09:29,970] Trial 6 finished with value: 23.574432468270526 and parameters: {'k': 20, 'ridge': 155708.54671269728}. Best is trial 6 with value: 23.574432468270526.
# Trial 007 | k = 2  | ridge =   6.47e+05 | MSE = 2196.265238 | MAE = 37.054102 | RMSE = 43.220494
# [I 2026-07-26 22:09:30,362] Trial 7 finished with value: 43.22049377168447 and parameters: {'k': 2, 'ridge': 647231.5631352852}. Best is trial 6 with value: 23.574432468270526.
# Trial 008 | k = 5  | ridge =   9.54e-03 | MSE = 2015.130576 | MAE = 35.597841 | RMSE = 41.943632
# [I 2026-07-26 22:09:30,802] Trial 8 finished with value: 41.943631917136145 and parameters: {'k': 5, 'ridge': 0.00953915916793728}. Best is trial 6 with value: 23.574432468270526.
# Trial 009 | k = 40 | ridge =   1.27e-04 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:31,903] Trial 9 failed with parameters: {'k': 40, 'ridge': 0.00012705363801063493} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:31,904] Trial 9 failed with value nan.
# Trial 010 | k = 2  | ridge =   5.80e-06 | MSE = 2101.782086 | MAE = 36.587876 | RMSE = 42.788182
# [I 2026-07-26 22:09:32,288] Trial 10 finished with value: 42.788181866017254 and parameters: {'k': 2, 'ridge': 5.798214493433132e-06}. Best is trial 6 with value: 23.574432468270526.
# Trial 011 | k = 30 | ridge =   4.20e-06 | MSE = 101271118.735157 | MAE = 67.973173 | RMSE = 515.080377
# [I 2026-07-26 22:09:33,186] Trial 11 finished with value: 515.0803770620918 and parameters: {'k': 30, 'ridge': 4.201261270629809e-06}. Best is trial 6 with value: 23.574432468270526.
# Trial 012 | k = 50 | ridge =   1.47e-05 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:34,529] Trial 12 failed with parameters: {'k': 50, 'ridge': 1.469990055727916e-05} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:34,529] Trial 12 failed with value nan.
# Trial 013 | k = 5  | ridge =   1.04e+04 | MSE = 1977.572178 | MAE = 34.981485 | RMSE = 41.018095
# [I 2026-07-26 22:09:34,957] Trial 13 finished with value: 41.01809541144127 and parameters: {'k': 5, 'ridge': 10436.458285315375}. Best is trial 6 with value: 23.574432468270526.
# Trial 014 | k = 50 | ridge =   3.99e-06 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:36,301] Trial 14 failed with parameters: {'k': 50, 'ridge': 3.986582558612395e-06} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:36,301] Trial 14 failed with value nan.
# Trial 015 | k = 30 | ridge =   2.69e-03 | MSE = 100613781.089987 | MAE = 67.802670 | RMSE = 513.466613
# [I 2026-07-26 22:09:37,198] Trial 15 finished with value: 513.4666126791719 and parameters: {'k': 30, 'ridge': 0.0026866767222803105}. Best is trial 6 with value: 23.574432468270526.
# Trial 016 | k = 20 | ridge =   5.12e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:37,921] Trial 16 failed with parameters: {'k': 20, 'ridge': 51.185115266499565} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:37,921] Trial 16 failed with value nan.
# Trial 017 | k = 20 | ridge =   2.93e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:38,641] Trial 17 failed with parameters: {'k': 20, 'ridge': 29.28979741804431} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:38,641] Trial 17 failed with value nan.
# Trial 018 | k = 20 | ridge =   5.64e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:39,364] Trial 18 failed with parameters: {'k': 20, 'ridge': 56.43145429340991} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:39,365] Trial 18 failed with value nan.
# Trial 019 | k = 20 | ridge =   4.28e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:40,085] Trial 19 failed with parameters: {'k': 20, 'ridge': 42.77644889574142} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:40,086] Trial 19 failed with value nan.
# Trial 020 | k = 20 | ridge =   3.26e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:40,806] Trial 20 failed with parameters: {'k': 20, 'ridge': 32.64354360982925} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:40,806] Trial 20 failed with value nan.
# Trial 021 | k = 20 | ridge =   6.02e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:41,529] Trial 21 failed with parameters: {'k': 20, 'ridge': 60.204345619199216} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:41,529] Trial 21 failed with value nan.
# Trial 022 | k = 20 | ridge =   2.48e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:42,250] Trial 22 failed with parameters: {'k': 20, 'ridge': 24.829739682220346} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:42,251] Trial 22 failed with value nan.
# Trial 023 | k = 20 | ridge =   3.88e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:42,975] Trial 23 failed with parameters: {'k': 20, 'ridge': 38.773303568596084} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:42,976] Trial 23 failed with value nan.
# Trial 024 | k = 20 | ridge =   1.13e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:43,698] Trial 24 failed with parameters: {'k': 20, 'ridge': 113.01433269051117} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:43,698] Trial 24 failed with value nan.
# Trial 025 | k = 20 | ridge =   6.83e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:44,420] Trial 25 failed with parameters: {'k': 20, 'ridge': 68.33885646042985} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:44,420] Trial 25 failed with value nan.
# Trial 026 | k = 20 | ridge =   6.71e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:45,143] Trial 26 failed with parameters: {'k': 20, 'ridge': 67.14033630922243} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:45,144] Trial 26 failed with value nan.
# Trial 027 | k = 20 | ridge =   1.12e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:45,866] Trial 27 failed with parameters: {'k': 20, 'ridge': 112.05266166886415} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:45,866] Trial 27 failed with value nan.
# Trial 028 | k = 20 | ridge =   6.17e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:46,587] Trial 28 failed with parameters: {'k': 20, 'ridge': 61.73955062084241} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:46,588] Trial 28 failed with value nan.
# Trial 029 | k = 20 | ridge =   1.27e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:47,312] Trial 29 failed with parameters: {'k': 20, 'ridge': 126.61625988804565} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:47,313] Trial 29 failed with value nan.
# Trial 030 | k = 20 | ridge =   9.76e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:48,056] Trial 30 failed with parameters: {'k': 20, 'ridge': 97.62745698619271} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:48,056] Trial 30 failed with value nan.
# Trial 031 | k = 20 | ridge =   1.00e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:48,776] Trial 31 failed with parameters: {'k': 20, 'ridge': 100.2448150354441} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:48,776] Trial 31 failed with value nan.
# Trial 032 | k = 20 | ridge =   3.78e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:49,501] Trial 32 failed with parameters: {'k': 20, 'ridge': 37.80390899308998} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:49,502] Trial 32 failed with value nan.
# Trial 033 | k = 20 | ridge =   7.84e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:50,221] Trial 33 failed with parameters: {'k': 20, 'ridge': 78.38019720914276} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:50,222] Trial 33 failed with value nan.
# Trial 034 | k = 20 | ridge =   7.41e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:50,938] Trial 34 failed with parameters: {'k': 20, 'ridge': 74.0872095501175} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:50,939] Trial 34 failed with value nan.
# Trial 035 | k = 20 | ridge =   3.54e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:51,658] Trial 35 failed with parameters: {'k': 20, 'ridge': 35.4130432239851} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:51,659] Trial 35 failed with value nan.
# Trial 036 | k = 20 | ridge =   1.80e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:52,381] Trial 36 failed with parameters: {'k': 20, 'ridge': 18.000493171221077} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:52,381] Trial 36 failed with value nan.
# Trial 037 | k = 20 | ridge =   2.73e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:53,102] Trial 37 failed with parameters: {'k': 20, 'ridge': 27.312913419583147} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:53,103] Trial 37 failed with value nan.
# Trial 038 | k = 20 | ridge =   6.44e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:53,824] Trial 38 failed with parameters: {'k': 20, 'ridge': 64.374531730174} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:53,825] Trial 38 failed with value nan.
# Trial 039 | k = 20 | ridge =   2.32e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:54,576] Trial 39 failed with parameters: {'k': 20, 'ridge': 23.175208694834808} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:54,577] Trial 39 failed with value nan.
# Trial 040 | k = 20 | ridge =   4.97e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:55,319] Trial 40 failed with parameters: {'k': 20, 'ridge': 49.65252647968156} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:55,320] Trial 40 failed with value nan.
# Trial 041 | k = 20 | ridge =   6.74e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:56,053] Trial 41 failed with parameters: {'k': 20, 'ridge': 67.3971997510769} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:56,054] Trial 41 failed with value nan.
# Trial 042 | k = 20 | ridge =   4.45e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:56,778] Trial 42 failed with parameters: {'k': 20, 'ridge': 44.45457911757329} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:56,779] Trial 42 failed with value nan.
# Trial 043 | k = 20 | ridge =   5.27e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:57,503] Trial 43 failed with parameters: {'k': 20, 'ridge': 52.72491673607164} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:57,503] Trial 43 failed with value nan.
# Trial 044 | k = 20 | ridge =   7.10e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:58,251] Trial 44 failed with parameters: {'k': 20, 'ridge': 70.99785766956221} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:58,252] Trial 44 failed with value nan.
# Trial 045 | k = 20 | ridge =   4.51e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:58,976] Trial 45 failed with parameters: {'k': 20, 'ridge': 45.07724642668624} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:58,977] Trial 45 failed with value nan.
# Trial 046 | k = 20 | ridge =   4.83e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:09:59,727] Trial 46 failed with parameters: {'k': 20, 'ridge': 48.290913173174275} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:09:59,728] Trial 46 failed with value nan.
# Trial 047 | k = 20 | ridge =   4.01e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:00,541] Trial 47 failed with parameters: {'k': 20, 'ridge': 40.081224554354854} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:00,542] Trial 47 failed with value nan.
# Trial 048 | k = 20 | ridge =   3.58e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:01,300] Trial 48 failed with parameters: {'k': 20, 'ridge': 35.798418745501} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:01,301] Trial 48 failed with value nan.
# Trial 049 | k = 20 | ridge =   3.08e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:02,055] Trial 49 failed with parameters: {'k': 20, 'ridge': 30.809811600719037} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:02,055] Trial 49 failed with value nan.
# Trial 050 | k = 20 | ridge =   8.85e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:02,780] Trial 50 failed with parameters: {'k': 20, 'ridge': 88.49499680289198} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:02,780] Trial 50 failed with value nan.
# Trial 051 | k = 20 | ridge =   2.03e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:03,504] Trial 51 failed with parameters: {'k': 20, 'ridge': 20.250291889363776} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:03,505] Trial 51 failed with value nan.
# Trial 052 | k = 20 | ridge =   6.28e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:04,256] Trial 52 failed with parameters: {'k': 20, 'ridge': 62.802687465573214} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:04,256] Trial 52 failed with value nan.
# Trial 053 | k = 20 | ridge =   8.74e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:04,976] Trial 53 failed with parameters: {'k': 20, 'ridge': 87.36020100554327} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:04,977] Trial 53 failed with value nan.
# Trial 054 | k = 20 | ridge =   8.42e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:05,699] Trial 54 failed with parameters: {'k': 20, 'ridge': 84.15726287582157} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:05,700] Trial 54 failed with value nan.
# Trial 055 | k = 20 | ridge =   5.26e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:06,422] Trial 55 failed with parameters: {'k': 20, 'ridge': 52.6009096976163} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:06,423] Trial 55 failed with value nan.
# Trial 056 | k = 20 | ridge =   4.06e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:07,159] Trial 56 failed with parameters: {'k': 20, 'ridge': 40.616683381188835} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:07,160] Trial 56 failed with value nan.
# Trial 057 | k = 20 | ridge =   1.13e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:07,879] Trial 57 failed with parameters: {'k': 20, 'ridge': 112.69438139437419} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:07,880] Trial 57 failed with value nan.
# Trial 058 | k = 20 | ridge =   3.11e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:08,603] Trial 58 failed with parameters: {'k': 20, 'ridge': 31.088329580118824} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:08,604] Trial 58 failed with value nan.
# Trial 059 | k = 20 | ridge =   2.75e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:09,338] Trial 59 failed with parameters: {'k': 20, 'ridge': 27.45504164245681} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:09,339] Trial 59 failed with value nan.
# Trial 060 | k = 20 | ridge =   6.72e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:10,059] Trial 60 failed with parameters: {'k': 20, 'ridge': 67.20502814293832} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:10,060] Trial 60 failed with value nan.
# Trial 061 | k = 20 | ridge =   2.34e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:10,781] Trial 61 failed with parameters: {'k': 20, 'ridge': 23.391434647099103} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:10,781] Trial 61 failed with value nan.
# Trial 062 | k = 20 | ridge =   1.52e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:11,515] Trial 62 failed with parameters: {'k': 20, 'ridge': 15.206508044471137} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:11,515] Trial 62 failed with value nan.
# Trial 063 | k = 20 | ridge =   1.94e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:12,257] Trial 63 failed with parameters: {'k': 20, 'ridge': 19.394136082465103} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:12,258] Trial 63 failed with value nan.
# Trial 064 | k = 20 | ridge =   2.64e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:12,979] Trial 64 failed with parameters: {'k': 20, 'ridge': 26.366291060639124} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:12,980] Trial 64 failed with value nan.
# Trial 065 | k = 20 | ridge =   5.68e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:13,698] Trial 65 failed with parameters: {'k': 20, 'ridge': 56.82873688539274} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:13,698] Trial 65 failed with value nan.
# Trial 066 | k = 20 | ridge =   5.38e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:14,420] Trial 66 failed with parameters: {'k': 20, 'ridge': 53.76343611063979} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:14,420] Trial 66 failed with value nan.
# Trial 067 | k = 20 | ridge =   2.99e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:15,201] Trial 67 failed with parameters: {'k': 20, 'ridge': 299.48026021423567} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:15,202] Trial 67 failed with value nan.
# Trial 068 | k = 20 | ridge =   6.17e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:15,921] Trial 68 failed with parameters: {'k': 20, 'ridge': 61.670030351689896} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:15,922] Trial 68 failed with value nan.
# Trial 069 | k = 20 | ridge =   3.42e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:16,655] Trial 69 failed with parameters: {'k': 20, 'ridge': 34.237597269271866} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:16,656] Trial 69 failed with value nan.
# Trial 070 | k = 20 | ridge =   5.85e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:17,944] Trial 70 failed with parameters: {'k': 20, 'ridge': 58.484382652096926} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:17,945] Trial 70 failed with value nan.
# Trial 071 | k = 20 | ridge =   1.73e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:19,366] Trial 71 failed with parameters: {'k': 20, 'ridge': 173.0754528780966} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:19,367] Trial 71 failed with value nan.
# Trial 072 | k = 20 | ridge =   4.15e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:20,788] Trial 72 failed with parameters: {'k': 20, 'ridge': 41.52370092318956} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:20,789] Trial 72 failed with value nan.
# Trial 073 | k = 20 | ridge =   1.51e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:22,052] Trial 73 failed with parameters: {'k': 20, 'ridge': 15.051710625513925} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:22,052] Trial 73 failed with value nan.
# Trial 074 | k = 20 | ridge =   7.48e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:22,885] Trial 74 failed with parameters: {'k': 20, 'ridge': 74.8493147525603} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:22,886] Trial 74 failed with value nan.
# Trial 075 | k = 20 | ridge =   4.24e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:23,733] Trial 75 failed with parameters: {'k': 20, 'ridge': 42.43534231722875} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:23,734] Trial 75 failed with value nan.
# Trial 076 | k = 20 | ridge =   2.45e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:24,565] Trial 76 failed with parameters: {'k': 20, 'ridge': 245.1332181410584} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:24,566] Trial 76 failed with value nan.
# Trial 077 | k = 20 | ridge =   1.13e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:25,398] Trial 77 failed with parameters: {'k': 20, 'ridge': 11.291587188124035} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:25,399] Trial 77 failed with value nan.
# Trial 078 | k = 20 | ridge =   5.37e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:26,230] Trial 78 failed with parameters: {'k': 20, 'ridge': 53.72550134450467} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:26,231] Trial 78 failed with value nan.
# Trial 079 | k = 20 | ridge =   1.97e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:27,065] Trial 79 failed with parameters: {'k': 20, 'ridge': 196.80368932628738} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:27,065] Trial 79 failed with value nan.
# Trial 080 | k = 20 | ridge =   3.81e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:27,902] Trial 80 failed with parameters: {'k': 20, 'ridge': 38.091906424603586} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:27,902] Trial 80 failed with value nan.
# Trial 081 | k = 20 | ridge =   2.72e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:28,735] Trial 81 failed with parameters: {'k': 20, 'ridge': 27.242159401002198} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:28,736] Trial 81 failed with value nan.
# Trial 082 | k = 20 | ridge =   1.21e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:29,582] Trial 82 failed with parameters: {'k': 20, 'ridge': 120.85933811879876} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:29,583] Trial 82 failed with value nan.
# Trial 083 | k = 20 | ridge =   4.75e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:30,466] Trial 83 failed with parameters: {'k': 20, 'ridge': 47.50916869358515} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:30,467] Trial 83 failed with value nan.
# Trial 084 | k = 20 | ridge =   3.89e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:31,844] Trial 84 failed with parameters: {'k': 20, 'ridge': 38.922068319175665} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:31,845] Trial 84 failed with value nan.
# Trial 085 | k = 20 | ridge =   5.48e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:33,164] Trial 85 failed with parameters: {'k': 20, 'ridge': 54.849973006666765} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:33,165] Trial 85 failed with value nan.
# Trial 086 | k = 20 | ridge =   3.37e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:34,006] Trial 86 failed with parameters: {'k': 20, 'ridge': 33.719928909435374} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:34,007] Trial 86 failed with value nan.
# Trial 087 | k = 20 | ridge =   5.18e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:35,181] Trial 87 failed with parameters: {'k': 20, 'ridge': 51.77625517966368} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:35,182] Trial 87 failed with value nan.
# Trial 088 | k = 20 | ridge =   8.29e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:35,912] Trial 88 failed with parameters: {'k': 20, 'ridge': 82.92256023790647} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:35,913] Trial 88 failed with value nan.
# Trial 089 | k = 20 | ridge =   4.17e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:36,634] Trial 89 failed with parameters: {'k': 20, 'ridge': 41.65159087821151} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:36,635] Trial 89 failed with value nan.
# Trial 090 | k = 20 | ridge =   3.77e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:37,359] Trial 90 failed with parameters: {'k': 20, 'ridge': 37.66883812427526} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:37,360] Trial 90 failed with value nan.
# Trial 091 | k = 20 | ridge =   2.30e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:38,079] Trial 91 failed with parameters: {'k': 20, 'ridge': 23.024222842202924} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:38,079] Trial 91 failed with value nan.
# Trial 092 | k = 20 | ridge =   2.24e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:38,802] Trial 92 failed with parameters: {'k': 20, 'ridge': 22.397848252016594} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:38,802] Trial 92 failed with value nan.
# Trial 093 | k = 20 | ridge =   7.65e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:39,523] Trial 93 failed with parameters: {'k': 20, 'ridge': 76.51630400673406} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:39,524] Trial 93 failed with value nan.
# Trial 094 | k = 20 | ridge =   3.77e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:40,243] Trial 94 failed with parameters: {'k': 20, 'ridge': 37.72527432268766} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:40,244] Trial 94 failed with value nan.
# Trial 095 | k = 20 | ridge =   5.46e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:40,963] Trial 95 failed with parameters: {'k': 20, 'ridge': 54.61854582789503} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:40,963] Trial 95 failed with value nan.
# Trial 096 | k = 20 | ridge =   4.72e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:41,682] Trial 96 failed with parameters: {'k': 20, 'ridge': 47.206523767236725} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:41,683] Trial 96 failed with value nan.
# Trial 097 | k = 20 | ridge =   1.21e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:42,402] Trial 97 failed with parameters: {'k': 20, 'ridge': 12.12387507319828} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:42,403] Trial 97 failed with value nan.
# Trial 098 | k = 20 | ridge =   7.57e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:43,124] Trial 98 failed with parameters: {'k': 20, 'ridge': 75.67495972530736} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:43,125] Trial 98 failed with value nan.
# Trial 099 | k = 20 | ridge =   3.59e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:43,850] Trial 99 failed with parameters: {'k': 20, 'ridge': 35.864389392810416} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:43,851] Trial 99 failed with value nan.
# Trial 100 | k = 20 | ridge =   1.99e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:44,571] Trial 100 failed with parameters: {'k': 20, 'ridge': 19.89914840559665} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:44,572] Trial 100 failed with value nan.
# Trial 101 | k = 20 | ridge =   4.70e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:45,291] Trial 101 failed with parameters: {'k': 20, 'ridge': 46.97256854589311} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:45,292] Trial 101 failed with value nan.
# Trial 102 | k = 20 | ridge =   1.17e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:46,017] Trial 102 failed with parameters: {'k': 20, 'ridge': 117.30955040356868} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:46,018] Trial 102 failed with value nan.
# Trial 103 | k = 20 | ridge =   8.60e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:46,739] Trial 103 failed with parameters: {'k': 20, 'ridge': 85.95757925350169} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:46,740] Trial 103 failed with value nan.
# Trial 104 | k = 20 | ridge =   3.95e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:47,462] Trial 104 failed with parameters: {'k': 20, 'ridge': 39.52760593292013} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:47,464] Trial 104 failed with value nan.
# Trial 105 | k = 20 | ridge =   3.75e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:48,195] Trial 105 failed with parameters: {'k': 20, 'ridge': 37.47771520927165} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:48,197] Trial 105 failed with value nan.
# Trial 106 | k = 20 | ridge =   6.32e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:48,921] Trial 106 failed with parameters: {'k': 20, 'ridge': 63.19995710616826} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:48,922] Trial 106 failed with value nan.
# Trial 107 | k = 20 | ridge =   3.36e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:49,639] Trial 107 failed with parameters: {'k': 20, 'ridge': 33.606464420809594} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:49,640] Trial 107 failed with value nan.
# Trial 108 | k = 20 | ridge =   3.78e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:50,364] Trial 108 failed with parameters: {'k': 20, 'ridge': 37.82823480177106} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:50,365] Trial 108 failed with value nan.
# Trial 109 | k = 20 | ridge =   2.07e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:51,085] Trial 109 failed with parameters: {'k': 20, 'ridge': 20.72898962075721} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:51,085] Trial 109 failed with value nan.
# Trial 110 | k = 20 | ridge =   2.14e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:51,826] Trial 110 failed with parameters: {'k': 20, 'ridge': 213.7830789646669} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:51,826] Trial 110 failed with value nan.
# Trial 111 | k = 20 | ridge =   5.10e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:52,546] Trial 111 failed with parameters: {'k': 20, 'ridge': 51.01755516389347} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:52,547] Trial 111 failed with value nan.
# Trial 112 | k = 20 | ridge =   8.04e+00 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:53,262] Trial 112 failed with parameters: {'k': 20, 'ridge': 8.037963816532308} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:53,263] Trial 112 failed with value nan.
# Trial 113 | k = 20 | ridge =   4.20e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:53,979] Trial 113 failed with parameters: {'k': 20, 'ridge': 42.026002527029405} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:53,980] Trial 113 failed with value nan.
# Trial 114 | k = 20 | ridge =   1.74e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:54,694] Trial 114 failed with parameters: {'k': 20, 'ridge': 173.58116411268063} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:54,695] Trial 114 failed with value nan.
# Trial 115 | k = 20 | ridge =   1.10e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:55,414] Trial 115 failed with parameters: {'k': 20, 'ridge': 110.45648583519564} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:55,415] Trial 115 failed with value nan.
# Trial 116 | k = 20 | ridge =   3.47e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:56,134] Trial 116 failed with parameters: {'k': 20, 'ridge': 34.682910983175994} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:56,135] Trial 116 failed with value nan.
# Trial 117 | k = 20 | ridge =   2.56e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:56,855] Trial 117 failed with parameters: {'k': 20, 'ridge': 25.592524167190362} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:56,856] Trial 117 failed with value nan.
# Trial 118 | k = 20 | ridge =   4.90e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:57,578] Trial 118 failed with parameters: {'k': 20, 'ridge': 48.981917061294716} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:57,579] Trial 118 failed with value nan.
# Trial 119 | k = 20 | ridge =   2.06e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:58,300] Trial 119 failed with parameters: {'k': 20, 'ridge': 20.641177645105564} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:58,301] Trial 119 failed with value nan.
# Trial 120 | k = 20 | ridge =   2.59e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:59,022] Trial 120 failed with parameters: {'k': 20, 'ridge': 25.884538476563772} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:59,022] Trial 120 failed with value nan.
# Trial 121 | k = 20 | ridge =   5.77e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:10:59,742] Trial 121 failed with parameters: {'k': 20, 'ridge': 57.70479235746855} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:10:59,743] Trial 121 failed with value nan.
# Trial 122 | k = 20 | ridge =   6.57e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:00,468] Trial 122 failed with parameters: {'k': 20, 'ridge': 65.67518197827177} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:00,469] Trial 122 failed with value nan.
# Trial 123 | k = 20 | ridge =   2.72e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:01,191] Trial 123 failed with parameters: {'k': 20, 'ridge': 27.167983296462516} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:01,191] Trial 123 failed with value nan.
# Trial 124 | k = 20 | ridge =   2.63e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:01,910] Trial 124 failed with parameters: {'k': 20, 'ridge': 26.288874663203195} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:01,911] Trial 124 failed with value nan.
# Trial 125 | k = 20 | ridge =   3.75e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:02,633] Trial 125 failed with parameters: {'k': 20, 'ridge': 37.46574187653066} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:02,634] Trial 125 failed with value nan.
# Trial 126 | k = 20 | ridge =   6.40e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:03,352] Trial 126 failed with parameters: {'k': 20, 'ridge': 64.00429800783155} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:03,353] Trial 126 failed with value nan.
# Trial 127 | k = 20 | ridge =   5.06e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:04,072] Trial 127 failed with parameters: {'k': 20, 'ridge': 50.55481880344202} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:04,073] Trial 127 failed with value nan.
# Trial 128 | k = 20 | ridge =   4.18e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:04,792] Trial 128 failed with parameters: {'k': 20, 'ridge': 41.83665863504965} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:04,793] Trial 128 failed with value nan.
# Trial 129 | k = 20 | ridge =   5.68e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:05,514] Trial 129 failed with parameters: {'k': 20, 'ridge': 56.75091494194194} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:05,515] Trial 129 failed with value nan.
# Trial 130 | k = 20 | ridge =   4.23e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:06,236] Trial 130 failed with parameters: {'k': 20, 'ridge': 42.25923879680593} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:06,237] Trial 130 failed with value nan.
# Trial 131 | k = 20 | ridge =   1.52e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:06,958] Trial 131 failed with parameters: {'k': 20, 'ridge': 152.1047606758671} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:06,958] Trial 131 failed with value nan.
# Trial 132 | k = 20 | ridge =   8.15e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:07,678] Trial 132 failed with parameters: {'k': 20, 'ridge': 81.54609521896627} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:07,679] Trial 132 failed with value nan.
# Trial 133 | k = 20 | ridge =   1.53e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:08,398] Trial 133 failed with parameters: {'k': 20, 'ridge': 15.279668392635159} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:08,399] Trial 133 failed with value nan.
# Trial 134 | k = 20 | ridge =   5.99e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:09,118] Trial 134 failed with parameters: {'k': 20, 'ridge': 59.87786455441112} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:09,118] Trial 134 failed with value nan.
# Trial 135 | k = 20 | ridge =   6.18e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:09,835] Trial 135 failed with parameters: {'k': 20, 'ridge': 61.77091589669612} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:09,835] Trial 135 failed with value nan.
# Trial 136 | k = 20 | ridge =   9.95e+00 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:10,561] Trial 136 failed with parameters: {'k': 20, 'ridge': 9.946931916972131} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:10,562] Trial 136 failed with value nan.
# Trial 137 | k = 20 | ridge =   9.53e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:11,285] Trial 137 failed with parameters: {'k': 20, 'ridge': 95.27502168947827} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:11,286] Trial 137 failed with value nan.
# Trial 138 | k = 20 | ridge =   5.47e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:12,005] Trial 138 failed with parameters: {'k': 20, 'ridge': 54.729108717687566} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:12,006] Trial 138 failed with value nan.
# Trial 139 | k = 20 | ridge =   5.11e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:12,727] Trial 139 failed with parameters: {'k': 20, 'ridge': 51.054329860844575} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:12,728] Trial 139 failed with value nan.
# Trial 140 | k = 20 | ridge =   7.48e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:13,446] Trial 140 failed with parameters: {'k': 20, 'ridge': 74.78053556038115} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:13,447] Trial 140 failed with value nan.
# Trial 141 | k = 20 | ridge =   3.74e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:14,192] Trial 141 failed with parameters: {'k': 20, 'ridge': 37.36119009754102} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:14,193] Trial 141 failed with value nan.
# Trial 142 | k = 20 | ridge =   9.72e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:14,911] Trial 142 failed with parameters: {'k': 20, 'ridge': 97.19423581699654} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:14,912] Trial 142 failed with value nan.
# Trial 143 | k = 20 | ridge =   6.90e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:15,640] Trial 143 failed with parameters: {'k': 20, 'ridge': 68.99113024383549} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:15,641] Trial 143 failed with value nan.
# Trial 144 | k = 20 | ridge =   3.44e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:16,361] Trial 144 failed with parameters: {'k': 20, 'ridge': 34.43581905060921} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:16,362] Trial 144 failed with value nan.
# Trial 145 | k = 20 | ridge =   6.55e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:17,082] Trial 145 failed with parameters: {'k': 20, 'ridge': 65.46408052225765} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:17,082] Trial 145 failed with value nan.
# Trial 146 | k = 20 | ridge =   1.33e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:17,803] Trial 146 failed with parameters: {'k': 20, 'ridge': 13.270079046862163} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:17,804] Trial 146 failed with value nan.
# Trial 147 | k = 20 | ridge =   5.55e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:18,524] Trial 147 failed with parameters: {'k': 20, 'ridge': 55.46452135016564} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:18,526] Trial 147 failed with value nan.
# Trial 148 | k = 20 | ridge =   1.04e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:19,242] Trial 148 failed with parameters: {'k': 20, 'ridge': 103.50703596767349} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:19,243] Trial 148 failed with value nan.
# Trial 149 | k = 20 | ridge =   7.23e+00 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:19,961] Trial 149 failed with parameters: {'k': 20, 'ridge': 7.228096111505016} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:19,962] Trial 149 failed with value nan.
# Trial 150 | k = 20 | ridge =   2.57e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:20,685] Trial 150 failed with parameters: {'k': 20, 'ridge': 25.729904605731654} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:20,686] Trial 150 failed with value nan.
# Trial 151 | k = 20 | ridge =   6.60e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:21,406] Trial 151 failed with parameters: {'k': 20, 'ridge': 65.99568383164218} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:21,407] Trial 151 failed with value nan.
# Trial 152 | k = 20 | ridge =   4.65e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:22,124] Trial 152 failed with parameters: {'k': 20, 'ridge': 46.47723751205813} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:22,125] Trial 152 failed with value nan.
# Trial 153 | k = 20 | ridge =   3.14e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:22,842] Trial 153 failed with parameters: {'k': 20, 'ridge': 31.44698854504509} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:22,842] Trial 153 failed with value nan.
# Trial 154 | k = 20 | ridge =   3.51e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:23,562] Trial 154 failed with parameters: {'k': 20, 'ridge': 35.07968280395901} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:23,563] Trial 154 failed with value nan.
# Trial 155 | k = 20 | ridge =   1.79e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:24,282] Trial 155 failed with parameters: {'k': 20, 'ridge': 179.02439594959804} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:24,283] Trial 155 failed with value nan.
# Trial 156 | k = 20 | ridge =   7.60e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:25,000] Trial 156 failed with parameters: {'k': 20, 'ridge': 75.99014760587218} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:25,001] Trial 156 failed with value nan.
# Trial 157 | k = 20 | ridge =   7.95e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:25,718] Trial 157 failed with parameters: {'k': 20, 'ridge': 79.49987848926605} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:25,718] Trial 157 failed with value nan.
# Trial 158 | k = 20 | ridge =   4.78e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:26,436] Trial 158 failed with parameters: {'k': 20, 'ridge': 47.79823411480824} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:26,437] Trial 158 failed with value nan.
# Trial 159 | k = 20 | ridge =   1.28e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:27,154] Trial 159 failed with parameters: {'k': 20, 'ridge': 127.66397749014146} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:27,154] Trial 159 failed with value nan.
# Trial 160 | k = 20 | ridge =   1.42e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:27,873] Trial 160 failed with parameters: {'k': 20, 'ridge': 14.171870153595728} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:27,874] Trial 160 failed with value nan.
# Trial 161 | k = 20 | ridge =   1.06e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:28,592] Trial 161 failed with parameters: {'k': 20, 'ridge': 106.17695879974019} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:28,593] Trial 161 failed with value nan.
# Trial 162 | k = 20 | ridge =   5.92e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:29,311] Trial 162 failed with parameters: {'k': 20, 'ridge': 59.17041008749264} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:29,312] Trial 162 failed with value nan.
# Trial 163 | k = 20 | ridge =   7.63e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:30,032] Trial 163 failed with parameters: {'k': 20, 'ridge': 76.29557561848078} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:30,033] Trial 163 failed with value nan.
# Trial 164 | k = 20 | ridge =   3.99e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:30,755] Trial 164 failed with parameters: {'k': 20, 'ridge': 39.920592222076} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:30,755] Trial 164 failed with value nan.
# Trial 165 | k = 20 | ridge =   6.09e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:31,473] Trial 165 failed with parameters: {'k': 20, 'ridge': 60.941235483263654} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:31,474] Trial 165 failed with value nan.
# Trial 166 | k = 20 | ridge =   1.15e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:32,191] Trial 166 failed with parameters: {'k': 20, 'ridge': 114.8931289202339} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:32,191] Trial 166 failed with value nan.
# Trial 167 | k = 20 | ridge =   4.70e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:32,907] Trial 167 failed with parameters: {'k': 20, 'ridge': 46.97815490318226} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:32,908] Trial 167 failed with value nan.
# Trial 168 | k = 20 | ridge =   2.02e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:33,627] Trial 168 failed with parameters: {'k': 20, 'ridge': 20.164547450466404} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:33,627] Trial 168 failed with value nan.
# Trial 169 | k = 20 | ridge =   4.50e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:34,344] Trial 169 failed with parameters: {'k': 20, 'ridge': 45.01040371876615} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:34,345] Trial 169 failed with value nan.
# Trial 170 | k = 20 | ridge =   1.02e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:35,058] Trial 170 failed with parameters: {'k': 20, 'ridge': 102.14718706050053} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:35,059] Trial 170 failed with value nan.
# Trial 171 | k = 20 | ridge =   5.56e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:35,776] Trial 171 failed with parameters: {'k': 20, 'ridge': 55.635337447536564} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:35,777] Trial 171 failed with value nan.
# Trial 172 | k = 20 | ridge =   4.96e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:36,494] Trial 172 failed with parameters: {'k': 20, 'ridge': 49.6037239258486} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:36,495] Trial 172 failed with value nan.
# Trial 173 | k = 20 | ridge =   2.97e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:37,213] Trial 173 failed with parameters: {'k': 20, 'ridge': 29.69681827833219} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:37,214] Trial 173 failed with value nan.
# Trial 174 | k = 20 | ridge =   1.34e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:37,934] Trial 174 failed with parameters: {'k': 20, 'ridge': 13.401637940893776} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:37,935] Trial 174 failed with value nan.
# Trial 175 | k = 20 | ridge =   2.78e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:38,653] Trial 175 failed with parameters: {'k': 20, 'ridge': 27.778236440451483} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:38,654] Trial 175 failed with value nan.
# Trial 176 | k = 20 | ridge =   5.57e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:39,372] Trial 176 failed with parameters: {'k': 20, 'ridge': 55.678692870243154} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:39,372] Trial 176 failed with value nan.
# Trial 177 | k = 20 | ridge =   4.71e+00 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:40,091] Trial 177 failed with parameters: {'k': 20, 'ridge': 4.712775425833726} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:40,092] Trial 177 failed with value nan.
# Trial 178 | k = 20 | ridge =   2.73e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:40,821] Trial 178 failed with parameters: {'k': 20, 'ridge': 27.273213727974742} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:40,821] Trial 178 failed with value nan.
# Trial 179 | k = 20 | ridge =   3.82e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:41,540] Trial 179 failed with parameters: {'k': 20, 'ridge': 38.151511437553346} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:41,541] Trial 179 failed with value nan.
# Trial 180 | k = 20 | ridge =   2.71e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:42,258] Trial 180 failed with parameters: {'k': 20, 'ridge': 27.088774103274886} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:42,259] Trial 180 failed with value nan.
# Trial 181 | k = 20 | ridge =   4.17e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:42,979] Trial 181 failed with parameters: {'k': 20, 'ridge': 41.711235364287944} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:42,979] Trial 181 failed with value nan.
# Trial 182 | k = 20 | ridge =   3.02e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:43,700] Trial 182 failed with parameters: {'k': 20, 'ridge': 30.195621422655673} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:43,701] Trial 182 failed with value nan.
# Trial 183 | k = 20 | ridge =   5.00e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:44,418] Trial 183 failed with parameters: {'k': 20, 'ridge': 50.00850800917457} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:44,419] Trial 183 failed with value nan.
# Trial 184 | k = 20 | ridge =   3.02e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:45,137] Trial 184 failed with parameters: {'k': 20, 'ridge': 30.223023208018336} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:45,138] Trial 184 failed with value nan.
# Trial 185 | k = 20 | ridge =   9.14e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:45,855] Trial 185 failed with parameters: {'k': 20, 'ridge': 91.40220035011232} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:45,856] Trial 185 failed with value nan.
# Trial 186 | k = 20 | ridge =   3.99e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:46,574] Trial 186 failed with parameters: {'k': 20, 'ridge': 39.91175722503707} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:46,575] Trial 186 failed with value nan.
# Trial 187 | k = 20 | ridge =   6.10e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:47,291] Trial 187 failed with parameters: {'k': 20, 'ridge': 60.98617679743034} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:47,292] Trial 187 failed with value nan.
# Trial 188 | k = 20 | ridge =   3.01e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:48,009] Trial 188 failed with parameters: {'k': 20, 'ridge': 30.079946815115136} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:48,009] Trial 188 failed with value nan.
# Trial 189 | k = 20 | ridge =   2.33e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:48,727] Trial 189 failed with parameters: {'k': 20, 'ridge': 23.339694235374353} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:48,728] Trial 189 failed with value nan.
# Trial 190 | k = 20 | ridge =   2.26e+02 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:49,444] Trial 190 failed with parameters: {'k': 20, 'ridge': 226.18442989348947} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:49,445] Trial 190 failed with value nan.
# Trial 191 | k = 20 | ridge =   4.04e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:50,165] Trial 191 failed with parameters: {'k': 20, 'ridge': 40.41468012681057} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:50,166] Trial 191 failed with value nan.
# Trial 192 | k = 20 | ridge =   2.58e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:50,889] Trial 192 failed with parameters: {'k': 20, 'ridge': 25.812595244937846} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:50,890] Trial 192 failed with value nan.
# Trial 193 | k = 20 | ridge =   4.95e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:51,610] Trial 193 failed with parameters: {'k': 20, 'ridge': 49.51433511631723} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:51,610] Trial 193 failed with value nan.
# Trial 194 | k = 20 | ridge =   8.00e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:52,328] Trial 194 failed with parameters: {'k': 20, 'ridge': 80.04624997386998} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:52,330] Trial 194 failed with value nan.
# Trial 195 | k = 20 | ridge =   2.23e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:53,049] Trial 195 failed with parameters: {'k': 20, 'ridge': 22.344822092561014} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:53,050] Trial 195 failed with value nan.
# Trial 196 | k = 20 | ridge =   9.58e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:53,769] Trial 196 failed with parameters: {'k': 20, 'ridge': 95.83338738112808} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:53,769] Trial 196 failed with value nan.
# Trial 197 | k = 20 | ridge =   3.87e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:54,487] Trial 197 failed with parameters: {'k': 20, 'ridge': 38.696633343627255} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:54,488] Trial 197 failed with value nan.
# Trial 198 | k = 20 | ridge =   5.32e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:55,207] Trial 198 failed with parameters: {'k': 20, 'ridge': 53.237367873268596} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:55,208] Trial 198 failed with value nan.
# Trial 199 | k = 20 | ridge =   5.92e+01 | MSE = nan | MAE = nan | RMSE = nan
# [W 2026-07-26 22:11:55,928] Trial 199 failed with parameters: {'k': 20, 'ridge': 59.23034977114196} because of the following error: The value nan is not acceptable.
# [W 2026-07-26 22:11:55,928] Trial 199 failed with value nan.
#
# ==== Optimal NG-RC Configuration ====
#
# Optimal delay dimension (k) : 20
# Optimal ridge parameter     : 1.56e+05
# Best validation MSE         : nan
# Best validation MAE         : nan
# Best validation RMSE        : 23.574432
# Execution time              : 150.91 seconds

# %%
# ============================================================
# 8. Select Optimal NG-RC Model
# ============================================================

valid_results = [r for r in results if np.isfinite(r["rmse"])]

if not valid_results:
    raise RuntimeError("No valid hyperparameter configuration found.")

best_result = min(valid_results, key=lambda r: r["rmse"])

best_k = best_result["k"]
best_ridge = best_result["ridge"]
best_mse = best_result["mse"]
best_mae = best_result["mae"]
best_rmse = best_result["rmse"]

print("\n==== Optimal NG-RC Configuration ====\n")
print(f"Delay dimension (k)    : {best_k}")
print(f"Ridge regularization   : {best_ridge:.2e}")
print(f"Validation MSE         : {best_mse:.6f}")
print(f"Validation MAE         : {best_mae:.6f}")
print(f"Validation RMSE        : {best_rmse:.6f}")


# ============================================================
# 9. Retrain NG-RC Using Optimal Hyperparameters
# ============================================================

train_start = warmup_pts - 1
train_end = warmtrain_pts - 1

# Construct NVAR training features
train_features, _ = build_features(X_soln, best_k, train_start, train_end)

# One-step latent increments
delta_x = X_soln[:, warmup_pts:warmtrain_pts] - X_soln[:, warmup_pts - 1 : warmtrain_pts - 1]

# Feature Dimensions
d_linear = d * best_k
d_quadratic = (d_linear * (d_linear + 1)) // 2
d_total = 1 + d_linear + d_quadratic

# Ridge Regression System
cov_matrix = train_features @ train_features.T
reg_matrix = cov_matrix + best_ridge * np.eye(d_total)

try:
    W_out = np.linalg.solve(reg_matrix.T, (delta_x @ train_features.T).T).T
except np.linalg.LinAlgError:
    W_out = delta_x @ train_features.T @ np.linalg.pinv(reg_matrix)


# ============================================================
# 10. Autonomous Forecast Evaluation on TEST Dataset
# ============================================================

test_start = val_end
test_end = maxtime_pts

window_size = 90
stride = 1
horizons = [10, 30, 60, 90]

# Containers (Latent Space)
all_true, all_pred = [], []
all_mse, all_mae, all_rmse = [], [], []

# Containers (Original SST Space)
all_rec_sst, all_true_sst = [], []
all_mse_sst, all_mae_sst, all_rmse_sst = [], [], []

# ============================================================
# Persistence Baseline (SST Space)
# ============================================================

all_persist_mse_sst = []
all_persist_mae_sst = []
all_persist_rmse_sst = []

horizon_persist_mses_sst = {h: [] for h in horizons}
horizon_persist_maes_sst = {h: [] for h in horizons}

# Horizon-wise Storage
horizon_mses = {h: [] for h in horizons}
horizon_maes = {h: [] for h in horizons}
horizon_sst_mses = {h: [] for h in horizons}
horizon_sst_maes = {h: [] for h in horizons}

# Pre-index upper-triangular terms for fast vectorization in rollout
r_idx, c_idx = np.triu_indices(d_linear)

print("\n==== NG-RC TEST Evaluation ====\n")

for start in range(test_start, test_end - window_size + 1, stride):
    end = start + window_size

    # Initialize Delay History
    history = [X_soln[:, start - best_k + i].copy() for i in range(best_k)]
    prediction = np.zeros((d, window_size))

    # Autonomous Rollout
    for step in range(window_size):
        z = np.hstack([history[-1 - delay] for delay in range(best_k)])

        test_features = np.ones(d_total)
        test_features[1 : 1 + d_linear] = z
        test_features[1 + d_linear :] = z[r_idx] * z[c_idx]

        delta_pred = W_out @ test_features
        next_state = history[-1] + delta_pred

        prediction[:, step] = next_state
        history.append(next_state)

    truth = X_soln[:, start:end]

    # Reconstruct SST Fields
    predicted_pcs = prediction.T
    reconstructed_sst = pca.inverse_transform(predicted_pcs)
    true_sst = sst_time_major[start:end]
    
    # Standard Persistence Forecast (SST Space)
    persistent_sst = np.repeat(true_sst[0][None, :], window_size, axis=0)

    all_rec_sst.append(reconstructed_sst)
    all_true_sst.append(true_sst)

    # Point-in-Time Horizon Errors
    for h in horizons:
        if h > window_size:
            continue

        idx = h - 1  # Target exact lead step

        # Latent Space (per-variable error at lead step h)
        horizon_mses[h].append((truth[:, idx] - prediction[:, idx]) ** 2)
        horizon_maes[h].append(np.abs(truth[:, idx] - prediction[:, idx]))

        # Reconstructed SST Space (spatial average error at lead step h)
        horizon_sst_mses[h].append((true_sst[idx] - reconstructed_sst[idx]) ** 2)
        horizon_sst_maes[h].append(np.abs(true_sst[idx] - reconstructed_sst[idx]))
        
        # Persistence Baseline
        horizon_persist_mses_sst[h].append((true_sst[idx] - persistent_sst[idx]) ** 2)
        horizon_persist_maes_sst[h].append(np.abs(true_sst[idx] - persistent_sst[idx]))
        
    # Full-window Errors
    # Latent Space
    full_mse = np.mean((truth - prediction) ** 2)
    full_mae = np.mean(np.abs(truth - prediction))
    full_rmse = np.sqrt(full_mse)

    all_mse.append(full_mse)
    all_mae.append(full_mae)
    all_rmse.append((start, end, full_rmse))

    # SST Space
    full_mse_sst = np.mean((true_sst - reconstructed_sst) ** 2)
    full_mae_sst = np.mean(np.abs(true_sst - reconstructed_sst))
    full_rmse_sst = np.sqrt(full_mse_sst)

    # Persistence Baseline (Full Window)
    persist_mse_sst = np.mean((true_sst - persistent_sst) ** 2)
    persist_mae_sst = np.mean(np.abs(true_sst - persistent_sst))
    persist_rmse_sst = np.sqrt(persist_mse_sst)

    all_persist_mse_sst.append(persist_mse_sst)
    all_persist_mae_sst.append(persist_mae_sst)
    all_persist_rmse_sst.append((start, end, persist_rmse_sst))

    all_mse_sst.append(full_mse_sst)
    all_mae_sst.append(full_mae_sst)
    all_rmse_sst.append((start, end, full_rmse_sst))

    all_true.append(truth)
    all_pred.append(prediction)


# ============================================================
# 11. Aggregate Array Formatting
# ============================================================

all_true = np.hstack(all_true) if all_true else np.empty((d, 0))
all_pred = np.hstack(all_pred) if all_pred else np.empty((d, 0))
all_rec_sst = np.concatenate(all_rec_sst) if all_rec_sst else np.empty((0, sst_time_major.shape[1]))
all_true_sst = np.concatenate(all_true_sst) if all_true_sst else np.empty((0, sst_time_major.shape[1]))


# ============================================================
# 12. Horizon-wise Forecast Skill Summary
# ============================================================

latent_variables = [f"PC {i+1}" for i in range(d)]

# --- 1. LATENT SPACE METRICS ---
print("\n" + "=" * 60)
print("  TEST Horizon-wise Forecast Skill (LATENT SPACE)")
print("=" * 60)

for h in horizons:
    if not horizon_mses[h]:
        continue

    mse_array = np.vstack(horizon_mses[h])
    mae_array = np.vstack(horizon_maes[h])

    mean_mse_per_variable = np.mean(mse_array, axis=0)
    mean_mae_per_variable = np.mean(mae_array, axis=0)
    rmse_per_variable = np.sqrt(mean_mse_per_variable)

    overall_mse = np.mean(mean_mse_per_variable)
    overall_mae = np.mean(mean_mae_per_variable)
    overall_rmse = np.sqrt(overall_mse)

    print(f"\n-- Forecast Horizon: Step {h} --")
    for i, var in enumerate(latent_variables):
        print(f"{var:<8} | MSE : {mean_mse_per_variable[i]:.6f} | MAE : {mean_mae_per_variable[i]:.6f} | RMSE : {rmse_per_variable[i]:.6f}")

    print(f"Overall   | MSE : {overall_mse:.6f} | MAE : {overall_mae:.6f} | RMSE : {overall_rmse:.6f}")


# --- 2. RECONSTRUCTED SST SPACE METRICS ---
print("\n" + "=" * 60)
print("  TEST Horizon-wise Forecast Skill (RECONSTRUCTED SST)")
print("=" * 60)

for h in horizons:
    if not horizon_sst_mses[h]:
        continue

    # NG-RC
    mse_array_sst = np.vstack(horizon_sst_mses[h])
    mae_array_sst = np.vstack(horizon_sst_maes[h])

    overall_mse_sst = np.mean(mse_array_sst)
    overall_mae_sst = np.mean(mae_array_sst)
    overall_rmse_sst = np.sqrt(overall_mse_sst)

    # Persistence
    persist_mse = np.mean(np.vstack(horizon_persist_mses_sst[h]))
    persist_mae = np.mean(np.vstack(horizon_persist_maes_sst[h]))
    persist_rmse = np.sqrt(persist_mse)

    # Percentage Improvements (Positive means NG-RC is better)
    imp_mse = ((persist_mse - overall_mse_sst) / persist_mse) * 100
    imp_mae = ((persist_mae - overall_mae_sst) / persist_mae) * 100
    imp_rmse = ((persist_rmse - overall_rmse_sst) / persist_rmse) * 100

    print(f"\n-- Forecast Horizon: Step {h} --")
    print(f"NG-RC       | MSE : {overall_mse_sst:.6f} | MAE : {overall_mae_sst:.6f} | RMSE : {overall_rmse_sst:.6f}")
    print(f"Persistence | MSE : {persist_mse:.6f} | MAE : {persist_mae:.6f} | RMSE : {persist_rmse:.6f}")
    print(f"Improvement | MSE : {imp_mse:+.2f}%   | MAE : {imp_mae:+.2f}%   | RMSE : {imp_rmse:+.2f}%")


# --- 3. OVERALL TEST SUMMARY ---
print("\n" + "=" * 60)
print("  Overall TEST Summary (Full Window Averages)")
print("=" * 60 + "\n")

overall_ng_mse_sst = np.mean(all_mse_sst)
overall_ng_mae_sst = np.mean(all_mae_sst)
overall_ng_rmse_sst = np.mean([x[2] for x in all_rmse_sst])

overall_per_mse_sst = np.mean(all_persist_mse_sst)
overall_per_mae_sst = np.mean(all_persist_mae_sst)
overall_per_rmse_sst = np.mean([x[2] for x in all_persist_rmse_sst])

# Overall Improvements
overall_imp_mse = ((overall_per_mse_sst - overall_ng_mse_sst) / overall_per_mse_sst) * 100
overall_imp_mae = ((overall_per_mae_sst - overall_ng_mae_sst) / overall_per_mae_sst) * 100
overall_imp_rmse = ((overall_per_rmse_sst - overall_ng_rmse_sst) / overall_per_rmse_sst) * 100

print(f"Latent Space (NG-RC)  | MSE : {np.mean(all_mse):.6f} | MAE : {np.mean(all_mae):.6f} | RMSE : {np.mean([x[2] for x in all_rmse]):.6f}")
print(f"SST Space (NG-RC)     | MSE : {overall_ng_mse_sst:.6f} | MAE : {overall_ng_mae_sst:.6f} | RMSE : {overall_ng_rmse_sst:.6f}")
print(f"SST Space (Persist)   | MSE : {overall_per_mse_sst:.6f} | MAE : {overall_per_mae_sst:.6f} | RMSE : {overall_per_rmse_sst:.6f}")
print(f"Improvement vs Pers.  | MSE : {overall_imp_mse:+.2f}%   | MAE : {overall_imp_mae:+.2f}%   | RMSE : {overall_imp_rmse:+.2f}%")

print("-" * 60)
print(f"TEST Window Size   : {window_size}")
print(f"TEST Stride        : {stride}")
print(f"Total TEST Windows : {len(all_rmse)}")
print("=" * 60)
# Out:
# ==== Optimal NG-RC Configuration ====
#
# Delay dimension (k)    : 20
# Ridge regularization   : 1.56e+05
# Validation MSE         : 769.398385
# Validation MAE         : 19.871598
# Validation RMSE        : 23.574432
#
# ==== NG-RC TEST Evaluation ====
#
#
# ============================================================
#   TEST Horizon-wise Forecast Skill (LATENT SPACE)
# ============================================================
#
# -- Forecast Horizon: Step 10 --
# PC 1     | MSE : 45.450964 | MAE : 5.089319 | RMSE : 6.741733
# Overall   | MSE : 45.450964 | MAE : 5.089319 | RMSE : 6.741733
#
# -- Forecast Horizon: Step 30 --
# PC 1     | MSE : 296.548386 | MAE : 13.798366 | RMSE : 17.220580
# Overall   | MSE : 296.548386 | MAE : 13.798366 | RMSE : 17.220580
#
# -- Forecast Horizon: Step 60 --
# PC 1     | MSE : 1119.319595 | MAE : 27.562644 | RMSE : 33.456234
# Overall   | MSE : 1119.319595 | MAE : 27.562644 | RMSE : 33.456234
#
# -- Forecast Horizon: Step 90 --
# PC 1     | MSE : 2127.984611 | MAE : 38.472516 | RMSE : 46.130084
# Overall   | MSE : 2127.984611 | MAE : 38.472516 | RMSE : 46.130084
#
# ============================================================
#   TEST Horizon-wise Forecast Skill (RECONSTRUCTED SST)
# ============================================================
#
# -- Forecast Horizon: Step 10 --
# NG-RC       | MSE : 0.060074 | MAE : 0.182463 | RMSE : 0.245100
# Persistence | MSE : 0.072619 | MAE : 0.203251 | RMSE : 0.269480
# Improvement | MSE : +17.28%   | MAE : +10.23%   | RMSE : +9.05%
#
# -- Forecast Horizon: Step 30 --
# NG-RC       | MSE : 0.143938 | MAE : 0.296527 | RMSE : 0.379392
# Persistence | MSE : 0.381382 | MAE : 0.507724 | RMSE : 0.617561
# Improvement | MSE : +62.26%   | MAE : +41.60%   | RMSE : +38.57%
#
# -- Forecast Horizon: Step 60 --
# NG-RC       | MSE : 0.420304 | MAE : 0.535295 | RMSE : 0.648308
# Persistence | MSE : 1.197950 | MAE : 0.921240 | RMSE : 1.094509
# Improvement | MSE : +64.91%   | MAE : +41.89%   | RMSE : +40.77%
#
# -- Forecast Horizon: Step 90 --
# NG-RC       | MSE : 0.761067 | MAE : 0.726009 | RMSE : 0.872392
# Persistence | MSE : 2.252161 | MAE : 1.273577 | RMSE : 1.500720
# Improvement | MSE : +66.21%   | MAE : +42.99%   | RMSE : +41.87%
#
# ============================================================
#   Overall TEST Summary (Full Window Averages)
# ============================================================
#
# Latent Space (NG-RC)  | MSE : 811.532057 | MAE : 20.665965 | RMSE : 24.538394
# SST Space (NG-RC)     | MSE : 0.317341 | MAE : 0.423795 | RMSE : 0.508702
# SST Space (Persist)   | MSE : 0.886628 | MAE : 0.705623 | RMSE : 0.846092
# Improvement vs Pers.  | MSE : +64.21%   | MAE : +39.94%   | RMSE : +39.88%
# ------------------------------------------------------------
# TEST Window Size   : 90
# TEST Stride        : 1
# Total TEST Windows : 411
# ============================================================

# %%
# ============================================================
# Continuous Autonomous SST Forecast Visualization
# Standard NVAR
# ============================================================

import numpy as np
import matplotlib.pyplot as plt

# ============================================================
# 1. FORECAST LENGTH & EVALUATION SETUP
# ============================================================

plot_len = 90

window_idx = 330      # 0 = first window, 1 = second, ...
test_stride = 1

test_start = val_end + window_idx * test_stride
# Initialize Delay History
history = [
    X_soln[:, test_start - best_k + i].copy()
    for i in range(best_k)
]

# Feature Dimensions & Pre-indexed Upper-Triangular Mapping
d_linear = d * best_k
d_quadratic = (d_linear * (d_linear + 1)) // 2
d_total = 1 + d_linear + d_quadratic

r_idx, c_idx = np.triu_indices(d_linear)

# ============================================================
# 2. CONTINUOUS AUTONOMOUS ROLLOUT
# ============================================================

continuous_pred = np.zeros((d, plot_len))

for j in range(plot_len):

    # Delay Embedding Vector
    z = np.hstack([history[-1 - i] for i in range(best_k)])

    # Construct NVAR Feature Vector
    out_test = np.ones(d_total)
    out_test[1 : 1 + d_linear] = z
    out_test[1 + d_linear :] = z[r_idx] * z[c_idx]

    # Predict Increment & Advance State
    delta_pred = W_out @ out_test
    next_x = history[-1] + delta_pred

    # Store Prediction & Update History
    continuous_pred[:, j] = next_x
    history.append(next_x)

# ============================================================
# 3. RECONSTRUCT SST FIELDS & ERROR
# ============================================================

pc_pred = continuous_pred.T
pred_field = pca.inverse_transform(pc_pred)
true_field = sst_time_major[test_start : test_start + plot_len]

# Absolute SST Error
sst_error = np.abs(true_field - pred_field)

# Enforce shared color scale for True and Predicted fields
vmin_sst = min(true_field.min(), pred_field.min())
vmax_sst = max(true_field.max(), pred_field.max())

# ============================================================
# 4. SUBPLOTS SETUP
# ============================================================

fig, axes = plt.subplots(3, 1, figsize=(14, 10), sharex=True)

# --- TRUE SST FIELD ---
im0 = axes[0].imshow(
    true_field.T,
    aspect='auto',
    origin='lower',
    cmap='coolwarm',
    vmin=vmin_sst,
    vmax=vmax_sst
)
axes[0].set_title('True SST Field', fontsize=14, fontweight='bold')
axes[0].set_ylabel('Spatial Grid Index', fontsize=12)

# --- PREDICTED SST FIELD ---
im1 = axes[1].imshow(
    pred_field.T,
    aspect='auto',
    origin='lower',
    cmap='coolwarm',
    vmin=vmin_sst,
    vmax=vmax_sst
)
axes[1].set_title('Standard NVAR Predicted SST Field', fontsize=14, fontweight='bold')
axes[1].set_ylabel('Spatial Grid Index', fontsize=12)

# --- ABSOLUTE ERROR FIELD ---
im2 = axes[2].imshow(
    sst_error.T,
    aspect='auto',
    origin='lower',
    cmap='inferno',
    vmin=0,
    vmax=sst_error.max()
)
axes[2].set_title('Absolute SST Error', fontsize=14, fontweight='bold')
axes[2].set_xlabel('Forecast Time Step', fontsize=12)
axes[2].set_ylabel('Spatial Grid Index', fontsize=12)

# ============================================================
# 5. COLORBARS & EXPORT
# ============================================================

cbar0 = fig.colorbar(im0, ax=axes[0], fraction=0.02, pad=0.02)
cbar0.set_label('SST', fontsize=10)

cbar1 = fig.colorbar(im1, ax=axes[1], fraction=0.02, pad=0.02)
cbar1.set_label('SST', fontsize=10)

cbar2 = fig.colorbar(im2, ax=axes[2], fraction=0.02, pad=0.02)
cbar2.set_label('Abs Error', fontsize=10)

plt.tight_layout()

plt.savefig(
    "standard_nvar_sst_field_evolution_East_China_Sea.png",
    dpi=300,
    bbox_inches='tight'
)

plt.show()
