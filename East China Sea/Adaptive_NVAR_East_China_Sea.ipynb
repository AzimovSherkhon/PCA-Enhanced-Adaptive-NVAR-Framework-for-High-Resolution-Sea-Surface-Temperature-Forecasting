# %%
# ============================================================
# Imports & Setup
# ============================================================
import warnings
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from matplotlib.ticker import MaxNLocator

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# Torch defaults
torch.set_default_dtype(torch.float32)

# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device in use: {device}")
if device.type == "cuda":
    print(f"CUDA device: {torch.cuda.current_device()} - {torch.cuda.get_device_name(0)}")

# Suppress unnecessary warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# Device in use: cuda
# CUDA device: 0 - A100-PCIE-40GB

# %%
# ============================================================
# 1. Load SST Dataset
# ============================================================
sst_data = np.load("sst_normalized_5k.npy")

# Shape transformation to time-major: (time, spatial_points)
sst_time_major = sst_data.T
print("Original SST shape (time-major):", sst_time_major.shape)

# ============================================================
# 2. Time Setup & Data Splits
# ============================================================
dt = 1.0
warmup    = 100.0
traintime = 3900.0
valtime   = 500.0
testtime  = 500.0

maxtime = warmup + traintime + valtime + testtime

warmup_pts    = int(round(warmup / dt))
traintime_pts = int(round(traintime / dt))
valtime_pts   = int(round(valtime / dt))
testtime_pts  = int(round(testtime / dt))

warmtrain_pts = warmup_pts + traintime_pts
val_end       = warmtrain_pts + valtime_pts
maxtime_pts   = int(round(maxtime / dt))

print("\n==== Data Splits ====")
print(f"Warmup : {warmup_pts}")
print(f"Train  : {traintime_pts}")
print(f"Val    : {valtime_pts}")
print(f"Test   : {testtime_pts}")
# Out:
# Original SST shape (time-major): (5001, 2989)
#
# ==== Data Splits ====
# Warmup : 100
# Train  : 3900
# Val    : 500
# Test   : 500

# %%
# ============================================================
# 3. Fit PCA/SVD on TRAINING DATA ONLY
# ============================================================
pca_train_end = warmtrain_pts
n_components = 1

train_sst = sst_time_major[:pca_train_end]

pca = PCA(n_components=n_components, svd_solver='full')
pca.fit(train_sst)

# Transform entire dataset using TRAIN PCA basis
sst_pca = pca.transform(sst_time_major)
explained_variance = pca.explained_variance_ratio_

print("\n==== PCA/SVD Summary ====")
print(f"Retained components      : {n_components}")
print(f"Explained variance ratio : {explained_variance}")

# ============================================================
# 4. Prepare Latent SST Dataset
# ============================================================
latent_sst = sst_pca.T
X_soln = latent_sst[:, :maxtime_pts + 1]
d, T_full = X_soln.shape

print(f"\nLatent SST shape: {X_soln.shape}")
# Out:
# ==== PCA/SVD Summary ====
# Retained components      : 1
# Explained variance ratio : [0.9650954]
#
# Latent SST shape: (1, 5001)

# %%
# ============================================================
# Professional PCA / EOF Visualization
# ============================================================

# Refit with more components for diagnostic spectrum plotting
n_plot_components = 10
pca_plot = PCA(n_components=n_plot_components, svd_solver='full')
pca_plot.fit(train_sst)

explained_variance_plot = pca_plot.explained_variance_ratio_
cumulative_variance_plot = np.cumsum(explained_variance_plot)

# ------------------------------------------------------------
# Figure 1: Explained Variance Spectrum
# ------------------------------------------------------------
fig, ax = plt.subplots(figsize=(8, 5))
components = np.arange(1, n_plot_components + 1)

# Variance plots
ax.plot(components, explained_variance_plot, marker='o', linewidth=2.2, markersize=6, label='Individual Variance Ratio')
ax.plot(components, cumulative_variance_plot, marker='s', linewidth=2.2, markersize=5, label='Cumulative Variance Ratio')

# Highlight retained dimensions
ax.axvline(x=n_components, linestyle='--', linewidth=2, color='tab:red', label=f'Retained Components = {n_components}')

# Axis Formatting
ax.set_xlabel('Principal Component Index', fontsize=14)
ax.set_ylabel('Explained Variance Ratio', fontsize=14)
ax.set_title('PCA Explained Variance Spectrum', fontsize=16, pad=12)
ax.set_xticks(components)
ax.tick_params(axis='both', labelsize=12)
ax.grid(True, linestyle='--', alpha=0.5)
ax.legend(fontsize=11, frameon=True)

plt.tight_layout()
plt.savefig('pca_explained_variance_professional.png', dpi=600, bbox_inches='tight')
plt.show()

# ------------------------------------------------------------
# Figure 2: Leading Principal Component Time Series
# ------------------------------------------------------------
fig, ax = plt.subplots(figsize=(11, 4))
time_axis = np.arange(X_soln.shape[1])

ax.plot(time_axis, X_soln[0], linewidth=1.2, color='tab:blue')

# Axis Formatting
ax.set_xlabel('Time Step', fontsize=14)
ax.set_ylabel('PC1 Amplitude', fontsize=14)
ax.set_title('Leading Principal Component Time Series', fontsize=16, pad=12)
ax.tick_params(axis='both', labelsize=12)
ax.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.savefig('pc1_timeseries_professional.png', dpi=600, bbox_inches='tight')
plt.show()

# ------------------------------------------------------------
# Figure 3: Latent SST Dynamics Overview
# ------------------------------------------------------------
num_components_to_plot = min(n_components, 10)
time_steps = np.arange(latent_sst.shape[1])

plt.figure(figsize=(12, 2.5 * num_components_to_plot))

for i in range(num_components_to_plot):
    plt.subplot(num_components_to_plot, 1, i + 1)
    plt.plot(time_steps, latent_sst[i], linewidth=1.0, label=f'PC {i+1}')
    plt.ylabel(f'PC {i+1}')
    plt.grid(True, alpha=0.3)
    plt.legend(loc='upper right')

    if i == 0:
        plt.title("Latent SST Dynamics in PCA Space", fontsize=14)
    if i == num_components_to_plot - 1:
        plt.xlabel("Time Step")

plt.tight_layout()
plt.show()

# ------------------------------------------------------------
# Variance Summary Output
# ------------------------------------------------------------
print("\n==== PCA Visualization Summary ====\n")
for i, var in enumerate(explained_variance_plot):
    print(f"PC{i+1:02d} Variance Ratio: {var:.6f}")

print(f"\nCumulative Variance (first {n_plot_components} PCs): {cumulative_variance_plot[-1]:.6f}")
# Out:
# ==== PCA Visualization Summary ====
#
# PC01 Variance Ratio: 0.965095
# PC02 Variance Ratio: 0.012904
# PC03 Variance Ratio: 0.004220
# PC04 Variance Ratio: 0.002226
# PC05 Variance Ratio: 0.001457
# PC06 Variance Ratio: 0.001194
# PC07 Variance Ratio: 0.001162
# PC08 Variance Ratio: 0.000908
# PC09 Variance Ratio: 0.000799
# PC10 Variance Ratio: 0.000635
#
# Cumulative Variance (first 10 PCs): 0.990599

# %%
# ============================================================
# Dataset Splits & Setup
# ============================================================
X_noisy_dataset = X_soln.T
X = torch.tensor(X_noisy_dataset, dtype=torch.float32)       # noisy input
X_true = torch.tensor(X_noisy_dataset, dtype=torch.float32)  # clean reference

# Dataset splits
warmup_len, train_len, val_len, test_len = 100, 3900, 500, 500

X_warmup = X[:warmup_len].to(device)
X_train_clean = X[warmup_len:warmup_len + train_len]
X_val  = X[warmup_len + train_len : warmup_len + train_len + val_len].to(device)
X_test = X[warmup_len + train_len + val_len : warmup_len + train_len + val_len + test_len].to(device)

# Ground truth references
X_val_true  = X_true[warmup_len + train_len : warmup_len + train_len + val_len].to(device)
X_test_true = X_true[warmup_len + train_len + val_len : warmup_len + train_len + val_len + test_len].to(device)
X_val_true_raw = X_true[warmup_len + train_len : warmup_len + train_len + val_len]
X_test_true_raw = sst_time_major[warmup_len + train_len + val_len : warmup_len + train_len + val_len + test_len]

# Training-time noise (regularization for noise-free case: train_noise_scale = 0.0)
train_noise_scale = 0.0
signal_std = X_train_clean.std(dim=0, keepdim=True).cpu().numpy()
train_noise = np.random.normal(0.0, train_noise_scale * signal_std, X_train_clean.shape)
X_train = torch.tensor((X_train_clean.cpu().numpy() + train_noise).astype(np.float32), device=device)


# ============================================================
# Adaptive NVAR Model Definition
# ============================================================
class FeatureMLP(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, output_dim)
        )

    def forward(self, x):
        return self.net(x)


class AdaptiveNVARModel(nn.Module):
    def __init__(self, dk, m, d, hidden_dim):
        super().__init__()
        self.mlp = FeatureMLP(dk, hidden_dim, m)
        self.readout = nn.Linear(dk + m, d, bias=False)

    def forward(self, H_lin):
        H_nn = self.mlp(H_lin)
        H_total = torch.cat([H_lin, H_nn], dim=1)
        return self.readout(H_total)


# ============================================================
# Helper Functions & Model Training
# ============================================================
def construct_H_lin(X, k):
    """Constructs delay-embedded features from time series."""
    T = X.shape[0]
    return torch.cat([X[i:T - k + i] for i in range(k)], dim=1)


def init_weights_stable(m):
    """Stable Xavier initialization for linear layers."""
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            nn.init.zeros_(m.bias)
        with torch.no_grad():
            m.weight.mul_(1.0)


def train_joint_model(
    X, k, m, hidden_dim=200,
    lr_adam=1e-4,
    max_epochs_adam=5000,
    save_path="best_joint_model.pth",
    adam_patience=200,
    tolerance=1e-8,
    device=None
):
    """Train Adaptive NVAR model using Adam optimization only."""
    device = device or torch.device("cuda" if torch.cuda.is_available() else "cpu")
    X = X.to(device)

    # Prepare features & targets
    H_lin = construct_H_lin(X, k)       # [n, dk]
    Y = X[k:] - X[k-1:-1]               # [n, d]
    n, dk = H_lin.shape
    d = Y.shape[1]

    # Initialize model
    model = AdaptiveNVARModel(dk, m, d, hidden_dim).to(device)
    model.apply(init_weights_stable)

    optimizer = torch.optim.Adam(model.parameters(), lr=lr_adam)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="min", factor=0.5, patience=200
    )

    best_loss = float("inf")
    epochs_no_improve = 0

    for epoch in range(max_epochs_adam):
        model.train()

        Y_hat = model(H_lin)
        loss = F.mse_loss(Y_hat, Y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step(loss.item())

        if best_loss - loss.item() > tolerance:
            best_loss = loss.item()
            epochs_no_improve = 0
            torch.save(model.state_dict(), save_path)
        else:
            epochs_no_improve += 1

        if epochs_no_improve >= adam_patience:
            break

    model.load_state_dict(torch.load(save_path))
    return model

# %%
# ============================================================
# Adaptive NVAR Hyperparameter Optimization (Optuna)
# ============================================================
import time
import optuna
import numpy as np
import torch

# Validation Setup
window_size = 90
stride = 1
horizons = [10, 30, 60, 90]
base_seed = 2025
n_trials = 200
num_runs = 5  # Number of independent models per trial

all_results = []

def objective(trial):
    # Hyperparameter Search Space
    k = trial.suggest_categorical("k", [2, 5, 10, 20, 30, 40, 50])
    hidden_dim = trial.suggest_categorical("hidden_dim", [20, 50, 100])
    lr_adam = trial.suggest_float("lr_adam", 1e-4, 1e-1, log=True)

    # Dimensions
    d = X_train.shape[1]
    dk = d * k
    m = int((dk * (dk + 1)) / 2)  # Adaptive nonlinear feature dimension

    # Containers across 3 independent runs
    runs_avg_mses = {h: [] for h in horizons}
    runs_avg_maes = {h: [] for h in horizons}
    runs_avg_rmses = {h: [] for h in horizons}

    for run in range(num_runs):
        # Unique seed per run for independent initializations/training
        run_seed = base_seed + run
        torch.manual_seed(run_seed)
        torch.cuda.manual_seed_all(run_seed)
        np.random.seed(run_seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

        model_path = f"optuna_model_k{k}_hd{hidden_dim}_adam{lr_adam:.2e}_run{run}.pth"

        # Train Model
        try:
            model = train_joint_model(
                X=X_train, k=k, m=m, hidden_dim=hidden_dim,
                lr_adam=lr_adam, save_path=model_path, device=device
            )
        except Exception as e:
            print(f"Training failed on run {run}: {e}")
            return np.inf

        model.eval()

        # Metric Storage for this run
        horizon_mses = {h: [] for h in horizons}
        horizon_maes = {h: [] for h in horizons}
        horizon_rmses = {h: [] for h in horizons}

        # Overlapping Rolling Validation
        for start in range(0, len(X_val_true) - window_size + 1, stride):
            end = start + window_size
            X_val_true_window = X_val_true[start:end]

            init_start = warmup_len + train_len + start - k
            init_end = warmup_len + train_len + start

            X_init = X[init_start:init_end].to(device)
            x_t = [x.clone() for x in X_init.unbind(0)]
            H_lin = torch.cat(x_t, dim=-1).unsqueeze(0)

            predictions = []
            unstable = False

            for step in range(window_size):
                with torch.no_grad():
                    delta_x = model(H_lin)

                x_next = x_t[-1] + delta_x.squeeze(0)

                if torch.isnan(x_next).any() or torch.isinf(x_next).any():
                    unstable = True
                    break

                predictions.append(x_next)
                x_t = x_t[1:] + [x_next]
                H_lin = torch.cat(x_t, dim=-1).unsqueeze(0)

            if unstable:
                return np.inf

            predictions_np = torch.stack(predictions).cpu().numpy()
            y_true_np = X_val_true_window.cpu().numpy()

            for h in horizons:
                if h > len(predictions_np):
                    continue

                mse_h = np.mean((y_true_np[:h] - predictions_np[:h]) ** 2)
                mae_h = np.mean(np.abs(y_true_np[:h] - predictions_np[:h]))
                rmse_h = np.sqrt(mse_h)

                if not np.isfinite(rmse_h):
                    return np.inf

                horizon_mses[h].append(mse_h)
                horizon_maes[h].append(mae_h)
                horizon_rmses[h].append(rmse_h)

        # Average performance for this specific run
        for h in horizons:
            runs_avg_mses[h].append(np.mean(horizon_mses[h]))
            runs_avg_maes[h].append(np.mean(horizon_maes[h]))
            runs_avg_rmses[h].append(np.mean(horizon_rmses[h]))

    # Mean performance across all 3 independent runs
    final_avg_mse = {h: np.mean(runs_avg_mses[h]) for h in horizons}
    final_avg_mae = {h: np.mean(runs_avg_maes[h]) for h in horizons}
    final_avg_rmse = {h: np.mean(runs_avg_rmses[h]) for h in horizons}

    all_results.append({
        "k": k, "hidden_dim": hidden_dim, "lr_adam": lr_adam,
        "mse": final_avg_mse, "mae": final_avg_mae, "rmse": final_avg_rmse
    })

    log_str = f"Trial {trial.number:03d} | k={k:<2d} | hidden_dim={hidden_dim:<4d} | Adam LR={lr_adam:.2e} | "
    log_str += ", ".join([f"h={h}: Mean RMSE={final_avg_rmse[h]:.6f}" for h in horizons])
    print(log_str)

    return final_avg_rmse[90]


# Execute Study
start_time = time.time()
print("\n==== Adaptive NVAR Hyperparameter Optimization (3 Runs Averaged) ====\n")

study = optuna.create_study(
    direction="minimize",
    sampler=optuna.samplers.TPESampler(seed=base_seed)
)

study.optimize(objective, n_trials=n_trials, show_progress_bar=True)

# Best Model Summary
best_config = study.best_params
best_rmse = study.best_value
best_result = min(all_results, key=lambda x: x["rmse"][90])

print("\n==== Best Adaptive NVAR Configuration ====\n")
print(f"k             : {best_config['k']}")
print(f"hidden_dim    : {best_config['hidden_dim']}")
print(f"Adam LR       : {best_config['lr_adam']:.2e}")
print(f"Best MSE@90   : {best_result['mse'][90]:.6f}")
print(f"Best MAE@90   : {best_result['mae'][90]:.6f}")
print(f"Best RMSE@90  : {best_rmse:.6f}")
print(f"Execution time: {time.time() - start_time:.2f} seconds")
# Out:
# [I 2026-07-26 10:59:15,464] A new study created in memory with name: no-name-46f31da2-aa77-44f6-8b81-60b3e0a83f61
# ==== Adaptive NVAR Hyperparameter Optimization (3 Runs Averaged) ====
#   0%|          | 0/200 [00:00<?, ?it/s]
# Trial 000 | k=10 | hidden_dim=50   | Adam LR=2.32e-03 | h=10: Mean RMSE=4.457404, h=30: Mean RMSE=10.323645, h=60: Mean RMSE=19.856649, h=90: Mean RMSE=29.655233
# [I 2026-07-26 11:00:37,212] Trial 0 finished with value: 29.65523338317871 and parameters: {'k': 10, 'hidden_dim': 50, 'lr_adam': 0.002320683185722375}. Best is trial 0 with value: 29.65523338317871.
# Trial 001 | k=50 | hidden_dim=100  | Adam LR=9.17e-02 | h=10: Mean RMSE=3.839389, h=30: Mean RMSE=6.593105, h=60: Mean RMSE=9.171911, h=90: Mean RMSE=10.980284
# [I 2026-07-26 11:02:10,168] Trial 1 finished with value: 10.980283737182617 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.09174844927586977}. Best is trial 1 with value: 10.980283737182617.
# Trial 002 | k=20 | hidden_dim=100  | Adam LR=3.46e-03 | h=10: Mean RMSE=4.481418, h=30: Mean RMSE=8.505491, h=60: Mean RMSE=14.206970, h=90: Mean RMSE=19.740162
# [I 2026-07-26 11:03:27,843] Trial 2 finished with value: 19.740161895751953 and parameters: {'k': 20, 'hidden_dim': 100, 'lr_adam': 0.003462771731035132}. Best is trial 1 with value: 10.980283737182617.
# Trial 003 | k=40 | hidden_dim=20   | Adam LR=4.89e-02 | h=10: Mean RMSE=3.719150, h=30: Mean RMSE=6.687109, h=60: Mean RMSE=10.622975, h=90: Mean RMSE=14.118025
# [I 2026-07-26 11:04:30,088] Trial 3 finished with value: 14.118024826049805 and parameters: {'k': 40, 'hidden_dim': 20, 'lr_adam': 0.04894860753318619}. Best is trial 1 with value: 10.980283737182617.
# Trial 004 | k=5  | hidden_dim=20   | Adam LR=1.72e-04 | h=10: Mean RMSE=5.896224, h=30: Mean RMSE=16.424116, h=60: Mean RMSE=36.026051, h=90: Mean RMSE=222.610443
# [I 2026-07-26 11:05:55,192] Trial 4 finished with value: 222.61044311523438 and parameters: {'k': 5, 'hidden_dim': 20, 'lr_adam': 0.0001715181000930745}. Best is trial 1 with value: 10.980283737182617.
# Trial 005 | k=5  | hidden_dim=50   | Adam LR=9.43e-02 | h=10: Mean RMSE=4.962588, h=30: Mean RMSE=12.985118, h=60: Mean RMSE=25.624874, h=90: Mean RMSE=37.443642
# [I 2026-07-26 11:06:52,690] Trial 5 finished with value: 37.443641662597656 and parameters: {'k': 5, 'hidden_dim': 50, 'lr_adam': 0.09427622839017512}. Best is trial 1 with value: 10.980283737182617.
# Trial 006 | k=2  | hidden_dim=50   | Adam LR=1.96e-04 | h=10: Mean RMSE=5.960340, h=30: Mean RMSE=16.455677, h=60: Mean RMSE=43.220497, h=90: Mean RMSE=224.232452
# [I 2026-07-26 11:08:19,869] Trial 6 finished with value: 224.23245239257812 and parameters: {'k': 2, 'hidden_dim': 50, 'lr_adam': 0.00019551586581276307}. Best is trial 1 with value: 10.980283737182617.
# Trial 007 | k=20 | hidden_dim=50   | Adam LR=2.55e-04 | h=10: Mean RMSE=4.373969, h=30: Mean RMSE=9.086450, h=60: Mean RMSE=16.257717, h=90: Mean RMSE=25.026783
# [I 2026-07-26 11:09:53,253] Trial 7 finished with value: 25.026782989501953 and parameters: {'k': 20, 'hidden_dim': 50, 'lr_adam': 0.0002552196236773345}. Best is trial 1 with value: 10.980283737182617.
# Trial 008 | k=30 | hidden_dim=100  | Adam LR=6.54e-04 | h=10: Mean RMSE=5.290564, h=30: Mean RMSE=10.074301, h=60: Mean RMSE=16.451235, h=90: Mean RMSE=22.638222
# [I 2026-07-26 11:11:21,769] Trial 8 finished with value: 22.638221740722656 and parameters: {'k': 30, 'hidden_dim': 100, 'lr_adam': 0.0006541737568595412}. Best is trial 1 with value: 10.980283737182617.
# Trial 009 | k=50 | hidden_dim=20   | Adam LR=1.05e-03 | h=10: Mean RMSE=4.806791, h=30: Mean RMSE=8.516496, h=60: Mean RMSE=12.417341, h=90: Mean RMSE=15.561478
# [I 2026-07-26 11:12:54,285] Trial 9 finished with value: 15.561477661132812 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.0010505938260479337}. Best is trial 1 with value: 10.980283737182617.
# Trial 010 | k=50 | hidden_dim=100  | Adam LR=1.77e-02 | h=10: Mean RMSE=4.074278, h=30: Mean RMSE=7.051956, h=60: Mean RMSE=9.713068, h=90: Mean RMSE=11.485881
# [I 2026-07-26 11:14:04,029] Trial 10 finished with value: 11.485880851745605 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.017720739134423014}. Best is trial 1 with value: 10.980283737182617.
# Trial 011 | k=50 | hidden_dim=100  | Adam LR=2.43e-02 | h=10: Mean RMSE=3.889758, h=30: Mean RMSE=6.671434, h=60: Mean RMSE=9.449321, h=90: Mean RMSE=11.183705
# [I 2026-07-26 11:15:13,325] Trial 11 finished with value: 11.18370532989502 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.024295768876512285}. Best is trial 1 with value: 10.980283737182617.
# Trial 012 | k=50 | hidden_dim=100  | Adam LR=1.59e-02 | h=10: Mean RMSE=3.967632, h=30: Mean RMSE=6.797543, h=60: Mean RMSE=9.246991, h=90: Mean RMSE=10.919935
# [I 2026-07-26 11:16:21,405] Trial 12 finished with value: 10.91993522644043 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.015939322129423287}. Best is trial 12 with value: 10.91993522644043.
# Trial 013 | k=50 | hidden_dim=100  | Adam LR=8.75e-03 | h=10: Mean RMSE=4.330079, h=30: Mean RMSE=7.289922, h=60: Mean RMSE=10.016665, h=90: Mean RMSE=11.592043
# [I 2026-07-26 11:17:25,813] Trial 13 finished with value: 11.592042922973633 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.008754870667672355}. Best is trial 12 with value: 10.91993522644043.
# Trial 014 | k=50 | hidden_dim=100  | Adam LR=8.99e-02 | h=10: Mean RMSE=3.726204, h=30: Mean RMSE=6.247412, h=60: Mean RMSE=8.854105, h=90: Mean RMSE=10.718121
# [I 2026-07-26 11:18:52,364] Trial 14 finished with value: 10.718120574951172 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.08994031779566898}. Best is trial 14 with value: 10.718120574951172.
# Trial 015 | k=30 | hidden_dim=100  | Adam LR=1.39e-02 | h=10: Mean RMSE=4.204777, h=30: Mean RMSE=7.246468, h=60: Mean RMSE=10.953486, h=90: Mean RMSE=14.611803
# [I 2026-07-26 11:19:56,944] Trial 15 finished with value: 14.61180305480957 and parameters: {'k': 30, 'hidden_dim': 100, 'lr_adam': 0.013866028272263726}. Best is trial 14 with value: 10.718120574951172.
# Trial 016 | k=40 | hidden_dim=100  | Adam LR=3.56e-02 | h=10: Mean RMSE=3.862135, h=30: Mean RMSE=6.645522, h=60: Mean RMSE=9.564154, h=90: Mean RMSE=11.491282
# [I 2026-07-26 11:21:06,729] Trial 16 finished with value: 11.49128246307373 and parameters: {'k': 40, 'hidden_dim': 100, 'lr_adam': 0.03561165249647614}. Best is trial 14 with value: 10.718120574951172.
# Trial 017 | k=2  | hidden_dim=100  | Adam LR=6.11e-03 | h=10: Mean RMSE=6.065041, h=30: Mean RMSE=16.402409, h=60: Mean RMSE=30.771313, h=90: Mean RMSE=43.632301
# [I 2026-07-26 11:22:20,698] Trial 17 finished with value: 43.632301330566406 and parameters: {'k': 2, 'hidden_dim': 100, 'lr_adam': 0.006111946187556564}. Best is trial 14 with value: 10.718120574951172.
# Trial 018 | k=10 | hidden_dim=100  | Adam LR=5.11e-02 | h=10: Mean RMSE=4.490579, h=30: Mean RMSE=10.910355, h=60: Mean RMSE=20.950335, h=90: Mean RMSE=30.211155
# [I 2026-07-26 11:23:23,243] Trial 18 finished with value: 30.21115493774414 and parameters: {'k': 10, 'hidden_dim': 100, 'lr_adam': 0.05114812172531195}. Best is trial 14 with value: 10.718120574951172.
# Trial 019 | k=50 | hidden_dim=20   | Adam LR=8.86e-03 | h=10: Mean RMSE=4.054925, h=30: Mean RMSE=6.818957, h=60: Mean RMSE=9.704972, h=90: Mean RMSE=11.608060
# [I 2026-07-26 11:24:33,193] Trial 19 finished with value: 11.608059883117676 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.008859804685273243}. Best is trial 14 with value: 10.718120574951172.
# Trial 020 | k=50 | hidden_dim=100  | Adam LR=3.67e-02 | h=10: Mean RMSE=3.832307, h=30: Mean RMSE=6.514227, h=60: Mean RMSE=8.947569, h=90: Mean RMSE=10.480163
# [I 2026-07-26 11:25:40,993] Trial 20 finished with value: 10.480162620544434 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.036661753103622526}. Best is trial 20 with value: 10.480162620544434.
# Trial 021 | k=50 | hidden_dim=100  | Adam LR=2.87e-02 | h=10: Mean RMSE=3.974770, h=30: Mean RMSE=6.939471, h=60: Mean RMSE=9.639681, h=90: Mean RMSE=11.235695
# [I 2026-07-26 11:26:51,328] Trial 21 finished with value: 11.235694885253906 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.02874958565376139}. Best is trial 20 with value: 10.480162620544434.
# Trial 022 | k=50 | hidden_dim=100  | Adam LR=5.25e-02 | h=10: Mean RMSE=3.900206, h=30: Mean RMSE=6.750791, h=60: Mean RMSE=9.558954, h=90: Mean RMSE=11.292170
# [I 2026-07-26 11:28:06,980] Trial 22 finished with value: 11.292169570922852 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.052452635256978075}. Best is trial 20 with value: 10.480162620544434.
# Trial 023 | k=50 | hidden_dim=100  | Adam LR=1.45e-02 | h=10: Mean RMSE=4.115997, h=30: Mean RMSE=7.021399, h=60: Mean RMSE=9.817354, h=90: Mean RMSE=12.139376
# [I 2026-07-26 11:29:12,949] Trial 23 finished with value: 12.139375686645508 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.014482129609857912}. Best is trial 20 with value: 10.480162620544434.
# Trial 024 | k=50 | hidden_dim=100  | Adam LR=8.94e-02 | h=10: Mean RMSE=3.775372, h=30: Mean RMSE=6.509921, h=60: Mean RMSE=9.040332, h=90: Mean RMSE=10.930559
# [I 2026-07-26 11:30:43,359] Trial 24 finished with value: 10.930559158325195 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.08938672445276141}. Best is trial 20 with value: 10.480162620544434.
# Trial 025 | k=50 | hidden_dim=100  | Adam LR=4.61e-03 | h=10: Mean RMSE=4.939977, h=30: Mean RMSE=8.517622, h=60: Mean RMSE=12.733208, h=90: Mean RMSE=16.211996
# [I 2026-07-26 11:32:02,820] Trial 25 finished with value: 16.21199607849121 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.004613082924924588}. Best is trial 20 with value: 10.480162620544434.
# Trial 026 | k=2  | hidden_dim=100  | Adam LR=2.02e-03 | h=10: Mean RMSE=5.949134, h=30: Mean RMSE=16.052059, h=60: Mean RMSE=30.390650, h=90: Mean RMSE=43.382149
# [I 2026-07-26 11:33:18,762] Trial 26 finished with value: 43.38214874267578 and parameters: {'k': 2, 'hidden_dim': 100, 'lr_adam': 0.002018804502994259}. Best is trial 20 with value: 10.480162620544434.
# Trial 027 | k=10 | hidden_dim=100  | Adam LR=2.44e-02 | h=10: Mean RMSE=4.411378, h=30: Mean RMSE=10.629286, h=60: Mean RMSE=20.724354, h=90: Mean RMSE=31.025122
# [I 2026-07-26 11:34:21,295] Trial 27 finished with value: 31.025121688842773 and parameters: {'k': 10, 'hidden_dim': 100, 'lr_adam': 0.02444268742815559}. Best is trial 20 with value: 10.480162620544434.
# Trial 028 | k=5  | hidden_dim=50   | Adam LR=5.28e-02 | h=10: Mean RMSE=5.226465, h=30: Mean RMSE=13.792377, h=60: Mean RMSE=26.394577, h=90: Mean RMSE=38.151310
# [I 2026-07-26 11:35:20,402] Trial 28 finished with value: 38.151309967041016 and parameters: {'k': 5, 'hidden_dim': 50, 'lr_adam': 0.05282957497655725}. Best is trial 20 with value: 10.480162620544434.
# Trial 029 | k=40 | hidden_dim=20   | Adam LR=1.08e-02 | h=10: Mean RMSE=4.016238, h=30: Mean RMSE=7.318327, h=60: Mean RMSE=11.475614, h=90: Mean RMSE=15.424405
# [I 2026-07-26 11:36:29,728] Trial 29 finished with value: 15.424405097961426 and parameters: {'k': 40, 'hidden_dim': 20, 'lr_adam': 0.010825779097383354}. Best is trial 20 with value: 10.480162620544434.
# Trial 030 | k=30 | hidden_dim=50   | Adam LR=2.04e-03 | h=10: Mean RMSE=4.639857, h=30: Mean RMSE=8.486574, h=60: Mean RMSE=13.589363, h=90: Mean RMSE=18.500090
# [I 2026-07-26 11:37:50,721] Trial 30 finished with value: 18.500089645385742 and parameters: {'k': 30, 'hidden_dim': 50, 'lr_adam': 0.002043458125887218}. Best is trial 20 with value: 10.480162620544434.
# Trial 031 | k=50 | hidden_dim=100  | Adam LR=8.32e-02 | h=10: Mean RMSE=3.752050, h=30: Mean RMSE=6.431161, h=60: Mean RMSE=8.862349, h=90: Mean RMSE=10.456587
# [I 2026-07-26 11:39:16,540] Trial 31 finished with value: 10.456586837768555 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.08320846216844355}. Best is trial 31 with value: 10.456586837768555.
# Trial 032 | k=50 | hidden_dim=100  | Adam LR=7.68e-02 | h=10: Mean RMSE=3.865807, h=30: Mean RMSE=6.688702, h=60: Mean RMSE=9.465134, h=90: Mean RMSE=11.588292
# [I 2026-07-26 11:40:42,232] Trial 32 finished with value: 11.588292121887207 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.0768043870015706}. Best is trial 31 with value: 10.456586837768555.
# Trial 033 | k=50 | hidden_dim=100  | Adam LR=3.70e-02 | h=10: Mean RMSE=3.822234, h=30: Mean RMSE=6.524349, h=60: Mean RMSE=8.883234, h=90: Mean RMSE=10.104510
# [I 2026-07-26 11:41:49,075] Trial 33 finished with value: 10.104510307312012 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.036961453998646615}. Best is trial 33 with value: 10.104510307312012.
# Trial 034 | k=20 | hidden_dim=100  | Adam LR=3.71e-02 | h=10: Mean RMSE=4.059332, h=30: Mean RMSE=8.192392, h=60: Mean RMSE=14.349329, h=90: Mean RMSE=21.493237
# [I 2026-07-26 11:42:49,955] Trial 34 finished with value: 21.493236541748047 and parameters: {'k': 20, 'hidden_dim': 100, 'lr_adam': 0.037125148783311086}. Best is trial 33 with value: 10.104510307312012.
# Trial 035 | k=50 | hidden_dim=100  | Adam LR=6.34e-02 | h=10: Mean RMSE=3.803036, h=30: Mean RMSE=6.546252, h=60: Mean RMSE=9.086669, h=90: Mean RMSE=10.864107
# [I 2026-07-26 11:44:09,653] Trial 35 finished with value: 10.864107131958008 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.06342943872806182}. Best is trial 33 with value: 10.104510307312012.
# Trial 036 | k=10 | hidden_dim=100  | Adam LR=3.67e-02 | h=10: Mean RMSE=4.479497, h=30: Mean RMSE=10.797014, h=60: Mean RMSE=21.053379, h=90: Mean RMSE=31.023968
# [I 2026-07-26 11:45:10,688] Trial 36 finished with value: 31.023967742919922 and parameters: {'k': 10, 'hidden_dim': 100, 'lr_adam': 0.036694387275803465}. Best is trial 33 with value: 10.104510307312012.
# Trial 037 | k=50 | hidden_dim=20   | Adam LR=9.54e-02 | h=10: Mean RMSE=3.730402, h=30: Mean RMSE=6.391426, h=60: Mean RMSE=9.422457, h=90: Mean RMSE=11.728999
# [I 2026-07-26 11:46:13,008] Trial 37 finished with value: 11.728999137878418 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.09535134450236774}. Best is trial 33 with value: 10.104510307312012.
# Trial 038 | k=20 | hidden_dim=100  | Adam LR=6.73e-02 | h=10: Mean RMSE=4.011567, h=30: Mean RMSE=7.884430, h=60: Mean RMSE=13.378410, h=90: Mean RMSE=19.778164
# [I 2026-07-26 11:47:14,088] Trial 38 finished with value: 19.77816390991211 and parameters: {'k': 20, 'hidden_dim': 100, 'lr_adam': 0.06732637683922493}. Best is trial 33 with value: 10.104510307312012.
# Trial 039 | k=5  | hidden_dim=50   | Adam LR=2.57e-02 | h=10: Mean RMSE=6.091909, h=30: Mean RMSE=17.834982, h=60: Mean RMSE=37.836441, h=90: Mean RMSE=57.866566
# [I 2026-07-26 11:48:04,840] Trial 39 finished with value: 57.8665657043457 and parameters: {'k': 5, 'hidden_dim': 50, 'lr_adam': 0.02565252752455608}. Best is trial 33 with value: 10.104510307312012.
# Trial 040 | k=40 | hidden_dim=100  | Adam LR=1.03e-04 | h=10: Mean RMSE=4.648694, h=30: Mean RMSE=9.196103, h=60: Mean RMSE=14.671387, h=90: Mean RMSE=19.819225
# [I 2026-07-26 11:49:56,080] Trial 40 finished with value: 19.819225311279297 and parameters: {'k': 40, 'hidden_dim': 100, 'lr_adam': 0.00010304111678883815}. Best is trial 33 with value: 10.104510307312012.
# Trial 041 | k=50 | hidden_dim=100  | Adam LR=6.25e-02 | h=10: Mean RMSE=3.767357, h=30: Mean RMSE=6.455125, h=60: Mean RMSE=8.990312, h=90: Mean RMSE=10.611315
# [I 2026-07-26 11:51:12,476] Trial 41 finished with value: 10.61131477355957 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.06252694607716873}. Best is trial 33 with value: 10.104510307312012.
# Trial 042 | k=50 | hidden_dim=100  | Adam LR=4.11e-02 | h=10: Mean RMSE=3.820576, h=30: Mean RMSE=6.534392, h=60: Mean RMSE=8.955990, h=90: Mean RMSE=10.137288
# [I 2026-07-26 11:52:20,915] Trial 42 finished with value: 10.137288093566895 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04113724202682714}. Best is trial 33 with value: 10.104510307312012.
# Trial 043 | k=50 | hidden_dim=100  | Adam LR=4.15e-02 | h=10: Mean RMSE=3.775016, h=30: Mean RMSE=6.387670, h=60: Mean RMSE=8.690618, h=90: Mean RMSE=9.930178
# [I 2026-07-26 11:53:27,024] Trial 43 finished with value: 9.930177688598633 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.041480468822822095}. Best is trial 43 with value: 9.930177688598633.
# Trial 044 | k=50 | hidden_dim=100  | Adam LR=3.95e-02 | h=10: Mean RMSE=3.815801, h=30: Mean RMSE=6.496387, h=60: Mean RMSE=8.941023, h=90: Mean RMSE=10.366987
# [I 2026-07-26 11:54:35,117] Trial 44 finished with value: 10.366987228393555 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.0395193209173939}. Best is trial 43 with value: 9.930177688598633.
# Trial 045 | k=50 | hidden_dim=100  | Adam LR=1.98e-02 | h=10: Mean RMSE=3.864896, h=30: Mean RMSE=6.514684, h=60: Mean RMSE=9.099664, h=90: Mean RMSE=10.916319
# [I 2026-07-26 11:55:46,664] Trial 45 finished with value: 10.916318893432617 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.019794627905211238}. Best is trial 43 with value: 9.930177688598633.
# Trial 046 | k=50 | hidden_dim=20   | Adam LR=3.65e-02 | h=10: Mean RMSE=3.727703, h=30: Mean RMSE=6.383874, h=60: Mean RMSE=9.455832, h=90: Mean RMSE=11.885695
# [I 2026-07-26 11:56:50,367] Trial 46 finished with value: 11.88569450378418 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.03650942028660387}. Best is trial 43 with value: 9.930177688598633.
# Trial 047 | k=30 | hidden_dim=50   | Adam LR=4.47e-04 | h=10: Mean RMSE=4.771345, h=30: Mean RMSE=8.609801, h=60: Mean RMSE=13.419698, h=90: Mean RMSE=18.486500
# [I 2026-07-26 11:58:24,601] Trial 47 finished with value: 18.486499786376953 and parameters: {'k': 30, 'hidden_dim': 50, 'lr_adam': 0.00044737761363312196}. Best is trial 43 with value: 9.930177688598633.
# Trial 048 | k=2  | hidden_dim=100  | Adam LR=1.97e-02 | h=10: Mean RMSE=6.078874, h=30: Mean RMSE=16.662436, h=60: Mean RMSE=31.564260, h=90: Mean RMSE=45.148872
# [I 2026-07-26 11:59:28,929] Trial 48 finished with value: 45.14887237548828 and parameters: {'k': 2, 'hidden_dim': 100, 'lr_adam': 0.01971928333365987}. Best is trial 43 with value: 9.930177688598633.
# Trial 049 | k=50 | hidden_dim=100  | Adam LR=4.51e-02 | h=10: Mean RMSE=3.869502, h=30: Mean RMSE=6.586392, h=60: Mean RMSE=9.128551, h=90: Mean RMSE=10.463246
# [I 2026-07-26 12:00:40,440] Trial 49 finished with value: 10.46324634552002 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.045142212091164605}. Best is trial 43 with value: 9.930177688598633.
# Trial 050 | k=20 | hidden_dim=100  | Adam LR=2.91e-03 | h=10: Mean RMSE=4.679792, h=30: Mean RMSE=9.176948, h=60: Mean RMSE=15.458041, h=90: Mean RMSE=21.600521
# [I 2026-07-26 12:01:56,928] Trial 50 finished with value: 21.600521087646484 and parameters: {'k': 20, 'hidden_dim': 100, 'lr_adam': 0.0029078353969797205}. Best is trial 43 with value: 9.930177688598633.
# Trial 051 | k=50 | hidden_dim=100  | Adam LR=4.52e-02 | h=10: Mean RMSE=3.866385, h=30: Mean RMSE=6.626385, h=60: Mean RMSE=8.959349, h=90: Mean RMSE=10.310385
# [I 2026-07-26 12:03:10,229] Trial 51 finished with value: 10.310384750366211 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04516054754196758}. Best is trial 43 with value: 9.930177688598633.
# Trial 052 | k=50 | hidden_dim=100  | Adam LR=2.92e-02 | h=10: Mean RMSE=3.900478, h=30: Mean RMSE=6.708497, h=60: Mean RMSE=9.324396, h=90: Mean RMSE=10.997284
# [I 2026-07-26 12:04:26,597] Trial 52 finished with value: 10.997283935546875 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.02921819075461877}. Best is trial 43 with value: 9.930177688598633.
# Trial 053 | k=50 | hidden_dim=100  | Adam LR=4.61e-02 | h=10: Mean RMSE=3.838286, h=30: Mean RMSE=6.558636, h=60: Mean RMSE=8.894641, h=90: Mean RMSE=10.218325
# [I 2026-07-26 12:05:39,825] Trial 53 finished with value: 10.218324661254883 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04612525078900403}. Best is trial 43 with value: 9.930177688598633.
# Trial 054 | k=50 | hidden_dim=100  | Adam LR=4.41e-02 | h=10: Mean RMSE=3.860955, h=30: Mean RMSE=6.581229, h=60: Mean RMSE=9.018183, h=90: Mean RMSE=10.226420
# [I 2026-07-26 12:06:54,392] Trial 54 finished with value: 10.226420402526855 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04412016573795057}. Best is trial 43 with value: 9.930177688598633.
# Trial 055 | k=50 | hidden_dim=100  | Adam LR=1.24e-02 | h=10: Mean RMSE=4.180135, h=30: Mean RMSE=6.997463, h=60: Mean RMSE=9.441297, h=90: Mean RMSE=11.222474
# [I 2026-07-26 12:07:59,368] Trial 55 finished with value: 11.222474098205566 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.012425606355193287}. Best is trial 43 with value: 9.930177688598633.
# Trial 056 | k=5  | hidden_dim=100  | Adam LR=1.98e-02 | h=10: Mean RMSE=5.129636, h=30: Mean RMSE=14.529614, h=60: Mean RMSE=28.899303, h=90: Mean RMSE=42.876003
# [I 2026-07-26 12:08:48,971] Trial 56 finished with value: 42.87600326538086 and parameters: {'k': 5, 'hidden_dim': 100, 'lr_adam': 0.01981055914170558}. Best is trial 43 with value: 9.930177688598633.
# Trial 057 | k=50 | hidden_dim=100  | Adam LR=5.31e-02 | h=10: Mean RMSE=3.855726, h=30: Mean RMSE=6.649209, h=60: Mean RMSE=9.374276, h=90: Mean RMSE=11.364058
# [I 2026-07-26 12:10:03,086] Trial 57 finished with value: 11.364057540893555 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.05305823278819308}. Best is trial 43 with value: 9.930177688598633.
# Trial 058 | k=50 | hidden_dim=20   | Adam LR=2.95e-02 | h=10: Mean RMSE=3.717175, h=30: Mean RMSE=6.457124, h=60: Mean RMSE=9.767428, h=90: Mean RMSE=12.618042
# [I 2026-07-26 12:11:07,623] Trial 58 finished with value: 12.6180419921875 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.029544476786562298}. Best is trial 43 with value: 9.930177688598633.
# Trial 059 | k=50 | hidden_dim=100  | Adam LR=1.18e-03 | h=10: Mean RMSE=5.696551, h=30: Mean RMSE=10.548253, h=60: Mean RMSE=16.353115, h=90: Mean RMSE=21.990992
# [I 2026-07-26 12:12:32,342] Trial 59 finished with value: 21.990991592407227 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.001180359551605988}. Best is trial 43 with value: 9.930177688598633.
# Trial 060 | k=10 | hidden_dim=100  | Adam LR=7.05e-03 | h=10: Mean RMSE=4.732017, h=30: Mean RMSE=11.244284, h=60: Mean RMSE=19.792007, h=90: Mean RMSE=29.097086
# [I 2026-07-26 12:13:38,845] Trial 60 finished with value: 29.09708595275879 and parameters: {'k': 10, 'hidden_dim': 100, 'lr_adam': 0.007051380032853188}. Best is trial 43 with value: 9.930177688598633.
# Trial 061 | k=50 | hidden_dim=100  | Adam LR=4.41e-02 | h=10: Mean RMSE=3.811074, h=30: Mean RMSE=6.436486, h=60: Mean RMSE=8.802218, h=90: Mean RMSE=9.992330
# [I 2026-07-26 12:14:52,726] Trial 61 finished with value: 9.992329597473145 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04405401974420977}. Best is trial 43 with value: 9.930177688598633.
# Trial 062 | k=50 | hidden_dim=100  | Adam LR=4.39e-02 | h=10: Mean RMSE=3.850066, h=30: Mean RMSE=6.584544, h=60: Mean RMSE=9.327262, h=90: Mean RMSE=10.741251
# [I 2026-07-26 12:16:02,737] Trial 62 finished with value: 10.741250991821289 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04393759217742217}. Best is trial 43 with value: 9.930177688598633.
# Trial 063 | k=50 | hidden_dim=100  | Adam LR=6.17e-02 | h=10: Mean RMSE=3.828111, h=30: Mean RMSE=6.614652, h=60: Mean RMSE=9.422286, h=90: Mean RMSE=11.381380
# [I 2026-07-26 12:17:17,165] Trial 63 finished with value: 11.381380081176758 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.06165059555689811}. Best is trial 43 with value: 9.930177688598633.
# Trial 064 | k=50 | hidden_dim=100  | Adam LR=2.98e-02 | h=10: Mean RMSE=3.858316, h=30: Mean RMSE=6.511842, h=60: Mean RMSE=8.924273, h=90: Mean RMSE=10.371862
# [I 2026-07-26 12:18:28,400] Trial 64 finished with value: 10.371862411499023 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.029769713010613662}. Best is trial 43 with value: 9.930177688598633.
# Trial 065 | k=40 | hidden_dim=100  | Adam LR=1.65e-02 | h=10: Mean RMSE=3.963973, h=30: Mean RMSE=7.293110, h=60: Mean RMSE=11.045472, h=90: Mean RMSE=14.271830
# [I 2026-07-26 12:19:29,501] Trial 65 finished with value: 14.271829605102539 and parameters: {'k': 40, 'hidden_dim': 100, 'lr_adam': 0.016452752229601325}. Best is trial 43 with value: 9.930177688598633.
# Trial 066 | k=2  | hidden_dim=50   | Adam LR=2.29e-02 | h=10: Mean RMSE=6.187920, h=30: Mean RMSE=17.505924, h=60: Mean RMSE=33.928261, h=90: Mean RMSE=48.569092
# [I 2026-07-26 12:20:27,900] Trial 66 finished with value: 48.569091796875 and parameters: {'k': 2, 'hidden_dim': 50, 'lr_adam': 0.022889373815231154}. Best is trial 43 with value: 9.930177688598633.
# Trial 067 | k=50 | hidden_dim=100  | Adam LR=4.78e-02 | h=10: Mean RMSE=3.835368, h=30: Mean RMSE=6.558771, h=60: Mean RMSE=8.944996, h=90: Mean RMSE=10.171958
# [I 2026-07-26 12:21:38,211] Trial 67 finished with value: 10.171957969665527 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04784670338278511}. Best is trial 43 with value: 9.930177688598633.
# Trial 068 | k=30 | hidden_dim=100  | Adam LR=7.32e-02 | h=10: Mean RMSE=3.991435, h=30: Mean RMSE=6.957188, h=60: Mean RMSE=10.278782, h=90: Mean RMSE=13.578493
# [I 2026-07-26 12:22:41,925] Trial 68 finished with value: 13.578493118286133 and parameters: {'k': 30, 'hidden_dim': 100, 'lr_adam': 0.07322368443520143}. Best is trial 43 with value: 9.930177688598633.
# Trial 069 | k=50 | hidden_dim=100  | Adam LR=5.43e-02 | h=10: Mean RMSE=3.809558, h=30: Mean RMSE=6.538941, h=60: Mean RMSE=9.283705, h=90: Mean RMSE=11.405362
# [I 2026-07-26 12:23:57,335] Trial 69 finished with value: 11.405362129211426 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.05426896925308527}. Best is trial 43 with value: 9.930177688598633.
# Trial 070 | k=50 | hidden_dim=100  | Adam LR=3.34e-02 | h=10: Mean RMSE=3.825622, h=30: Mean RMSE=6.556371, h=60: Mean RMSE=9.006899, h=90: Mean RMSE=10.368306
# [I 2026-07-26 12:25:03,503] Trial 70 finished with value: 10.368306159973145 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.03340495173021564}. Best is trial 43 with value: 9.930177688598633.
# Trial 071 | k=50 | hidden_dim=100  | Adam LR=4.53e-02 | h=10: Mean RMSE=3.845896, h=30: Mean RMSE=6.546136, h=60: Mean RMSE=8.993787, h=90: Mean RMSE=10.330299
# [I 2026-07-26 12:26:12,448] Trial 71 finished with value: 10.330299377441406 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.045281502909885106}. Best is trial 43 with value: 9.930177688598633.
# Trial 072 | k=50 | hidden_dim=100  | Adam LR=7.52e-02 | h=10: Mean RMSE=3.790363, h=30: Mean RMSE=6.424712, h=60: Mean RMSE=8.899202, h=90: Mean RMSE=10.778070
# [I 2026-07-26 12:27:33,459] Trial 72 finished with value: 10.778070449829102 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.07517431054177676}. Best is trial 43 with value: 9.930177688598633.
# Trial 073 | k=50 | hidden_dim=100  | Adam LR=2.52e-02 | h=10: Mean RMSE=3.923082, h=30: Mean RMSE=6.835376, h=60: Mean RMSE=9.494136, h=90: Mean RMSE=10.957838
# [I 2026-07-26 12:28:41,318] Trial 73 finished with value: 10.95783805847168 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.02523915535862105}. Best is trial 43 with value: 9.930177688598633.
# Trial 074 | k=50 | hidden_dim=100  | Adam LR=4.87e-02 | h=10: Mean RMSE=3.800112, h=30: Mean RMSE=6.506682, h=60: Mean RMSE=9.073432, h=90: Mean RMSE=10.730375
# [I 2026-07-26 12:30:00,242] Trial 74 finished with value: 10.730375289916992 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04867546176424516}. Best is trial 43 with value: 9.930177688598633.
# Trial 075 | k=50 | hidden_dim=100  | Adam LR=1.00e-01 | h=10: Mean RMSE=3.806304, h=30: Mean RMSE=6.555705, h=60: Mean RMSE=9.204169, h=90: Mean RMSE=10.960118
# [I 2026-07-26 12:31:31,761] Trial 75 finished with value: 10.960118293762207 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.09999723856750144}. Best is trial 43 with value: 9.930177688598633.
# Trial 076 | k=50 | hidden_dim=20   | Adam LR=6.12e-02 | h=10: Mean RMSE=3.798372, h=30: Mean RMSE=7.028304, h=60: Mean RMSE=11.510253, h=90: Mean RMSE=15.806723
# [I 2026-07-26 12:32:35,237] Trial 76 finished with value: 15.806722640991211 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.06124114103034299}. Best is trial 43 with value: 9.930177688598633.
# Trial 077 | k=5  | hidden_dim=100  | Adam LR=4.18e-02 | h=10: Mean RMSE=5.589807, h=30: Mean RMSE=15.709269, h=60: Mean RMSE=30.239025, h=90: Mean RMSE=43.337044
# [I 2026-07-26 12:33:33,994] Trial 77 finished with value: 43.33704376220703 and parameters: {'k': 5, 'hidden_dim': 100, 'lr_adam': 0.04182455359625307}. Best is trial 43 with value: 9.930177688598633.
# Trial 078 | k=20 | hidden_dim=100  | Adam LR=3.31e-02 | h=10: Mean RMSE=4.051573, h=30: Mean RMSE=8.644499, h=60: Mean RMSE=15.683533, h=90: Mean RMSE=23.603418
# [I 2026-07-26 12:34:35,229] Trial 78 finished with value: 23.603418350219727 and parameters: {'k': 20, 'hidden_dim': 100, 'lr_adam': 0.03309564854406405}. Best is trial 43 with value: 9.930177688598633.
# Trial 079 | k=10 | hidden_dim=50   | Adam LR=2.25e-02 | h=10: Mean RMSE=4.549014, h=30: Mean RMSE=11.063492, h=60: Mean RMSE=20.537292, h=90: Mean RMSE=29.465214
# [I 2026-07-26 12:35:23,793] Trial 79 finished with value: 29.465213775634766 and parameters: {'k': 10, 'hidden_dim': 50, 'lr_adam': 0.022501349583019782}. Best is trial 43 with value: 9.930177688598633.
# Trial 080 | k=50 | hidden_dim=100  | Adam LR=1.05e-02 | h=10: Mean RMSE=4.329007, h=30: Mean RMSE=7.385387, h=60: Mean RMSE=9.828565, h=90: Mean RMSE=11.309066
# [I 2026-07-26 12:36:27,375] Trial 80 finished with value: 11.309065818786621 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.010455990588386633}. Best is trial 43 with value: 9.930177688598633.
# Trial 081 | k=50 | hidden_dim=100  | Adam LR=4.96e-02 | h=10: Mean RMSE=3.855515, h=30: Mean RMSE=6.526665, h=60: Mean RMSE=9.150178, h=90: Mean RMSE=10.673922
# [I 2026-07-26 12:37:44,329] Trial 81 finished with value: 10.673921585083008 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04956522836925269}. Best is trial 43 with value: 9.930177688598633.
# Trial 082 | k=50 | hidden_dim=100  | Adam LR=3.92e-02 | h=10: Mean RMSE=3.825283, h=30: Mean RMSE=6.515426, h=60: Mean RMSE=9.189270, h=90: Mean RMSE=10.770565
# [I 2026-07-26 12:38:52,370] Trial 82 finished with value: 10.770565032958984 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.03920966919601987}. Best is trial 43 with value: 9.930177688598633.
# Trial 083 | k=50 | hidden_dim=100  | Adam LR=4.60e-02 | h=10: Mean RMSE=3.791763, h=30: Mean RMSE=6.447748, h=60: Mean RMSE=9.006751, h=90: Mean RMSE=10.478938
# [I 2026-07-26 12:40:02,488] Trial 83 finished with value: 10.478938102722168 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04599564029200718}. Best is trial 43 with value: 9.930177688598633.
# Trial 084 | k=50 | hidden_dim=100  | Adam LR=5.91e-02 | h=10: Mean RMSE=3.780894, h=30: Mean RMSE=6.554117, h=60: Mean RMSE=9.210378, h=90: Mean RMSE=11.301785
# [I 2026-07-26 12:41:17,059] Trial 84 finished with value: 11.301785469055176 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.059076941085131056}. Best is trial 43 with value: 9.930177688598633.
# Trial 085 | k=40 | hidden_dim=100  | Adam LR=7.97e-02 | h=10: Mean RMSE=3.821424, h=30: Mean RMSE=6.703914, h=60: Mean RMSE=9.910304, h=90: Mean RMSE=12.162157
# [I 2026-07-26 12:42:30,853] Trial 85 finished with value: 12.16215705871582 and parameters: {'k': 40, 'hidden_dim': 100, 'lr_adam': 0.07970392292824018}. Best is trial 43 with value: 9.930177688598633.
# Trial 086 | k=50 | hidden_dim=100  | Adam LR=3.34e-02 | h=10: Mean RMSE=3.853949, h=30: Mean RMSE=6.608336, h=60: Mean RMSE=9.070760, h=90: Mean RMSE=10.608973
# [I 2026-07-26 12:43:37,797] Trial 86 finished with value: 10.608972549438477 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.033396422022425265}. Best is trial 43 with value: 9.930177688598633.
# Trial 087 | k=2  | hidden_dim=100  | Adam LR=6.99e-02 | h=10: Mean RMSE=5.954394, h=30: Mean RMSE=16.354130, h=60: Mean RMSE=32.556141, h=90: Mean RMSE=48.402744
# [I 2026-07-26 12:44:34,437] Trial 87 finished with value: 48.40274429321289 and parameters: {'k': 2, 'hidden_dim': 100, 'lr_adam': 0.06992329657268669}. Best is trial 43 with value: 9.930177688598633.
# Trial 088 | k=50 | hidden_dim=100  | Adam LR=2.79e-02 | h=10: Mean RMSE=3.890458, h=30: Mean RMSE=6.749448, h=60: Mean RMSE=9.320334, h=90: Mean RMSE=10.990748
# [I 2026-07-26 12:45:43,474] Trial 88 finished with value: 10.990748405456543 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.027893362185925384}. Best is trial 43 with value: 9.930177688598633.
# Trial 089 | k=30 | hidden_dim=20   | Adam LR=4.27e-02 | h=10: Mean RMSE=3.956085, h=30: Mean RMSE=7.338916, h=60: Mean RMSE=11.717371, h=90: Mean RMSE=15.556773
# [I 2026-07-26 12:46:43,425] Trial 89 finished with value: 15.55677318572998 and parameters: {'k': 30, 'hidden_dim': 20, 'lr_adam': 0.04273620016552759}. Best is trial 43 with value: 9.930177688598633.
# Trial 090 | k=50 | hidden_dim=100  | Adam LR=1.44e-02 | h=10: Mean RMSE=4.038442, h=30: Mean RMSE=6.869343, h=60: Mean RMSE=9.579126, h=90: Mean RMSE=11.537836
# [I 2026-07-26 12:47:47,298] Trial 90 finished with value: 11.537836074829102 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.014393124484082712}. Best is trial 43 with value: 9.930177688598633.
# Trial 091 | k=50 | hidden_dim=100  | Adam LR=4.09e-02 | h=10: Mean RMSE=3.899167, h=30: Mean RMSE=6.715253, h=60: Mean RMSE=9.074484, h=90: Mean RMSE=10.217138
# [I 2026-07-26 12:48:52,597] Trial 91 finished with value: 10.217138290405273 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.040890559667625066}. Best is trial 43 with value: 9.930177688598633.
# Trial 092 | k=50 | hidden_dim=100  | Adam LR=5.51e-02 | h=10: Mean RMSE=3.807759, h=30: Mean RMSE=6.519922, h=60: Mean RMSE=9.056017, h=90: Mean RMSE=10.731039
# [I 2026-07-26 12:50:09,805] Trial 92 finished with value: 10.731039047241211 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.05511645599177701}. Best is trial 43 with value: 9.930177688598633.
# Trial 093 | k=50 | hidden_dim=100  | Adam LR=3.20e-02 | h=10: Mean RMSE=3.823670, h=30: Mean RMSE=6.541252, h=60: Mean RMSE=9.167650, h=90: Mean RMSE=10.654358
# [I 2026-07-26 12:51:18,896] Trial 93 finished with value: 10.65435791015625 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.0319641760629571}. Best is trial 43 with value: 9.930177688598633.
# Trial 094 | k=50 | hidden_dim=100  | Adam LR=4.18e-02 | h=10: Mean RMSE=3.904547, h=30: Mean RMSE=6.671054, h=60: Mean RMSE=9.358989, h=90: Mean RMSE=11.035625
# [I 2026-07-26 12:52:24,363] Trial 94 finished with value: 11.035624504089355 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04181126502435808}. Best is trial 43 with value: 9.930177688598633.
# Trial 095 | k=50 | hidden_dim=100  | Adam LR=1.83e-02 | h=10: Mean RMSE=3.898383, h=30: Mean RMSE=6.519094, h=60: Mean RMSE=9.179216, h=90: Mean RMSE=11.271111
# [I 2026-07-26 12:53:31,612] Trial 95 finished with value: 11.271111488342285 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.018339023280540392}. Best is trial 43 with value: 9.930177688598633.
# Trial 096 | k=50 | hidden_dim=100  | Adam LR=2.19e-02 | h=10: Mean RMSE=3.874660, h=30: Mean RMSE=6.835654, h=60: Mean RMSE=9.799719, h=90: Mean RMSE=11.645758
# [I 2026-07-26 12:54:44,865] Trial 96 finished with value: 11.645757675170898 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.021856472128568484}. Best is trial 43 with value: 9.930177688598633.
# Trial 097 | k=50 | hidden_dim=100  | Adam LR=6.66e-02 | h=10: Mean RMSE=3.744174, h=30: Mean RMSE=6.348283, h=60: Mean RMSE=8.841326, h=90: Mean RMSE=10.341584
# [I 2026-07-26 12:56:02,831] Trial 97 finished with value: 10.341584205627441 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.06655751291055198}. Best is trial 43 with value: 9.930177688598633.
# Trial 098 | k=5  | hidden_dim=50   | Adam LR=8.30e-02 | h=10: Mean RMSE=5.126291, h=30: Mean RMSE=13.369512, h=60: Mean RMSE=25.409157, h=90: Mean RMSE=36.842964
# [I 2026-07-26 12:56:58,253] Trial 98 finished with value: 36.84296417236328 and parameters: {'k': 5, 'hidden_dim': 50, 'lr_adam': 0.08303489067139246}. Best is trial 43 with value: 9.930177688598633.
# Trial 099 | k=20 | hidden_dim=100  | Adam LR=3.79e-02 | h=10: Mean RMSE=4.129668, h=30: Mean RMSE=8.673711, h=60: Mean RMSE=15.641405, h=90: Mean RMSE=23.582077
# [I 2026-07-26 12:57:58,966] Trial 99 finished with value: 23.582077026367188 and parameters: {'k': 20, 'hidden_dim': 100, 'lr_adam': 0.0378683443708439}. Best is trial 43 with value: 9.930177688598633.
# Trial 100 | k=50 | hidden_dim=100  | Adam LR=2.64e-02 | h=10: Mean RMSE=3.940021, h=30: Mean RMSE=6.814780, h=60: Mean RMSE=9.352968, h=90: Mean RMSE=10.779919
# [I 2026-07-26 12:59:08,030] Trial 100 finished with value: 10.779918670654297 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.026381454162853177}. Best is trial 43 with value: 9.930177688598633.
# Trial 101 | k=50 | hidden_dim=100  | Adam LR=6.96e-02 | h=10: Mean RMSE=3.767767, h=30: Mean RMSE=6.471807, h=60: Mean RMSE=9.093373, h=90: Mean RMSE=11.004080
# [I 2026-07-26 13:00:27,224] Trial 101 finished with value: 11.004079818725586 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.06958703566163503}. Best is trial 43 with value: 9.930177688598633.
# Trial 102 | k=50 | hidden_dim=100  | Adam LR=4.95e-02 | h=10: Mean RMSE=3.800394, h=30: Mean RMSE=6.465095, h=60: Mean RMSE=9.045681, h=90: Mean RMSE=10.481063
# [I 2026-07-26 13:01:40,240] Trial 102 finished with value: 10.481062889099121 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.049494665183914724}. Best is trial 43 with value: 9.930177688598633.
# Trial 103 | k=50 | hidden_dim=100  | Adam LR=5.72e-02 | h=10: Mean RMSE=3.758703, h=30: Mean RMSE=6.385113, h=60: Mean RMSE=8.983864, h=90: Mean RMSE=10.791459
# [I 2026-07-26 13:02:56,474] Trial 103 finished with value: 10.791459083557129 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.05716130966021015}. Best is trial 43 with value: 9.930177688598633.
# Trial 104 | k=50 | hidden_dim=100  | Adam LR=4.65e-02 | h=10: Mean RMSE=3.884994, h=30: Mean RMSE=6.596124, h=60: Mean RMSE=9.005445, h=90: Mean RMSE=10.252739
# [I 2026-07-26 13:04:07,094] Trial 104 finished with value: 10.252738952636719 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.046514027492386326}. Best is trial 43 with value: 9.930177688598633.
# Trial 105 | k=50 | hidden_dim=100  | Adam LR=3.53e-02 | h=10: Mean RMSE=3.869175, h=30: Mean RMSE=6.555638, h=60: Mean RMSE=9.160984, h=90: Mean RMSE=10.804891
# [I 2026-07-26 13:05:15,513] Trial 105 finished with value: 10.804890632629395 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.035282700206452224}. Best is trial 43 with value: 9.930177688598633.
# Trial 106 | k=10 | hidden_dim=100  | Adam LR=4.19e-03 | h=10: Mean RMSE=4.566096, h=30: Mean RMSE=10.814707, h=60: Mean RMSE=20.642330, h=90: Mean RMSE=30.897308
# [I 2026-07-26 13:06:23,591] Trial 106 finished with value: 30.897308349609375 and parameters: {'k': 10, 'hidden_dim': 100, 'lr_adam': 0.004185359452955664}. Best is trial 43 with value: 9.930177688598633.
# Trial 107 | k=50 | hidden_dim=100  | Adam LR=4.66e-02 | h=10: Mean RMSE=3.782450, h=30: Mean RMSE=6.376480, h=60: Mean RMSE=8.677878, h=90: Mean RMSE=9.984571
# [I 2026-07-26 13:07:33,717] Trial 107 finished with value: 9.98457145690918 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.0465511424810605}. Best is trial 43 with value: 9.930177688598633.
# Trial 108 | k=40 | hidden_dim=100  | Adam LR=3.87e-02 | h=10: Mean RMSE=3.880181, h=30: Mean RMSE=6.790722, h=60: Mean RMSE=9.555830, h=90: Mean RMSE=11.476127
# [I 2026-07-26 13:08:40,296] Trial 108 finished with value: 11.476126670837402 and parameters: {'k': 40, 'hidden_dim': 100, 'lr_adam': 0.038652664320098916}. Best is trial 43 with value: 9.930177688598633.
# Trial 109 | k=50 | hidden_dim=20   | Adam LR=8.93e-02 | h=10: Mean RMSE=3.788656, h=30: Mean RMSE=6.670682, h=60: Mean RMSE=9.891417, h=90: Mean RMSE=12.788866
# [I 2026-07-26 13:09:41,739] Trial 109 finished with value: 12.78886604309082 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.08926983656201716}. Best is trial 43 with value: 9.930177688598633.
# Trial 110 | k=50 | hidden_dim=100  | Adam LR=2.96e-02 | h=10: Mean RMSE=3.910221, h=30: Mean RMSE=6.721739, h=60: Mean RMSE=9.441412, h=90: Mean RMSE=11.102262
# [I 2026-07-26 13:10:51,721] Trial 110 finished with value: 11.102261543273926 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.0296066006855149}. Best is trial 43 with value: 9.930177688598633.
# Trial 111 | k=50 | hidden_dim=100  | Adam LR=4.58e-02 | h=10: Mean RMSE=3.851411, h=30: Mean RMSE=6.614607, h=60: Mean RMSE=9.073844, h=90: Mean RMSE=10.406131
# [I 2026-07-26 13:12:01,508] Trial 111 finished with value: 10.40613079071045 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04579356342523448}. Best is trial 43 with value: 9.930177688598633.
# Trial 112 | k=50 | hidden_dim=100  | Adam LR=5.03e-02 | h=10: Mean RMSE=3.734975, h=30: Mean RMSE=6.459895, h=60: Mean RMSE=8.954935, h=90: Mean RMSE=10.594129
# [I 2026-07-26 13:13:16,363] Trial 112 finished with value: 10.594128608703613 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.05032095048236829}. Best is trial 43 with value: 9.930177688598633.
# Trial 113 | k=50 | hidden_dim=100  | Adam LR=5.72e-02 | h=10: Mean RMSE=3.702319, h=30: Mean RMSE=6.356124, h=60: Mean RMSE=9.031608, h=90: Mean RMSE=10.840059
# [I 2026-07-26 13:14:31,286] Trial 113 finished with value: 10.840059280395508 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.057207282251104385}. Best is trial 43 with value: 9.930177688598633.
# Trial 114 | k=50 | hidden_dim=100  | Adam LR=4.58e-02 | h=10: Mean RMSE=3.842070, h=30: Mean RMSE=6.485548, h=60: Mean RMSE=8.880865, h=90: Mean RMSE=10.030397
# [I 2026-07-26 13:15:44,703] Trial 114 finished with value: 10.030397415161133 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.045757516337942644}. Best is trial 43 with value: 9.930177688598633.
# Trial 115 | k=2  | hidden_dim=100  | Adam LR=1.22e-03 | h=10: Mean RMSE=5.940826, h=30: Mean RMSE=16.082966, h=60: Mean RMSE=30.593018, h=90: Mean RMSE=44.019886
# [I 2026-07-26 13:16:59,815] Trial 115 finished with value: 44.0198860168457 and parameters: {'k': 2, 'hidden_dim': 100, 'lr_adam': 0.0012217258687173159}. Best is trial 43 with value: 9.930177688598633.
# Trial 116 | k=50 | hidden_dim=100  | Adam LR=3.37e-02 | h=10: Mean RMSE=3.861458, h=30: Mean RMSE=6.640114, h=60: Mean RMSE=9.199967, h=90: Mean RMSE=10.650938
# [I 2026-07-26 13:18:14,167] Trial 116 finished with value: 10.650938034057617 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.033691483137555954}. Best is trial 43 with value: 9.930177688598633.
# Trial 117 | k=50 | hidden_dim=100  | Adam LR=2.60e-02 | h=10: Mean RMSE=3.845312, h=30: Mean RMSE=6.667822, h=60: Mean RMSE=9.192612, h=90: Mean RMSE=10.384297
# [I 2026-07-26 13:19:26,675] Trial 117 finished with value: 10.384297370910645 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.025958390951736743}. Best is trial 43 with value: 9.930177688598633.
# Trial 118 | k=50 | hidden_dim=50   | Adam LR=4.18e-02 | h=10: Mean RMSE=3.918021, h=30: Mean RMSE=6.716434, h=60: Mean RMSE=9.345616, h=90: Mean RMSE=10.968170
# [I 2026-07-26 13:20:29,052] Trial 118 finished with value: 10.968170166015625 and parameters: {'k': 50, 'hidden_dim': 50, 'lr_adam': 0.041790617714706525}. Best is trial 43 with value: 9.930177688598633.
# Trial 119 | k=30 | hidden_dim=100  | Adam LR=6.15e-02 | h=10: Mean RMSE=3.859270, h=30: Mean RMSE=6.583447, h=60: Mean RMSE=9.666420, h=90: Mean RMSE=12.909567
# [I 2026-07-26 13:21:29,841] Trial 119 finished with value: 12.909566879272461 and parameters: {'k': 30, 'hidden_dim': 100, 'lr_adam': 0.06147201237784534}. Best is trial 43 with value: 9.930177688598633.
# Trial 120 | k=50 | hidden_dim=100  | Adam LR=5.08e-02 | h=10: Mean RMSE=3.769365, h=30: Mean RMSE=6.490022, h=60: Mean RMSE=9.097916, h=90: Mean RMSE=10.700875
# [I 2026-07-26 13:22:47,002] Trial 120 finished with value: 10.700875282287598 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.050812293584724555}. Best is trial 43 with value: 9.930177688598633.
# Trial 121 | k=50 | hidden_dim=100  | Adam LR=4.56e-02 | h=10: Mean RMSE=3.796867, h=30: Mean RMSE=6.413130, h=60: Mean RMSE=8.823544, h=90: Mean RMSE=10.246243
# [I 2026-07-26 13:23:57,629] Trial 121 finished with value: 10.246243476867676 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.045625652261347224}. Best is trial 43 with value: 9.930177688598633.
# Trial 122 | k=50 | hidden_dim=100  | Adam LR=3.75e-02 | h=10: Mean RMSE=3.762509, h=30: Mean RMSE=6.414837, h=60: Mean RMSE=8.822177, h=90: Mean RMSE=10.165394
# [I 2026-07-26 13:25:02,008] Trial 122 finished with value: 10.165393829345703 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.03748383799922477}. Best is trial 43 with value: 9.930177688598633.
# Trial 123 | k=50 | hidden_dim=100  | Adam LR=3.79e-02 | h=10: Mean RMSE=3.821818, h=30: Mean RMSE=6.539525, h=60: Mean RMSE=9.108069, h=90: Mean RMSE=10.692533
# [I 2026-07-26 13:26:09,110] Trial 123 finished with value: 10.692533493041992 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.03791339768570841}. Best is trial 43 with value: 9.930177688598633.
# Trial 124 | k=50 | hidden_dim=100  | Adam LR=3.21e-02 | h=10: Mean RMSE=3.900220, h=30: Mean RMSE=6.654938, h=60: Mean RMSE=9.195256, h=90: Mean RMSE=10.431232
# [I 2026-07-26 13:27:19,015] Trial 124 finished with value: 10.431232452392578 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.0321101513409401}. Best is trial 43 with value: 9.930177688598633.
# Trial 125 | k=50 | hidden_dim=100  | Adam LR=7.22e-02 | h=10: Mean RMSE=3.774781, h=30: Mean RMSE=6.438802, h=60: Mean RMSE=9.223491, h=90: Mean RMSE=11.371132
# [I 2026-07-26 13:28:41,324] Trial 125 finished with value: 11.371131896972656 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.0721509182825546}. Best is trial 43 with value: 9.930177688598633.
# Trial 126 | k=50 | hidden_dim=100  | Adam LR=2.21e-02 | h=10: Mean RMSE=3.859192, h=30: Mean RMSE=6.747546, h=60: Mean RMSE=9.471716, h=90: Mean RMSE=11.083514
# [I 2026-07-26 13:29:51,119] Trial 126 finished with value: 11.083514213562012 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.02214017650028582}. Best is trial 43 with value: 9.930177688598633.
# Trial 127 | k=50 | hidden_dim=100  | Adam LR=2.36e-04 | h=10: Mean RMSE=5.683515, h=30: Mean RMSE=10.381090, h=60: Mean RMSE=16.988180, h=90: Mean RMSE=29.607517
# [I 2026-07-26 13:31:36,676] Trial 127 finished with value: 29.60751724243164 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.0002360323493922759}. Best is trial 43 with value: 9.930177688598633.
# Trial 128 | k=5  | hidden_dim=100  | Adam LR=4.93e-04 | h=10: Mean RMSE=4.722646, h=30: Mean RMSE=13.067041, h=60: Mean RMSE=27.022146, h=90: Mean RMSE=40.804920
# [I 2026-07-26 13:32:58,323] Trial 128 finished with value: 40.8049201965332 and parameters: {'k': 5, 'hidden_dim': 100, 'lr_adam': 0.0004932547726878353}. Best is trial 43 with value: 9.930177688598633.
# Trial 129 | k=20 | hidden_dim=100  | Adam LR=5.55e-02 | h=10: Mean RMSE=4.018083, h=30: Mean RMSE=8.242989, h=60: Mean RMSE=14.419864, h=90: Mean RMSE=21.165607
# [I 2026-07-26 13:33:58,701] Trial 129 finished with value: 21.165607452392578 and parameters: {'k': 20, 'hidden_dim': 100, 'lr_adam': 0.05545417090371178}. Best is trial 43 with value: 9.930177688598633.
# Trial 130 | k=50 | hidden_dim=100  | Adam LR=2.93e-02 | h=10: Mean RMSE=3.886280, h=30: Mean RMSE=6.678275, h=60: Mean RMSE=9.345224, h=90: Mean RMSE=11.031743
# [I 2026-07-26 13:35:08,385] Trial 130 finished with value: 11.031743049621582 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.029294958949364572}. Best is trial 43 with value: 9.930177688598633.
# ...
# Trial 157 | k=50 | hidden_dim=100  | Adam LR=6.67e-02 | h=10: Mean RMSE=3.791615, h=30: Mean RMSE=6.506554, h=60: Mean RMSE=8.946461, h=90: Mean RMSE=10.715542
# [I 2026-07-26 14:05:20,588] Trial 157 finished with value: 10.71554183959961 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.066711677033581}. Best is trial 43 with value: 9.930177688598633.
# Trial 158 | k=50 | hidden_dim=100  | Adam LR=5.58e-02 | h=10: Mean RMSE=3.788766, h=30: Mean RMSE=6.445044, h=60: Mean RMSE=9.071024, h=90: Mean RMSE=10.788412
# [I 2026-07-26 14:06:42,080] Trial 158 finished with value: 10.788412094116211 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.055785107935046686}. Best is trial 43 with value: 9.930177688598633.
# Trial 159 | k=50 | hidden_dim=20   | Adam LR=4.94e-02 | h=10: Mean RMSE=3.748629, h=30: Mean RMSE=6.494012, h=60: Mean RMSE=9.361114, h=90: Mean RMSE=11.570174
# [I 2026-07-26 14:07:43,388] Trial 159 finished with value: 11.570174217224121 and parameters: {'k': 50, 'hidden_dim': 20, 'lr_adam': 0.04937273064557556}. Best is trial 43 with value: 9.930177688598633.
# Trial 160 | k=5  | hidden_dim=100  | Adam LR=3.56e-02 | h=10: Mean RMSE=5.374778, h=30: Mean RMSE=14.928413, h=60: Mean RMSE=29.398550, h=90: Mean RMSE=43.225567
# [I 2026-07-26 14:08:48,465] Trial 160 finished with value: 43.22556686401367 and parameters: {'k': 5, 'hidden_dim': 100, 'lr_adam': 0.03562161150192594}. Best is trial 43 with value: 9.930177688598633.
# Trial 161 | k=50 | hidden_dim=100  | Adam LR=4.39e-02 | h=10: Mean RMSE=3.847871, h=30: Mean RMSE=6.599707, h=60: Mean RMSE=8.906359, h=90: Mean RMSE=10.103479
# [I 2026-07-26 14:10:00,538] Trial 161 finished with value: 10.103479385375977 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.043915801244550676}. Best is trial 43 with value: 9.930177688598633.
# Trial 162 | k=50 | hidden_dim=100  | Adam LR=4.17e-02 | h=10: Mean RMSE=3.883041, h=30: Mean RMSE=6.645803, h=60: Mean RMSE=9.096446, h=90: Mean RMSE=10.282563
# [I 2026-07-26 14:11:09,073] Trial 162 finished with value: 10.282563209533691 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04172406634200199}. Best is trial 43 with value: 9.930177688598633.
# Trial 163 | k=50 | hidden_dim=100  | Adam LR=2.73e-02 | h=10: Mean RMSE=3.925195, h=30: Mean RMSE=6.790792, h=60: Mean RMSE=9.453756, h=90: Mean RMSE=11.382989
# [I 2026-07-26 14:12:22,788] Trial 163 finished with value: 11.382988929748535 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.027337127840684924}. Best is trial 43 with value: 9.930177688598633.
# Trial 164 | k=50 | hidden_dim=100  | Adam LR=5.06e-02 | h=10: Mean RMSE=3.645657, h=30: Mean RMSE=6.134038, h=60: Mean RMSE=8.625022, h=90: Mean RMSE=10.276441
# [I 2026-07-26 14:13:37,113] Trial 164 finished with value: 10.276440620422363 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.05063037123999087}. Best is trial 43 with value: 9.930177688598633.
# Trial 165 | k=20 | hidden_dim=100  | Adam LR=4.38e-02 | h=10: Mean RMSE=4.138533, h=30: Mean RMSE=8.749304, h=60: Mean RMSE=15.277926, h=90: Mean RMSE=22.509975
# [I 2026-07-26 14:14:39,466] Trial 165 finished with value: 22.50997543334961 and parameters: {'k': 20, 'hidden_dim': 100, 'lr_adam': 0.04376350500863245}. Best is trial 43 with value: 9.930177688598633.
# Trial 166 | k=50 | hidden_dim=100  | Adam LR=5.91e-02 | h=10: Mean RMSE=3.741431, h=30: Mean RMSE=6.418388, h=60: Mean RMSE=9.060718, h=90: Mean RMSE=10.734813
# [I 2026-07-26 14:15:58,506] Trial 166 finished with value: 10.73481273651123 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.05909161313848908}. Best is trial 43 with value: 9.930177688598633.
# Trial 167 | k=50 | hidden_dim=50   | Adam LR=3.57e-02 | h=10: Mean RMSE=3.823483, h=30: Mean RMSE=6.569783, h=60: Mean RMSE=9.054578, h=90: Mean RMSE=10.958240
# [I 2026-07-26 14:17:02,433] Trial 167 finished with value: 10.958239555358887 and parameters: {'k': 50, 'hidden_dim': 50, 'lr_adam': 0.03570320219319048}. Best is trial 43 with value: 9.930177688598633.
# Trial 168 | k=50 | hidden_dim=100  | Adam LR=3.11e-02 | h=10: Mean RMSE=3.891483, h=30: Mean RMSE=6.728904, h=60: Mean RMSE=9.171457, h=90: Mean RMSE=10.509405
# [I 2026-07-26 14:18:13,157] Trial 168 finished with value: 10.509405136108398 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.031083784897520287}. Best is trial 43 with value: 9.930177688598633.
# Trial 169 | k=10 | hidden_dim=100  | Adam LR=1.27e-04 | h=10: Mean RMSE=4.125028, h=30: Mean RMSE=9.342460, h=60: Mean RMSE=16.368870, h=90: Mean RMSE=23.096333
# [I 2026-07-26 14:19:45,099] Trial 169 finished with value: 23.096332550048828 and parameters: {'k': 10, 'hidden_dim': 100, 'lr_adam': 0.00012661157861128977}. Best is trial 43 with value: 9.930177688598633.
# Trial 170 | k=50 | hidden_dim=100  | Adam LR=4.08e-02 | h=10: Mean RMSE=3.790129, h=30: Mean RMSE=6.512313, h=60: Mean RMSE=9.139844, h=90: Mean RMSE=10.584200
# [I 2026-07-26 14:20:51,760] Trial 170 finished with value: 10.584199905395508 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04079641391707533}. Best is trial 43 with value: 9.930177688598633.
# Trial 171 | k=50 | hidden_dim=100  | Adam LR=4.72e-02 | h=10: Mean RMSE=3.794750, h=30: Mean RMSE=6.412677, h=60: Mean RMSE=8.895363, h=90: Mean RMSE=10.423211
# [I 2026-07-26 14:22:03,436] Trial 171 finished with value: 10.423211097717285 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04717725037937415}. Best is trial 43 with value: 9.930177688598633.
# Trial 172 | k=50 | hidden_dim=100  | Adam LR=5.29e-02 | h=10: Mean RMSE=3.847764, h=30: Mean RMSE=6.602714, h=60: Mean RMSE=9.368388, h=90: Mean RMSE=11.406291
# [I 2026-07-26 14:23:19,682] Trial 172 finished with value: 11.406291007995605 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.05294994373422144}. Best is trial 43 with value: 9.930177688598633.
# Trial 173 | k=50 | hidden_dim=100  | Adam LR=4.58e-02 | h=10: Mean RMSE=3.888110, h=30: Mean RMSE=6.565415, h=60: Mean RMSE=9.073598, h=90: Mean RMSE=10.523537
# [I 2026-07-26 14:24:29,053] Trial 173 finished with value: 10.523536682128906 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04584569398524315}. Best is trial 43 with value: 9.930177688598633.
# Trial 174 | k=50 | hidden_dim=100  | Adam LR=3.60e-02 | h=10: Mean RMSE=3.922568, h=30: Mean RMSE=6.721028, h=60: Mean RMSE=9.245813, h=90: Mean RMSE=10.792564
# [I 2026-07-26 14:25:37,477] Trial 174 finished with value: 10.792564392089844 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.03596973971530533}. Best is trial 43 with value: 9.930177688598633.
# Trial 175 | k=50 | hidden_dim=100  | Adam LR=6.76e-02 | h=10: Mean RMSE=3.853554, h=30: Mean RMSE=6.671727, h=60: Mean RMSE=9.161592, h=90: Mean RMSE=10.886879
# [I 2026-07-26 14:26:58,063] Trial 175 finished with value: 10.886878967285156 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.06763611883118531}. Best is trial 43 with value: 9.930177688598633.
# Trial 176 | k=40 | hidden_dim=100  | Adam LR=5.80e-02 | h=10: Mean RMSE=3.829090, h=30: Mean RMSE=6.654944, h=60: Mean RMSE=9.704854, h=90: Mean RMSE=11.947557
# [I 2026-07-26 14:28:09,567] Trial 176 finished with value: 11.94755744934082 and parameters: {'k': 40, 'hidden_dim': 100, 'lr_adam': 0.05802126720661083}. Best is trial 43 with value: 9.930177688598633.
# Trial 177 | k=50 | hidden_dim=100  | Adam LR=4.08e-02 | h=10: Mean RMSE=3.818484, h=30: Mean RMSE=6.584120, h=60: Mean RMSE=8.981390, h=90: Mean RMSE=10.381926
# [I 2026-07-26 14:29:16,606] Trial 177 finished with value: 10.381925582885742 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.040807614250257}. Best is trial 43 with value: 9.930177688598633.
# Trial 178 | k=50 | hidden_dim=100  | Adam LR=4.78e-02 | h=10: Mean RMSE=3.818373, h=30: Mean RMSE=6.432451, h=60: Mean RMSE=8.929058, h=90: Mean RMSE=10.380187
# [I 2026-07-26 14:30:27,404] Trial 178 finished with value: 10.380187034606934 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.0478172338579103}. Best is trial 43 with value: 9.930177688598633.
# Trial 179 | k=50 | hidden_dim=100  | Adam LR=3.20e-02 | h=10: Mean RMSE=3.856390, h=30: Mean RMSE=6.565806, h=60: Mean RMSE=9.034031, h=90: Mean RMSE=10.448118
# [I 2026-07-26 14:31:36,350] Trial 179 finished with value: 10.448118209838867 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.031955274767325174}. Best is trial 43 with value: 9.930177688598633.
# Trial 180 | k=2  | hidden_dim=100  | Adam LR=2.81e-02 | h=10: Mean RMSE=5.870703, h=30: Mean RMSE=16.102470, h=60: Mean RMSE=30.940866, h=90: Mean RMSE=44.697014
# [I 2026-07-26 14:32:28,562] Trial 180 finished with value: 44.69701385498047 and parameters: {'k': 2, 'hidden_dim': 100, 'lr_adam': 0.028117693584433872}. Best is trial 43 with value: 9.930177688598633.
# Trial 181 | k=50 | hidden_dim=100  | Adam LR=5.05e-02 | h=10: Mean RMSE=3.802697, h=30: Mean RMSE=6.536037, h=60: Mean RMSE=9.026800, h=90: Mean RMSE=10.664816
# [I 2026-07-26 14:33:41,078] Trial 181 finished with value: 10.664815902709961 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.05046414513213453}. Best is trial 43 with value: 9.930177688598633.
# Trial 182 | k=50 | hidden_dim=100  | Adam LR=4.22e-02 | h=10: Mean RMSE=3.795205, h=30: Mean RMSE=6.448582, h=60: Mean RMSE=9.064342, h=90: Mean RMSE=10.566951
# [I 2026-07-26 14:34:48,311] Trial 182 finished with value: 10.566950798034668 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04217839984277772}. Best is trial 43 with value: 9.930177688598633.
# Trial 183 | k=50 | hidden_dim=100  | Adam LR=5.08e-02 | h=10: Mean RMSE=3.859759, h=30: Mean RMSE=6.604137, h=60: Mean RMSE=9.216179, h=90: Mean RMSE=10.685671
# [I 2026-07-26 14:36:03,672] Trial 183 finished with value: 10.685670852661133 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.05084213504833332}. Best is trial 43 with value: 9.930177688598633.
# Trial 184 | k=50 | hidden_dim=100  | Adam LR=3.64e-02 | h=10: Mean RMSE=3.862352, h=30: Mean RMSE=6.691747, h=60: Mean RMSE=9.173830, h=90: Mean RMSE=10.598955
# [I 2026-07-26 14:37:11,764] Trial 184 finished with value: 10.598955154418945 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.03642686605018314}. Best is trial 43 with value: 9.930177688598633.
# Trial 185 | k=50 | hidden_dim=100  | Adam LR=5.96e-02 | h=10: Mean RMSE=3.809981, h=30: Mean RMSE=6.662396, h=60: Mean RMSE=9.571688, h=90: Mean RMSE=11.872883
# [I 2026-07-26 14:38:30,163] Trial 185 finished with value: 11.872882843017578 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.05957734099240879}. Best is trial 43 with value: 9.930177688598633.
# Trial 186 | k=30 | hidden_dim=100  | Adam LR=5.58e-03 | h=10: Mean RMSE=4.671206, h=30: Mean RMSE=8.245511, h=60: Mean RMSE=12.642115, h=90: Mean RMSE=17.404486
# [I 2026-07-26 14:39:46,392] Trial 186 finished with value: 17.40448570251465 and parameters: {'k': 30, 'hidden_dim': 100, 'lr_adam': 0.005579695543320297}. Best is trial 43 with value: 9.930177688598633.
# Trial 187 | k=50 | hidden_dim=100  | Adam LR=4.46e-02 | h=10: Mean RMSE=3.857094, h=30: Mean RMSE=6.525475, h=60: Mean RMSE=8.955603, h=90: Mean RMSE=10.444334
# [I 2026-07-26 14:40:52,712] Trial 187 finished with value: 10.444334030151367 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.04462672014886639}. Best is trial 43 with value: 9.930177688598633.
# Trial 188 | k=50 | hidden_dim=100  | Adam LR=1.52e-03 | h=10: Mean RMSE=5.454197, h=30: Mean RMSE=9.449314, h=60: Mean RMSE=14.499924, h=90: Mean RMSE=18.544682
# [I 2026-07-26 14:42:15,896] Trial 188 finished with value: 18.544681549072266 and parameters: {'k': 50, 'hidden_dim': 100, 'lr_adam': 0.0015242256777210233}. Best is trial 43 with value: 9.930177688598633.
# Trial 189 | k=50 | hidden_dim=50   | Adam LR=7.30e-02 | h=10: Mean RMSE=3.666742, h=30: Mean RMSE=6.133021, h=60: Mean RMSE=8.567776, h=90: Mean RMSE=10.261198
# [I 2026-07-26 14:43:20,213] Trial 189 finished with value: 10.261198043823242 and parameters: {'k': 50, 'hidden_dim': 50, 'lr_adam': 0.07296340555443964}. Best is trial 43 with value: 9.930177688598633.
# Trial 190 | k=50 | hidden_dim=50   | Adam LR=8.68e-02 | h=10: Mean RMSE=3.729538, h=30: Mean RMSE=6.388377, h=60: Mean RMSE=9.047631, h=90: Mean RMSE=10.908424
# [I 2026-07-26 14:44:27,745] Trial 190 finished with value: 10.908424377441406 and parameters: {'k': 50, 'hidden_dim': 50, 'lr_adam': 0.08678114105332371}. Best is trial 43 with value: 9.930177688598633.
# Trial 191 | k=50 | hidden_dim=50   | Adam LR=7.33e-02 | h=10: Mean RMSE=3.748608, h=30: Mean RMSE=6.309876, h=60: Mean RMSE=8.667182, h=90: Mean RMSE=10.271124
# [I 2026-07-26 14:45:33,507] Trial 191 finished with value: 10.271123886108398 and parameters: {'k': 50, 'hidden_dim': 50, 'lr_adam': 0.07328194032072156}. Best is trial 43 with value: 9.930177688598633.
# Trial 192 | k=50 | hidden_dim=50   | Adam LR=7.23e-02 | h=10: Mean RMSE=3.721331, h=30: Mean RMSE=6.323091, h=60: Mean RMSE=8.946367, h=90: Mean RMSE=10.683587
# [I 2026-07-26 14:46:36,129] Trial 192 finished with value: 10.683587074279785 and parameters: {'k': 50, 'hidden_dim': 50, 'lr_adam': 0.07226736359564795}. Best is trial 43 with value: 9.930177688598633.
# Trial 193 | k=50 | hidden_dim=50   | Adam LR=8.12e-02 | h=10: Mean RMSE=3.774148, h=30: Mean RMSE=6.407845, h=60: Mean RMSE=8.934445, h=90: Mean RMSE=10.543759
# [I 2026-07-26 14:47:41,327] Trial 193 finished with value: 10.5437593460083 and parameters: {'k': 50, 'hidden_dim': 50, 'lr_adam': 0.08118869365187728}. Best is trial 43 with value: 9.930177688598633.
# Trial 194 | k=50 | hidden_dim=50   | Adam LR=6.61e-02 | h=10: Mean RMSE=3.786470, h=30: Mean RMSE=6.426795, h=60: Mean RMSE=9.110907, h=90: Mean RMSE=11.169154
# [I 2026-07-26 14:48:42,414] Trial 194 finished with value: 11.169154167175293 and parameters: {'k': 50, 'hidden_dim': 50, 'lr_adam': 0.06613750333448709}. Best is trial 43 with value: 9.930177688598633.
# Trial 195 | k=50 | hidden_dim=50   | Adam LR=3.90e-02 | h=10: Mean RMSE=3.851140, h=30: Mean RMSE=6.556139, h=60: Mean RMSE=9.156906, h=90: Mean RMSE=11.076731
# [I 2026-07-26 14:49:46,787] Trial 195 finished with value: 11.076730728149414 and parameters: {'k': 50, 'hidden_dim': 50, 'lr_adam': 0.03897864927865833}. Best is trial 43 with value: 9.930177688598633.
# Trial 196 | k=50 | hidden_dim=50   | Adam LR=9.39e-02 | h=10: Mean RMSE=3.738880, h=30: Mean RMSE=6.398480, h=60: Mean RMSE=8.933504, h=90: Mean RMSE=10.638769
# [I 2026-07-26 14:50:53,033] Trial 196 finished with value: 10.638769149780273 and parameters: {'k': 50, 'hidden_dim': 50, 'lr_adam': 0.0938713942767172}. Best is trial 43 with value: 9.930177688598633.
# Trial 197 | k=50 | hidden_dim=50   | Adam LR=5.46e-02 | h=10: Mean RMSE=3.827507, h=30: Mean RMSE=6.587719, h=60: Mean RMSE=9.130839, h=90: Mean RMSE=10.686846
# [I 2026-07-26 14:51:55,262] Trial 197 finished with value: 10.686845779418945 and parameters: {'k': 50, 'hidden_dim': 50, 'lr_adam': 0.05457522902098018}. Best is trial 43 with value: 9.930177688598633.
# Trial 198 | k=50 | hidden_dim=50   | Adam LR=3.28e-02 | h=10: Mean RMSE=3.779103, h=30: Mean RMSE=6.473540, h=60: Mean RMSE=9.102468, h=90: Mean RMSE=11.059885
# [I 2026-07-26 14:52:57,650] Trial 198 finished with value: 11.059885025024414 and parameters: {'k': 50, 'hidden_dim': 50, 'lr_adam': 0.03283556857946357}. Best is trial 43 with value: 9.930177688598633.
# Trial 199 | k=5  | hidden_dim=50   | Adam LR=7.47e-04 | h=10: Mean RMSE=4.638452, h=30: Mean RMSE=13.041087, h=60: Mean RMSE=26.824017, h=90: Mean RMSE=39.689453
# [I 2026-07-26 14:54:18,368] Trial 199 finished with value: 39.689453125 and parameters: {'k': 5, 'hidden_dim': 50, 'lr_adam': 0.0007474760637627405}. Best is trial 43 with value: 9.930177688598633.
#
# ==== Best Adaptive NVAR Configuration ====
#
# k             : 50
# hidden_dim    : 100
# Adam LR       : 4.15e-02
# Best MSE@90   : 122.770065
# Best MAE@90   : 8.655377
# Best RMSE@90  : 9.930178
# Execution time: 14102.91 seconds

# %%
import numpy as np
import torch

# ============================================================
# TEST DATASET EVALUATION (Overlapping Windows)
# Adaptive NVAR
# ============================================================

test_window_size = 90
test_stride = 1
horizons = [10, 30, 60, 90]

# Containers (Latent Space)
all_test_preds, all_test_true, all_test_noisy = [], [], []
all_test_mse, all_test_mae, all_test_rmse = [], [], []

# Containers (Original SST Space)
all_test_rec_sst, all_test_true_sst = [], []
all_test_mse_sst, all_test_mae_sst, all_test_rmse_sst = [], [], []

# ============================================================
# Persistence Baseline Containers (SST Space)
# ============================================================
all_persist_mse_sst = []
all_persist_mae_sst = []
all_persist_rmse_sst = []

horizon_persist_mses_sst = {h: [] for h in horizons}
horizon_persist_maes_sst = {h: [] for h in horizons}

# Horizon-wise Storage
horizon_mses = {h: [] for h in horizons}
horizon_maes = {h: [] for h in horizons}
horizon_mses_sst = {h: [] for h in horizons}
horizon_maes_sst = {h: [] for h in horizons}

# ============================================================
# Reload Best Models (Ensemble of 3 Runs)
# ============================================================

best_k = best_config["k"]
best_hidden = best_config["hidden_dim"]
best_lr_adam = best_config["lr_adam"]

d = X_train.shape[1]
best_dk = d * best_k
best_m = int((best_dk * (best_dk + 1)) / 2)

num_runs = 5
best_models = []

for run in range(num_runs):
    best_model_path = f"optuna_model_k{best_k}_hd{best_hidden}_adam{best_lr_adam:.2e}_run{run}.pth"
    print(f"Loading model ({run + 1}/{num_runs}): {best_model_path}")

    model = AdaptiveNVARModel(
        dk=best_dk, m=best_m, d=d, hidden_dim=best_hidden
    ).to(device)

    model.load_state_dict(torch.load(best_model_path, map_location=device))
    model.eval()
    best_models.append(model)

# ============================================================
# TEST Rollout Predictions (Averaged Across 3 Runs)
# ============================================================

print("\n==== Adaptive NVAR TEST Evaluation (3-Model Ensemble) ====\n")

num_windows = len(X_test_true) - test_window_size + 1

for start in range(0, num_windows, test_stride):
    end = start + test_window_size

    X_test_true_window = X_test_true[start:end]
    X_test_noisy_window = X_test[start:end]

    # Global TEST Indices
    global_test_start = warmup_len + train_len + val_len + start
    global_test_end = global_test_start + test_window_size

    # Delay Context Initialization
    init_start = global_test_start - best_k
    init_end = global_test_start
    X_init = X[init_start:init_end].to(device)

    # Rollout predictions for each of the 3 independent models
    run_predictions = []

    for model in best_models:
        x_t = [x.clone() for x in X_init.unbind(0)]
        H_lin = torch.cat(x_t, dim=-1).unsqueeze(0)

        preds = []
        for step in range(test_window_size):
            with torch.no_grad():
                delta_x = model(H_lin)

            x_next = x_t[-1] + delta_x.squeeze(0)
            preds.append(x_next)

            # Update delay buffer
            x_t = x_t[1:] + [x_next]
            H_lin = torch.cat(x_t, dim=-1).unsqueeze(0)

        run_predictions.append(torch.stack(preds).cpu().numpy())

    # Average rollout predictions across the 3 models
    pred_np = np.mean(run_predictions, axis=0)
    true_np = X_test_true_window.cpu().numpy()
    noisy_np = X_test_noisy_window.cpu().numpy()

    # Spatial SST Reconstruction (Original Space)
    reconstructed_sst = pca.inverse_transform(pred_np)
    true_sst = sst_time_major[global_test_start:global_test_end]

    assert reconstructed_sst.shape == true_sst.shape

    # Standard Persistence Forecast (SST Space)
    persistent_sst = np.repeat(true_sst[0][None, :], test_window_size, axis=0)

    all_test_rec_sst.append(reconstructed_sst)
    all_test_true_sst.append(true_sst)




    # ------------------------------------------------------------
    # Horizon-wise Metrics (Exact Lead Step: index h - 1)
    # ------------------------------------------------------------
    for h in horizons:
        if h > pred_np.shape[0]:
            continue
        
        idx = h - 1
        
        # Latent Space
        horizon_mses[h].append((true_np[idx] - pred_np[idx]) ** 2)
        horizon_maes[h].append(np.abs(true_np[idx] - pred_np[idx]))

        # Original SST Space
        horizon_mses_sst[h].append((true_sst[idx] - reconstructed_sst[idx]) ** 2)
        horizon_maes_sst[h].append(np.abs(true_sst[idx] - reconstructed_sst[idx]))

        # Persistence Baseline (SST Space)
        horizon_persist_mses_sst[h].append((true_sst[idx] - persistent_sst[idx]) ** 2)
        horizon_persist_maes_sst[h].append(np.abs(true_sst[idx] - persistent_sst[idx]))

    # ------------------------------------------------------------
    # Full-window Metrics (Latent Space)
    # ------------------------------------------------------------
    full_mse = np.mean((true_np - pred_np) ** 2)
    full_mae = np.mean(np.abs(true_np - pred_np))
    full_rmse = np.sqrt(full_mse)

    all_test_mse.append(full_mse)
    all_test_mae.append(full_mae)
    all_test_rmse.append((start, end, full_rmse))

    all_test_preds.append(pred_np)
    all_test_true.append(true_np)
    all_test_noisy.append(noisy_np)

    # ------------------------------------------------------------
    # Full-window Metrics (Original SST Space)
    # ------------------------------------------------------------
    full_mse_sst = np.mean((true_sst - reconstructed_sst) ** 2)
    full_mae_sst = np.mean(np.abs(true_sst - reconstructed_sst))
    full_rmse_sst = np.sqrt(full_mse_sst)

    all_test_mse_sst.append(full_mse_sst)
    all_test_mae_sst.append(full_mae_sst)
    all_test_rmse_sst.append((start, end, full_rmse_sst))

    # ------------------------------------------------------------
    # Persistence Baseline (Full Window)
    # ------------------------------------------------------------
    persist_mse_sst = np.mean((true_sst - persistent_sst) ** 2)
    persist_mae_sst = np.mean(np.abs(true_sst - persistent_sst))
    persist_rmse_sst = np.sqrt(persist_mse_sst)

    all_persist_mse_sst.append(persist_mse_sst)
    all_persist_mae_sst.append(persist_mae_sst)
    all_persist_rmse_sst.append((start, end, persist_rmse_sst))


# ============================================================
# SUMMARY DIAGNOSTICS
# ============================================================

latent_variables = [f"PC {i+1}" for i in range(d)]

# --- 1. LATENT SPACE METRICS ---
print("\n" + "=" * 60)
print("  TEST Horizon-wise Forecast Skill (LATENT SPACE)")
print("=" * 60)

for h in horizons:
    if not horizon_mses[h]:
        continue

    mse_array = np.vstack(horizon_mses[h])
    mae_array = np.vstack(horizon_maes[h])

    mean_mse_per_var = np.mean(mse_array, axis=0)
    mean_mae_per_var = np.mean(mae_array, axis=0)
    rmse_per_var = np.sqrt(mean_mse_per_var)

    overall_mse = np.mean(mean_mse_per_var)
    overall_mae = np.mean(mean_mae_per_var)
    overall_rmse = np.sqrt(overall_mse)

    print(f"\n-- Forecast Horizon: Step {h} --")
    for i, var in enumerate(latent_variables):
        print(f"{var:<8} | MSE : {mean_mse_per_var[i]:.6f} | MAE : {mean_mae_per_var[i]:.6f} | RMSE : {rmse_per_var[i]:.6f}")

    print(f"Overall   | MSE : {overall_mse:.6f} | MAE : {overall_mae:.6f} | RMSE : {overall_rmse:.6f}")


# --- 2. RECONSTRUCTED SST SPACE METRICS ---
print("\n" + "=" * 60)
print("  TEST Horizon-wise Forecast Skill (RECONSTRUCTED SST)")
print("=" * 60)

for h in horizons:
    if not horizon_mses_sst[h]:
        continue

    # Adaptive NVAR Metrics
    mse_array_sst = np.vstack(horizon_mses_sst[h])
    mae_array_sst = np.vstack(horizon_maes_sst[h])

    overall_mse_sst = np.mean(mse_array_sst)
    overall_mae_sst = np.mean(mae_array_sst)
    overall_rmse_sst = np.sqrt(overall_mse_sst)

    # Persistence Metrics
    persist_mse = np.mean(np.vstack(horizon_persist_mses_sst[h]))
    persist_mae = np.mean(np.vstack(horizon_persist_maes_sst[h]))
    persist_rmse = np.sqrt(persist_mse)

    # Percentage Improvements
    imp_mse = ((persist_mse - overall_mse_sst) / persist_mse) * 100
    imp_mae = ((persist_mae - overall_mae_sst) / persist_mae) * 100
    imp_rmse = ((persist_rmse - overall_rmse_sst) / persist_rmse) * 100

    print(f"\n-- Forecast Horizon: Step {h} --")
    print(f"Adaptive NVAR | MSE : {overall_mse_sst:.6f} | MAE : {overall_mae_sst:.6f} | RMSE : {overall_rmse_sst:.6f}")
    print(f"Persistence   | MSE : {persist_mse:.6f} | MAE : {persist_mae:.6f} | RMSE : {persist_rmse:.6f}")
    print(f"Improvement   | MSE : {imp_mse:+.2f}%   | MAE : {imp_mae:+.2f}%   | RMSE : {imp_rmse:+.2f}%")


# --- 3. OVERALL TEST SUMMARY ---
print("\n" + "=" * 60)
print("  Overall TEST Summary (Full Window Averages)")
print("=" * 60 + "\n")

overall_nvar_mse_sst = np.mean(all_test_mse_sst)
overall_nvar_mae_sst = np.mean(all_test_mae_sst)
overall_nvar_rmse_sst = np.mean([x[2] for x in all_test_rmse_sst])

overall_per_mse_sst = np.mean(all_persist_mse_sst)
overall_per_mae_sst = np.mean(all_persist_mae_sst)
overall_per_rmse_sst = np.mean([x[2] for x in all_persist_rmse_sst])

# Overall Improvements
overall_imp_mse = ((overall_per_mse_sst - overall_nvar_mse_sst) / overall_per_mse_sst) * 100
overall_imp_mae = ((overall_per_mae_sst - overall_nvar_mae_sst) / overall_per_mae_sst) * 100
overall_imp_rmse = ((overall_per_rmse_sst - overall_nvar_rmse_sst) / overall_per_rmse_sst) * 100

print(f"Latent Space (Adaptive NVAR) | MSE : {np.mean(all_test_mse):.6f} | MAE : {np.mean(all_test_mae):.6f} | RMSE : {np.mean([x[2] for x in all_test_rmse]):.6f}")
print(f"SST Space (Adaptive NVAR)    | MSE : {overall_nvar_mse_sst:.6f} | MAE : {overall_nvar_mae_sst:.6f} | RMSE : {overall_nvar_rmse_sst:.6f}")
print(f"SST Space (Persistence)      | MSE : {overall_per_mse_sst:.6f} | MAE : {overall_per_mae_sst:.6f} | RMSE : {overall_per_rmse_sst:.6f}")
print(f"Improvement vs Persistence   | MSE : {overall_imp_mse:+.2f}%   | MAE : {overall_imp_mae:+.2f}%   | RMSE : {overall_imp_rmse:+.2f}%")

print("-" * 60)
print(f"TEST Window Size   : {test_window_size}")
print(f"TEST Stride        : {test_stride}")
print(f"Total TEST Windows : {len(all_test_rmse)}")
print("=" * 60)
# Out:
# Loading model (1/5): optuna_model_k50_hd100_adam4.15e-02_run0.pth
# Loading model (2/5): optuna_model_k50_hd100_adam4.15e-02_run1.pth
# Loading model (3/5): optuna_model_k50_hd100_adam4.15e-02_run2.pth
# Loading model (4/5): optuna_model_k50_hd100_adam4.15e-02_run3.pth
# Loading model (5/5): optuna_model_k50_hd100_adam4.15e-02_run4.pth
#
# ==== Adaptive NVAR TEST Evaluation (3-Model Ensemble) ====
#
#
# ============================================================
#   TEST Horizon-wise Forecast Skill (LATENT SPACE)
# ============================================================
#
# -- Forecast Horizon: Step 10 --
# PC 1     | MSE : 45.714325 | MAE : 5.143879 | RMSE : 6.761237
# Overall   | MSE : 45.714325 | MAE : 5.143879 | RMSE : 6.761237
#
# -- Forecast Horizon: Step 30 --
# PC 1     | MSE : 172.301025 | MAE : 10.472043 | RMSE : 13.126348
# Overall   | MSE : 172.301025 | MAE : 10.472043 | RMSE : 13.126348
#
# -- Forecast Horizon: Step 60 --
# PC 1     | MSE : 389.332123 | MAE : 16.616486 | RMSE : 19.731501
# Overall   | MSE : 389.332123 | MAE : 16.616486 | RMSE : 19.731501
#
# -- Forecast Horizon: Step 90 --
# PC 1     | MSE : 439.671295 | MAE : 18.170742 | RMSE : 20.968340
# Overall   | MSE : 439.671295 | MAE : 18.170742 | RMSE : 20.968340
#
# ============================================================
#   TEST Horizon-wise Forecast Skill (RECONSTRUCTED SST)
# ============================================================
#
# -- Forecast Horizon: Step 10 --
# Adaptive NVAR | MSE : 0.060162 | MAE : 0.184054 | RMSE : 0.245280
# Persistence   | MSE : 0.072619 | MAE : 0.203251 | RMSE : 0.269480
# Improvement   | MSE : +17.15%   | MAE : +9.45%   | RMSE : +8.98%
#
# -- Forecast Horizon: Step 30 --
# Adaptive NVAR | MSE : 0.102370 | MAE : 0.251061 | RMSE : 0.319953
# Persistence   | MSE : 0.381382 | MAE : 0.507724 | RMSE : 0.617561
# Improvement   | MSE : +73.16%   | MAE : +50.55%   | RMSE : +48.19%
#
# -- Forecast Horizon: Step 60 --
# Adaptive NVAR | MSE : 0.176079 | MAE : 0.339694 | RMSE : 0.419618
# Persistence   | MSE : 1.197950 | MAE : 0.921240 | RMSE : 1.094509
# Improvement   | MSE : +85.30%   | MAE : +63.13%   | RMSE : +61.66%
#
# -- Forecast Horizon: Step 90 --
# Adaptive NVAR | MSE : 0.196225 | MAE : 0.365826 | RMSE : 0.442973
# Persistence   | MSE : 2.252161 | MAE : 1.273577 | RMSE : 1.500720
# Improvement   | MSE : +91.29%   | MAE : +71.28%   | RMSE : +70.48%
#
# ============================================================
#   Overall TEST Summary (Full Window Averages)
# ============================================================
#
# Latent Space (Adaptive NVAR) | MSE : 269.897797 | MAE : 12.768413 | RMSE : 15.043639
# SST Space (Adaptive NVAR)    | MSE : 0.136132 | MAE : 0.287891 | RMSE : 0.353307
# SST Space (Persistence)      | MSE : 0.886628 | MAE : 0.705623 | RMSE : 0.846092
# Improvement vs Persistence   | MSE : +84.65%   | MAE : +59.20%   | RMSE : +58.24%
# ------------------------------------------------------------
# TEST Window Size   : 90
# TEST Stride        : 1
# Total TEST Windows : 411
# ============================================================

# %%
import matplotlib.pyplot as plt
import numpy as np

# ============================================================
# 1. VARIABLE RESOLUTION & SETUP
# ============================================================
plot_len = 90    # Set forecast horizon to visualize
window_idx = 330  # 0 = first window, 1 = second, ...

# Fallback check to ensure data variables exist in memory
if 'y_test_rec_sst' in globals() and len(y_test_rec_sst) > 0:
    X_rec_norm = y_test_rec_sst
    X_test_true_raw = y_test_true_sst
elif 'all_test_rec_sst' in globals() and len(all_test_rec_sst) > 0:
    X_rec_norm = all_test_rec_sst[window_idx]
    X_test_true_raw = all_test_true_sst[window_idx]
else:
    raise NameError(
        "Evaluation data not found in memory! "
        "Please run your test evaluation loop first."
    )

# Slice arrays to the requested plot length
true_field = X_test_true_raw[:plot_len]
pred_field = X_rec_norm[:plot_len]

# ============================================================
# 2. ABSOLUTE ERROR & COLORMAP RANGES
# ============================================================
sst_error = np.abs(true_field - pred_field)

# Enforce shared color scale for True and Predicted fields
vmin_sst = min(true_field.min(), pred_field.min())
vmax_sst = max(true_field.max(), pred_field.max())

# ============================================================
# 3. SUBPLOTS SETUP
# ============================================================
fig, axes = plt.subplots(3, 1, figsize=(14, 10), sharex=True)

# --- TRUE SST FIELD ---
im0 = axes[0].imshow(
    true_field.T,
    aspect='auto',
    origin='lower',
    cmap='coolwarm',
    vmin=vmin_sst,
    vmax=vmax_sst
)
axes[0].set_title('True SST Field', fontsize=14, fontweight='bold')
axes[0].set_ylabel('Spatial Grid Index', fontsize=12)

# --- PREDICTED SST FIELD (3-Model Ensemble) ---
im1 = axes[1].imshow(
    pred_field.T,
    aspect='auto',
    origin='lower',
    cmap='coolwarm',
    vmin=vmin_sst,
    vmax=vmax_sst
)
axes[1].set_title('Adaptive NVAR Predicted SST Field', fontsize=14, fontweight='bold')
axes[1].set_ylabel('Spatial Grid Index', fontsize=12)

# --- ABSOLUTE ERROR FIELD ---
im2 = axes[2].imshow(
    sst_error.T,
    aspect='auto',
    origin='lower',
    cmap='inferno',
    vmin=0,
    vmax=sst_error.max()
)
axes[2].set_title('Absolute SST Error', fontsize=14, fontweight='bold')
axes[2].set_xlabel('Forecast Time Step', fontsize=12)
axes[2].set_ylabel('Spatial Grid Index', fontsize=12)

# ============================================================
# 4. COLORBARS & EXPORT
# ============================================================
cbar0 = fig.colorbar(im0, ax=axes[0], fraction=0.02, pad=0.02)
cbar0.set_label('SST', fontsize=10)

cbar1 = fig.colorbar(im1, ax=axes[1], fraction=0.02, pad=0.02)
cbar1.set_label('SST', fontsize=10)

cbar2 = fig.colorbar(im2, ax=axes[2], fraction=0.02, pad=0.02)
cbar2.set_label('Abs Error', fontsize=10)

plt.tight_layout()

plt.savefig(
    "adaptive_nvar_ensemble_sst_field_evolution_East_China_Sea.png",
    dpi=300,
    bbox_inches='tight'
)

plt.show()
